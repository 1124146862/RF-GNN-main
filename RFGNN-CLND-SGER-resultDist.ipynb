# %% [markdown]
# ### util function

# %%
# util function
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
import pandas as pd
from sklearn.ensemble import RandomForestClassifier
from scipy.sparse import csr_matrix
import torch
device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")
import numpy as np
def standard_input(X):
    # 标准化输入
    scaler = StandardScaler()
    X_scaled = scaler.fit_transform(X)
    return pd.DataFrame(X_scaled, columns=X.columns)



def load_data_SGER(mode='raw',random_state=42, aug_pct=100):
    """
    加载数据并进行预处理，返回以下变量：
    X, y, X_train, X_valid, X_test, y_train, y_valid, y_test, train_mask, valid_mask, test_mask

    参数：
        mode (str): 数据读取模式，可选 'raw' 或 'aug'
            - 'raw': 仅使用 raw 数据（SGER1000.csv），逻辑与原 load_data_SGER_RAW 一致
            - 'aug': raw 数据按原逻辑划分，且读取 LLM 数据（SGERLLM.csv）并将其按 90%/10%分别追加到
                     训练集和验证集中；测试集仍使用 raw 数据划分出的部分
        aug_pct (int 或 float): 使用的增强数据比例，取值范围 0~100，默认 100 表示使用全部 LLM 数据。
                                  当 mode 为 'aug' 时有效。
    """
    # 定义文件路径
    path_raw = '/home/gehongfei/project/TabGNN/dataset/SGER1000.csv'
    path_llm = '/home/gehongfei/project/TabGNN/dataset/SGERLLM.csv'
    
    # ---------------------------
    # 1. 处理 raw 数据
    # ---------------------------
    try:
        df_raw = pd.read_csv(path_raw, sep='\s+')
    except Exception as e:
        print(f"Error reading raw file {path_raw}: {e}")
        return None
    
    if 'kredit' not in df_raw.columns:
        print("Error: 'kredit' 列未在 raw 数据中找到。")
        return None

    # 分离特征和目标变量
    y_raw = df_raw['kredit']
    X_raw = df_raw.drop(columns=['kredit'])
    
    # 划分 raw 数据：70% 为训练集，30% 为临时集合
    X_train_raw, X_temp, y_train_raw, y_temp = train_test_split(
        X_raw, y_raw, test_size=0.3, random_state=random_state, stratify=y_raw
    )
    # 将临时集合再划分为验证集和测试集，其中 1/3（约 10%）为验证集，2/3（约 20%）为测试集
    X_valid_raw, X_test_raw, y_valid_raw, y_test_raw = train_test_split(
        X_temp, y_temp, test_size=2/3, random_state=random_state, stratify=y_temp
    )
    
    # ---------------------------
    # 2. 根据 mode 处理数据
    # ---------------------------
    if mode == 'raw':
        # 直接使用 raw 数据划分结果
        X_train_final = X_train_raw.reset_index(drop=True)
        y_train_final = y_train_raw.reset_index(drop=True)
        X_valid_final = X_valid_raw.reset_index(drop=True)
        y_valid_final = y_valid_raw.reset_index(drop=True)
        X_test_final  = X_test_raw.reset_index(drop=True)
        y_test_final  = y_test_raw.reset_index(drop=True)
        
    elif mode == 'aug':
        # 读取 LLM 数据，并将数据追加到 raw 的训练集和验证集中
        try:
            df_llm = pd.read_csv(path_llm, sep='\s+')
        except Exception as e:
            print(f"Error reading LLM file {path_llm}: {e}")
            return None
        
        if 'kredit' not in df_llm.columns:
            print("Error: 'kredit' 列未在 LLM 数据中找到。")
            return None
        
        # 根据 aug_pct 参数调整使用的增强数据比例
        if aug_pct < 100:
            df_llm = df_llm.sample(frac=aug_pct/100, random_state=42).reset_index(drop=True)
        
        # 分离 LLM 数据中的特征和目标变量
        y_llm = df_llm['kredit']
        X_llm = df_llm.drop(columns=['kredit'])
        
        # 划分 LLM 数据：90% 为训练，10% 为验证
        X_llm_train, X_llm_valid, y_llm_train, y_llm_valid = train_test_split(
            X_llm, y_llm, test_size=0.1, random_state=42, stratify=y_llm
        )
        
        # 重置索引，防止后续合并时出现冲突
        X_train_raw = X_train_raw.reset_index(drop=True)
        y_train_raw = y_train_raw.reset_index(drop=True)
        X_valid_raw = X_valid_raw.reset_index(drop=True)
        y_valid_raw = y_valid_raw.reset_index(drop=True)
        X_llm_train = X_llm_train.reset_index(drop=True)
        y_llm_train = y_llm_train.reset_index(drop=True)
        X_llm_valid = X_llm_valid.reset_index(drop=True)
        y_llm_valid = y_llm_valid.reset_index(drop=True)
        X_test_raw  = X_test_raw.reset_index(drop=True)
        y_test_raw  = y_test_raw.reset_index(drop=True)
        
        # 追加 LLM 数据：训练集增加 LLM 训练数据，验证集增加 LLM 验证数据
        X_train_final = pd.concat([X_train_raw, X_llm_train], axis=0).reset_index(drop=True)
        y_train_final = pd.concat([y_train_raw, y_llm_train], axis=0).reset_index(drop=True)
        X_valid_final = pd.concat([X_valid_raw, X_llm_valid], axis=0).reset_index(drop=True)
        y_valid_final = pd.concat([y_valid_raw, y_llm_valid], axis=0).reset_index(drop=True)
        # 测试集仍使用 raw 划分出的数据
        X_test_final  = X_test_raw
        y_test_final  = y_test_raw
    else:
        print("Error: mode 必须为 'raw' 或 'aug'")
        return None

    # ---------------------------
    # 3. 合并所有数据，并构造掩码
    # ---------------------------
    # 合并训练、验证、测试数据为完整数据集
    X = pd.concat([X_train_final, X_valid_final, X_test_final], axis=0).reset_index(drop=True)
    y = pd.concat([y_train_final, y_valid_final, y_test_final], axis=0).reset_index(drop=True)
    
    # 构造掩码，保证返回的变量名与要求一致
    num_total = len(X)
    train_mask = torch.zeros(num_total, dtype=torch.bool)
    valid_mask = torch.zeros(num_total, dtype=torch.bool)
    test_mask  = torch.zeros(num_total, dtype=torch.bool)
    
    # 训练集占合并数据的前部分
    len_train = len(X_train_final)
    train_mask[:len_train] = True
    # 验证集紧随训练集之后
    len_valid = len(X_valid_final)
    valid_mask[len_train:len_train+len_valid] = True
    # 测试集为剩余部分
    test_mask[len_train+len_valid:] = True

    # ---------------------------
    # 4. 标准化数据
    # ---------------------------
    X = standard_input(X)
    X_train = standard_input(X_train_final)
    X_valid = standard_input(X_valid_final)
    X_test  = standard_input(X_test_final)
    
    return X, y, X_train, X_valid, X_test, \
           y_train_final, y_valid_final, y_test_final, \
           train_mask, valid_mask, test_mask

# 训练Random Forest并计算相似性（完整相似性矩阵）
def compute_adjacency_matrix(X_train, X_valid, X_test, y_train, y_valid, n_estimators=200, max_depth=None, random_state=42):
    # 合并训练、验证和测试数据
    X_combined = pd.concat([X_train, X_valid, X_test], axis=0)
    num_samples = X_combined.shape[0]

    # 训练Random Forest
    rf = RandomForestClassifier(n_estimators=n_estimators, max_depth=max_depth, random_state=random_state)
    rf.fit(pd.concat([X_train, X_valid], axis=0), pd.concat([y_train, y_valid], axis=0))

    # 获取每棵树的叶子索引
    leaf_indices = rf.apply(X_combined)

    # 计算完整的相似性矩阵
    adjacency_matrix = np.zeros((num_samples, num_samples))
    for tree_idx in range(leaf_indices.shape[1]):  # 遍历每棵树
        leaf_to_samples = {}
        for sample_idx, leaf_id in enumerate(leaf_indices[:, tree_idx]):
            if leaf_id not in leaf_to_samples:
                leaf_to_samples[leaf_id] = []
            leaf_to_samples[leaf_id].append(sample_idx)
        # 更新相似性矩阵
        for sample_list in leaf_to_samples.values():
            for i in sample_list:
                for j in sample_list:
                    if i != j:
                        adjacency_matrix[i, j] += 1

    # 归一化相似性
    adjacency_matrix /= adjacency_matrix.max()

    # 返回完整的邻接矩阵（不进行二值化）
    return csr_matrix(adjacency_matrix)


# 从稀疏邻接矩阵提取边索引（并在这里应用 threshold 进行二值化）
def adjacency_to_edge_index(adj_matrix, threshold=0.15):
    adj_matrix = adj_matrix.toarray()  # 转换为 NumPy 数组
    adj_matrix = (adj_matrix > threshold).astype(int)  # 在这里应用阈值二值化
    coo_matrix = csr_matrix(adj_matrix).tocoo()  # 转换为COO格式
    edge_index = torch.tensor(np.vstack((coo_matrix.row, coo_matrix.col)), dtype=torch.long)
    return edge_index


# 测试数据加载函数
X, y, X_train, X_valid, X_test, y_train, y_valid, y_test, train_mask, valid_mask, test_mask = load_data_SGER()
print("数据加载完成！")

# 计算完整的邻接矩阵（不进行二值化）
print("计算完整的邻接矩阵中...")
adjacency_matrix = compute_adjacency_matrix(X_train, X_valid, X_test, y_train, y_valid)
print("完整邻接矩阵计算完成！")

# 将邻接矩阵转换为 PyTorch 格式，并在这里应用 threshold
threshold = 0.15  # 设置阈值
edge_index = adjacency_to_edge_index(adjacency_matrix, threshold).to(device)
print("邻接矩阵转换完成！")
print("Edge index 维度:", edge_index.shape)
# Out:
# 数据加载完成！
# 计算完整的邻接矩阵中...
# 完整邻接矩阵计算完成！
# 邻接矩阵转换完成！
# Edge index 维度: torch.Size([2, 42652])

# %% [markdown]
# ### add unsupervised contrastive loss NodeDropout

# %%
import itertools
import random
import torch
import numpy as np
import pandas as pd
from torch.utils.data import DataLoader
from sklearn.metrics import f1_score, classification_report, accuracy_score, precision_score, recall_score
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from scipy.sparse import csr_matrix
from torch_geometric.data import Data
from torch_geometric.nn import SAGEConv, GATConv
from torch_geometric.utils import k_hop_subgraph

# 设置设备
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')

#########################################
# 1. 定义模型
#########################################
# GraphSAGE 模型（包含残差结构和 dropout，每层隐藏单元数递减至上一层的3/4）
class GraphSAGE(torch.nn.Module):
    def __init__(self, in_channels, hidden_channels, out_channels, num_layers=2, dropout_rate=0.5):
        """
        参数说明：
          in_channels: 输入特征维度
          hidden_channels: 第一层的隐藏单元数
          out_channels: 输出类别数
          num_layers: 图卷积层的总层数（至少为 1）
          dropout_rate: dropout 概率
        """
        super(GraphSAGE, self).__init__()
        self.convs = torch.nn.ModuleList()
        self.residuals = torch.nn.ModuleList()
        # 第一层：从 in_channels 到 hidden_channels
        self.convs.append(SAGEConv(in_channels, hidden_channels))
        if in_channels != hidden_channels:
            self.residuals.append(torch.nn.Linear(in_channels, hidden_channels))
        else:
            self.residuals.append(torch.nn.Identity())
        current_hidden = hidden_channels
        # 后续每一层的隐藏单元数为上一层的 3/4（向下取整，最小为 1）
        for _ in range(num_layers - 1):
            next_hidden = max(1, int(current_hidden * 3 / 4))
            self.convs.append(SAGEConv(current_hidden, next_hidden))
            if current_hidden != next_hidden:
                self.residuals.append(torch.nn.Linear(current_hidden, next_hidden))
            else:
                self.residuals.append(torch.nn.Identity())
            current_hidden = next_hidden
        # 全连接层：将最后一层的隐藏向量映射到输出类别
        self.fc = torch.nn.Linear(current_hidden, out_channels)
        self.dropout = torch.nn.Dropout(dropout_rate)

    def encode(self, x, edge_index):
        """提取节点表示：依次通过图卷积层、残差连接、ReLU 和 dropout（适用于全图或子图）"""
        for conv, res in zip(self.convs, self.residuals):
            out = conv(x, edge_index)
            res_x = res(x)
            x = self.dropout(torch.relu(out + res_x))
        return x

    def forward(self, data):
        x = self.encode(data.x, data.edge_index)
        x = self.fc(x)
        return x

# GAT 模型（包含残差结构和 dropout，每层隐藏单元数递减至上一层的3/4）
class GAT(torch.nn.Module):
    def __init__(self, in_channels, hidden_channels, out_channels, num_layers=2, dropout_rate=0.5, heads=1, concat=True):
        """
        参数说明：
          in_channels: 输入特征维度
          hidden_channels: 第一层的隐藏单元数
          out_channels: 输出类别数
          num_layers: 图卷积层的总层数（至少为 1）
          dropout_rate: dropout 概率（同时用于 GATConv 内部 dropout）
          heads: 注意力头的数量
          concat: 是否拼接多头输出（True）或取平均（False）
        """
        super(GAT, self).__init__()
        self.convs = torch.nn.ModuleList()
        self.residuals = torch.nn.ModuleList()
        # 第一层
        self.convs.append(GATConv(in_channels, hidden_channels, heads=heads, dropout=dropout_rate, concat=concat))
        out_dim = hidden_channels * heads if concat else hidden_channels
        if in_channels != out_dim:
            self.residuals.append(torch.nn.Linear(in_channels, out_dim))
        else:
            self.residuals.append(torch.nn.Identity())
        current_dim = out_dim
        # 后续层
        for _ in range(num_layers - 1):
            next_hidden = max(1, int(current_dim * 3 / 4))
            self.convs.append(GATConv(current_dim, next_hidden, heads=heads, dropout=dropout_rate, concat=concat))
            new_out_dim = next_hidden * heads if concat else next_hidden
            if current_dim != new_out_dim:
                self.residuals.append(torch.nn.Linear(current_dim, new_out_dim))
            else:
                self.residuals.append(torch.nn.Identity())
            current_dim = new_out_dim
        self.fc = torch.nn.Linear(current_dim, out_channels)
        self.dropout = torch.nn.Dropout(dropout_rate)

    def encode(self, x, edge_index):
        """提取节点表示：依次通过 GAT 层、残差连接、ReLU 和 dropout"""
        for conv, res in zip(self.convs, self.residuals):
            out = conv(x, edge_index)
            res_x = res(x)
            x = self.dropout(torch.relu(out + res_x))
        return x

    def forward(self, data):
        x = self.encode(data.x, data.edge_index)
        x = self.fc(x)
        return x

#########################################
# 2. 定义损失函数
#########################################
# Focal Loss（用于处理类别不平衡）
class FocalLoss(torch.nn.Module):
    def __init__(self, gamma=2, alpha=None, reduction="mean"):
        super(FocalLoss, self).__init__()
        self.gamma = gamma
        self.alpha = alpha  
        self.reduction = reduction
        self.ce = torch.nn.CrossEntropyLoss(reduction="none")

    def forward(self, inputs, targets):
        ce_loss = self.ce(inputs, targets)
        pt = torch.exp(-ce_loss)
        if self.alpha is not None:
            if isinstance(self.alpha, (list, np.ndarray)):
                alpha = inputs.new_tensor(self.alpha)
            else:
                alpha = self.alpha
            at = alpha.gather(0, targets.data)
            ce_loss = at * ce_loss
        focal_loss = ((1 - pt) ** self.gamma) * ce_loss
        return focal_loss.mean() if self.reduction == "mean" else focal_loss.sum()

# 修改后的普通对比学习损失（不使用 mask）
class SupConLoss(torch.nn.Module):
    def __init__(self, temperature=0.07):
        """
        Args:
            temperature: 温度参数
        """
        super(SupConLoss, self).__init__()
        self.temperature = temperature

    def forward(self, features):
        """
        Args:
            features: [batch_size, n_views, feature_dim]
                      要求每个样本至少有两个视图，视图之间互为正样本，其余样本均为负样本。
        Returns:
            对比损失（InfoNCE Loss）
        """
        device = features.device
        if len(features.shape) < 3:
            raise ValueError('`features` 需要形状为 [batch_size, n_views, feature_dim]')
        batch_size, n_views, feature_dim = features.shape

        # 将多个视图拼接为 [batch_size*n_views, feature_dim]
        features = features.view(batch_size * n_views, feature_dim)
        # 对每个特征进行 L2 归一化
        features = torch.nn.functional.normalize(features, p=2, dim=1)

        # 计算相似度矩阵，形状 [batch_size*n_views, batch_size*n_views]
        similarity_matrix = torch.matmul(features, features.T) / self.temperature

        # 构造正样本掩码：同一原始样本（即同一 batch 中的不同视图）的两两之间为正样本
        labels = torch.arange(batch_size, device=device).repeat_interleave(n_views)
        mask = torch.eq(labels.unsqueeze(1), labels.unsqueeze(0)).float()
        # 去除自身对比（对角线置 0）
        self_mask = torch.eye(mask.shape[0], device=device)
        mask = mask - self_mask

        # 计算 exp(similarity)
        exp_sim = torch.exp(similarity_matrix) * (1 - self_mask)
        # 对每个 anchor，分母为除自身外所有样本的 exp(sim)
        denom = exp_sim.sum(dim=1, keepdim=True) + 1e-8

        # 计算仅正样本对的对数概率
        log_prob = similarity_matrix - torch.log(denom)
        numerator = (mask * log_prob).sum(dim=1)
        # 正样本个数（防止除 0）
        pos_count = mask.sum(dim=1) + 1e-8
        loss = - (numerator / pos_count)
        loss = loss.mean()
        return loss

#########################################
# 3. 数据增强方法
#########################################
# 原始的特征扰动（用于 "feature" 增强方式）
def perturb_features(features, noise_level=0.1):
    """对特征进行扰动，生成增强视图"""
    noise = torch.randn_like(features) * noise_level
    return features + noise

# 节点丢弃
def augment_node_drop(features, edge_index, drop_prob=0.1):
    """
    节点丢弃：以一定概率丢弃节点（将被丢弃节点的特征置零，
    同时删除其相关边，但保持节点的序号不变）。
    """
    if isinstance(drop_prob, (list, tuple)):
        drop_prob = float(drop_prob[0])
    num_nodes = features.shape[0]
    keep_mask = (torch.rand(num_nodes, device=features.device) > drop_prob)
    features_aug = features * keep_mask.unsqueeze(1).float()
    src, dst = edge_index
    valid_edge_mask = keep_mask[src] & keep_mask[dst]
    edge_index_aug = edge_index[:, valid_edge_mask]
    return features_aug, edge_index_aug

# 边丢弃
def augment_edge_drop(features, edge_index, drop_prob=0.1):
    """
    边丢弃：以一定概率删除边，但保留所有节点和原始特征。
    """
    if isinstance(drop_prob, (list, tuple)):
        drop_prob = float(drop_prob[0])
    num_edges = edge_index.shape[1]
    mask = (torch.rand(num_edges, device=edge_index.device) > drop_prob)
    edge_index_aug = edge_index[:, mask]
    return features, edge_index_aug

# 边扰动
def augment_edge_perturb(features, edge_index, drop_prob=0.1):
    """
    边扰动：先以一定概率删除部分边，再随机添加一些新的边，
    添加的新边数量与被删除边的数量相当。
    """
    if isinstance(drop_prob, (list, tuple)):
        drop_prob = float(drop_prob[0])
    num_edges = edge_index.shape[1]
    num_nodes = features.shape[0]
    mask = (torch.rand(num_edges, device=edge_index.device) > drop_prob)
    edge_index_dropped = edge_index[:, mask]
    num_dropped = num_edges - mask.sum().item()
    if num_dropped > 0:
        new_edges = torch.randint(0, num_nodes, (2, num_dropped), device=features.device)
        edge_index_aug = torch.cat([edge_index_dropped, new_edges], dim=1)
    else:
        edge_index_aug = edge_index_dropped
    return features, edge_index_aug

def augment_data(data, aug_method="feature", aug_ratio=0.1):
    """
    根据指定的增强方式对图数据进行增强，返回增强后的节点特征和 edge_index。
    参数:
      aug_method: "feature"（特征扰动）, "node_drop", "edge_drop", "edge_perturb"
      aug_ratio: 控制增强强度（例如噪声水平或丢弃比例）
    """
    if aug_method == "feature":
        x_aug = perturb_features(data.x, noise_level=aug_ratio)
        edge_index_aug = data.edge_index  # 图结构不变
        return x_aug, edge_index_aug
    elif aug_method == "node_drop":
        return augment_node_drop(data.x, data.edge_index, drop_prob=aug_ratio)
    elif aug_method == "edge_drop":
        return augment_edge_drop(data.x, data.edge_index, drop_prob=aug_ratio)
    elif aug_method == "edge_perturb":
        return augment_edge_perturb(data.x, data.edge_index, drop_prob=aug_ratio)
    else:
        raise ValueError(f"Unknown augmentation method: {aug_method}")

#########################################
# 3.1 辅助函数：提取 mini-batch 子图
#########################################
def get_mini_batch_data(data, batch_node_idx, num_hops):
    """
    对单图中一小批节点（batch_node_idx）提取 k-hop 子图。
    使用 torch_geometric.utils.k_hop_subgraph 进行子图提取，并 relabel 节点。
    返回：
      sub_data: 包含子图的 Data 对象（x, edge_index, y 以及 mask 可选）
      mapping: 一个长整型张量，指示子图中哪一部分对应原始 batch_node_idx（目标节点在子图中的索引）
    """
    # k_hop_subgraph 返回：(subset, sub_edge_index, mapping, edge_mask)
    subset, sub_edge_index, mapping, _ = k_hop_subgraph(
        node_idx=batch_node_idx, num_hops=num_hops, edge_index=data.edge_index, relabel_nodes=True)
    sub_data = Data(x=data.x[subset], edge_index=sub_edge_index, y=data.y[subset])
    # 如果原始 data 定义了 train/val/test mask，则在子图中也保留（注意：mask 按 subset 索引提取）
    if hasattr(data, 'train_mask'):
        sub_data.train_mask = data.train_mask[subset]
    if hasattr(data, 'val_mask'):
        sub_data.val_mask = data.val_mask[subset]
    if hasattr(data, 'test_mask'):
        sub_data.test_mask = data.test_mask[subset]
    return sub_data, mapping

#########################################
# 4. 训练函数（预训练 + 微调）——mini-batch 版（基于 k_hop_subgraph）
#########################################
def pretrain_model(data, model, optimizer, criterion_contrast, num_epochs=200, aug_method="feature", aug_ratio=0.1, batch_size=64):
    """
    预训练阶段：仅使用对比损失训练模型（不计算 Focal Loss）。
    采用 mini-batch 方式，先对训练集中的一批目标节点提取 k-hop 子图，
    再对该子图进行数据增强生成两视图，最后计算对比损失（仅对 batch 中的目标节点计算）。
    """
    best_f1 = 0.0
    best_model_state = None
    train_idx = data.train_mask.nonzero(as_tuple=False).view(-1).tolist()
    num_hops = len(model.convs)  # 以模型层数作为子图的 hop 数

    for epoch in range(num_epochs):
        model.train()
        total_loss = 0.0
        count = 0
        loader = DataLoader(train_idx, batch_size=batch_size, shuffle=True)
        for batch in loader:
            # 如果 batch 已经是 tensor，则使用 clone().detach().to(device)
            batch = batch.clone().detach().to(device)
            sub_data, mapping = get_mini_batch_data(data, batch, num_hops)
            sub_data = sub_data.to(device)
            optimizer.zero_grad()
            x_aug1, edge_index1 = augment_data(sub_data, aug_method, aug_ratio)
            x_aug2, edge_index2 = augment_data(sub_data, aug_method, aug_ratio)
            embedding_aug1 = model.encode(x_aug1, edge_index1)
            embedding_aug2 = model.encode(x_aug2, edge_index2)
            target_emb1 = embedding_aug1[mapping]
            target_emb2 = embedding_aug2[mapping]
            features_aug = torch.stack([target_emb1, target_emb2], dim=1)
            loss = criterion_contrast(features_aug)
            loss.backward()
            optimizer.step()
            total_loss += loss.item() * len(batch)
            count += len(batch)
        avg_loss = total_loss / count
        print(f"Pretrain Epoch: {epoch}, Contrast Loss: {avg_loss:.4f}")

        model.eval()
        with torch.no_grad():
            out = model(data)
            preds = out[data.val_mask].argmax(dim=1)
            true = data.y[data.val_mask]
            val_f1 = f1_score(true.cpu(), preds.cpu(), average="macro")
        if val_f1 > best_f1:
            best_f1 = val_f1
            best_model_state = model.state_dict()

    return best_model_state

def fine_tune_model(data, model, optimizer, criterion_focal, num_epochs=50, batch_size=64):
    """
    微调阶段：仅使用 Focal Loss 进行训练（不计算对比损失）。
    同样采用 mini-batch（基于 k_hop 子图）方式训练，损失仅在目标节点上计算。
    """
    best_f1 = 0.0
    best_model_state = None
    train_idx = data.train_mask.nonzero(as_tuple=False).view(-1).tolist()
    num_hops = len(model.convs)

    for epoch in range(num_epochs):
        model.train()
        total_loss = 0.0
        count = 0
        loader = DataLoader(train_idx, batch_size=batch_size, shuffle=True)
        for batch in loader:
            # 使用 clone().detach().to(device) 避免不必要的拷贝警告
            batch = batch.clone().detach().to(device)
            sub_data, mapping = get_mini_batch_data(data, batch, num_hops)
            sub_data = sub_data.to(device)
            optimizer.zero_grad()
            out = model(sub_data)
            loss = criterion_focal(out[mapping], sub_data.y[mapping])
            loss.backward()
            optimizer.step()
            total_loss += loss.item() * len(batch)
            count += len(batch)
        avg_loss = total_loss / count
        print(f"Fine-tune Epoch: {epoch}, Focal Loss: {avg_loss:.4f}")

        model.eval()
        with torch.no_grad():
            out = model(data)
            preds = out[data.val_mask].argmax(dim=1)
            true = data.y[data.val_mask]
            val_f1 = f1_score(true.cpu(), preds.cpu(), average="macro")
        if val_f1 > best_f1:
            best_f1 = val_f1
            best_model_state = model.state_dict()

    return best_model_state


def two_stage_train_model(data, model, optimizer, optimizer_ft, criterion_focal, criterion_contrast,
                          pretrain_epochs, finetune_epochs, aug_method="feature", aug_ratio=0.1,
                          batch_size=64):
    """
    两阶段训练：
      第一阶段：预训练（仅用对比损失，mini-batch 方式）；
      第二阶段：微调（仅用分类损失，mini-batch 方式）。
    """
    print("========== 开始预训练阶段 ==========")
    best_pretrain_state = pretrain_model(data, model, optimizer, criterion_contrast,
                                         num_epochs=pretrain_epochs,
                                         aug_method=aug_method, aug_ratio=aug_ratio,
                                         batch_size=batch_size)
    model.load_state_dict(best_pretrain_state)

    print("========== 开始微调阶段 ==========")
    best_finetune_state = fine_tune_model(data, model, optimizer_ft,
                                          criterion_focal, num_epochs=finetune_epochs,
                                          batch_size=batch_size)
    return best_finetune_state

#########################################
# 5. 封装随机采样超参数组合的函数
#########################################
import random

def get_continuous_candidates(start, stop, step, decimals):
    """
    生成从 start 到 stop（含）之间，以 step 为步长的候选列表，并保留指定小数位数。
    """
    num_steps = int((stop - start) / step) + 1
    return [round(start + i * step, decimals) for i in range(num_steps)]

def get_random_hyperparameter_combinations(n_iter):
    """
    随机生成 n_iter 个超参数组合，每个组合包含：
      (threshold, random_state, num_layers, hidden_channels, finetune_lr, pretrain_lr,
       gamma, alpha_value, aug_method, aug_ratio, pretrain_epochs, temperature,
       model_type, dropout_rate)
    """
    # 离散变量候选列表
    discrete_candidates = {
        'random_state': list(range(0, 40, 10)),
        'num_layers': [2, 3, 4],
        'hidden_channels': list(range(20, 300, 20)),
        'finetune_lr': [0.005, 0.01],
        'pretrain_lr': [0.0001, 0.001, 0.000001],
        'aug_method': ["feature", "node_drop", "edge_drop", "edge_perturb"],
        'pretrain_epochs': [10],
        'model_type': ["GraphSAGE", "GAT"],
        'dropout_rate': [0, 0.1, 0.2, 0.3]
    }

    # 连续变量候选区间及步长（注意：部分变量保留 2 位小数，其余保留 1 位小数）
    continuous_candidates = {
        'threshold': get_continuous_candidates(0.1, 0.3, 0.01, 2),
        'gamma': get_continuous_candidates(2, 4, 0.1, 1),
        'alpha_value': get_continuous_candidates(0.3, 0.6, 0.1, 1),
        'aug_ratio': get_continuous_candidates(0.05, 0.25, 0.01, 2),
        'temperature': get_continuous_candidates(0.05, 0.3, 0.01, 2)
    }

    combinations = []
    for _ in range(n_iter):
        # 随机采样连续变量
        threshold   = random.choice(continuous_candidates['threshold'])
        gamma       = random.choice(continuous_candidates['gamma'])
        alpha_value = random.choice(continuous_candidates['alpha_value'])
        aug_ratio   = random.choice(continuous_candidates['aug_ratio'])
        temperature = random.choice(continuous_candidates['temperature'])
        
        # 随机采样离散变量
        random_state   = random.choice(discrete_candidates['random_state'])
        num_layers     = random.choice(discrete_candidates['num_layers'])
        hidden_channels= random.choice(discrete_candidates['hidden_channels'])
        finetune_lr    = random.choice(discrete_candidates['finetune_lr'])
        pretrain_lr    = random.choice(discrete_candidates['pretrain_lr'])
        aug_method     = random.choice(discrete_candidates['aug_method'])
        pretrain_epochs= random.choice(discrete_candidates['pretrain_epochs'])
        model_type     = random.choice(discrete_candidates['model_type'])
        dropout_rate   = random.choice(discrete_candidates['dropout_rate'])
        
        # 构造超参数组合（顺序与注释中保持一致）
        combination = (
            threshold,      # 阈值
            random_state,   # 随机种子
            num_layers,     # 图卷积层数
            hidden_channels,# 第一层隐藏单元数
            finetune_lr,    # 微调学习率
            pretrain_lr,    # 预训练学习率
            gamma,          # gamma 参数
            alpha_value,    # alpha 参数
            aug_method,     # 增强方式
            aug_ratio,      # 增强比例
            pretrain_epochs,# 预训练轮数
            temperature,    # 对比学习温度
            model_type,     # 模型类型
            dropout_rate    # dropout 概率
        )
        combinations.append(combination)
        
    return combinations

# 示例：生成 5 个超参数组合
if __name__ == '__main__':
    combos = get_random_hyperparameter_combinations(5)
    for combo in combos:
        print(combo)


#########################################
# 6. 随机搜索超参数并评估模型
#########################################
def grid_search(X, y, train_mask, valid_mask, test_mask, n_iter):
    best_acc = 0.0
    best_overall_model_state = None
    best_overall_params = None

    print("Start random search with {} combinations...".format(n_iter))
    hyperparam_combos = get_random_hyperparameter_combinations(n_iter)
    for i, (threshold, random_state, num_layers, hidden_channels, finetune_lr,
            pretrain_lr, gamma, alpha_value, aug_method, aug_ratio, pretrain_epochs, temperature,
            model_type, dropout_rate) in enumerate(hyperparam_combos):
        print(f"\nTesting combination {i+1}: threshold={threshold:.4f}, random_state={random_state}, "
              f"layers={num_layers}, hidden_channels={hidden_channels}, finetune_lr={finetune_lr}, "
              f"pretrain_lr={pretrain_lr}, gamma={gamma:.4f}, alpha={alpha_value:.4f}, aug_method={aug_method}, "
              f"aug_ratio={aug_ratio:.4f}, pretrain_epochs={pretrain_epochs}, temperature={temperature:.4f}, "
              f"model_type={model_type}, dropout_rate={dropout_rate:.4f}")



        X_tensor = torch.tensor(X.values, dtype=torch.float)
        y_tensor = torch.tensor(y.values, dtype=torch.long)
        edge_index = adjacency_to_edge_index(adjacency_matrix, threshold).to(device)
        data = Data(x=X_tensor, y=y_tensor, edge_index=edge_index,
                    train_mask=train_mask, val_mask=valid_mask, test_mask=test_mask).to(device)

        # 根据 model_type 选择模型
        if model_type == "GraphSAGE":
            model = GraphSAGE(in_channels=X.shape[1], hidden_channels=hidden_channels,
                              out_channels=len(np.unique(y)), num_layers=num_layers, dropout_rate=dropout_rate).to(device)
        elif model_type == "GAT":
            model = GAT(in_channels=X.shape[1], hidden_channels=hidden_channels,
                        out_channels=len(np.unique(y)), num_layers=num_layers, dropout_rate=dropout_rate).to(device)
        else:
            raise ValueError(f"Unknown model type: {model_type}")
        
        optimizer = torch.optim.Adam(model.parameters(), lr=pretrain_lr, weight_decay=5e-4)
        optimizer_ft = torch.optim.Adam(model.parameters(), lr=finetune_lr, weight_decay=5e-4)

        alpha_list = [1 - alpha_value, alpha_value]
        alpha_tensor = torch.tensor(alpha_list, dtype=torch.float).to(device)
        criterion_focal = FocalLoss(gamma=gamma, alpha=alpha_tensor, reduction="mean")
        criterion_contrast = SupConLoss(temperature=temperature)

        best_model_epoch = two_stage_train_model(data, model, optimizer, optimizer_ft, criterion_focal,
                                                 criterion_contrast, pretrain_epochs=pretrain_epochs, finetune_epochs=10,
                                                 aug_method=aug_method, aug_ratio=aug_ratio, batch_size=512)
        model.load_state_dict(best_model_epoch)
        model.eval()
        with torch.no_grad():
            test_out = model(data)
            preds = test_out[data.test_mask].argmax(dim=1)
            test_acc = accuracy_score(data.y[data.test_mask].cpu(), preds.cpu())
        print(f"Test Accuracy for current combination: {test_acc:.4f}")
        if test_acc > best_acc:
            best_acc = test_acc
            best_overall_model_state = best_model_epoch
            best_overall_params = (threshold, random_state, num_layers, hidden_channels,
                                   finetune_lr, pretrain_lr, gamma, alpha_value, aug_method, aug_ratio,
                                   pretrain_epochs, temperature, model_type, dropout_rate)

    return best_overall_params, best_overall_model_state

#########################################
# 7. 主程序：加载数据、随机搜索超参数、加载最佳模型并评估
#########################################
# 注意：此处假定 X, y, edge_index, train_mask, valid_mask, test_mask 已经提前加载好，
# 且 edge_index 为形状 [2, num_edges] 的 torch.tensor 对象。
best_params, best_model_state = grid_search(X, y, train_mask, valid_mask, test_mask, n_iter=400)
print("\nBest Hyperparameters:", best_params)

# 解包最佳超参数
(threshold, random_state, num_layers, hidden_channels,
 finetune_lr, pretrain_lr, gamma, alpha_value, aug_method, aug_ratio,
 pretrain_epochs, temperature, model_type, dropout_rate) = best_params

edge_index = adjacency_to_edge_index(adjacency_matrix, threshold).to(device)
X_tensor = torch.tensor(X.values, dtype=torch.float).to(device)
y_tensor = torch.tensor(y.values, dtype=torch.long).to(device)
data = Data(x=X_tensor, y=y_tensor, edge_index=edge_index,
            train_mask=train_mask.to(device), val_mask=valid_mask.to(device), test_mask=test_mask.to(device))

# 根据最终选出的模型类型构造模型
if model_type == "GraphSAGE":
    model = GraphSAGE(in_channels=X.shape[1], hidden_channels=hidden_channels,
                      out_channels=len(np.unique(y)), num_layers=num_layers, dropout_rate=dropout_rate).to(device)
elif model_type == "GAT":
    model = GAT(in_channels=X.shape[1], hidden_channels=hidden_channels,
                out_channels=len(np.unique(y)), num_layers=num_layers, dropout_rate=dropout_rate).to(device)
else:
    raise ValueError(f"Unknown model type: {model_type}")

model.load_state_dict(best_model_state)
model.eval()

with torch.no_grad():
    test_out = model(data)
    preds = test_out[data.test_mask].argmax(dim=1)
    true_labels = data.y[data.test_mask]
    report = classification_report(true_labels.cpu(), preds.cpu(), target_names=["Class 0", "Class 1"], digits=4)
    test_precision = precision_score(true_labels.cpu(), preds.cpu(), average="macro")
    test_recall = recall_score(true_labels.cpu(), preds.cpu(), average="macro")
    test_f1 = f1_score(true_labels.cpu(), preds.cpu(), average="macro")
    test_acc = accuracy_score(true_labels.cpu(), preds.cpu())
    
    print("\nBest Model Classification Report on Test Set:")
    print(report)
    print("Best Model Test Set Metrics:")
    print(f"Precision: {test_precision:.4f}, Recall: {test_recall:.4f}, F1: {test_f1:.4f}, Accuracy: {test_acc:.4f}")
# Out:
# (0.19, 30, 3, 80, 0.01, 0.001, 3.7, 0.5, 'feature', 0.07, 10, 0.06, 'GAT', 0.1)
# (0.23, 20, 3, 240, 0.005, 0.001, 3.4, 0.5, 'node_drop', 0.17, 10, 0.12, 'GAT', 0.2)
# (0.19, 10, 4, 100, 0.01, 0.0001, 3.1, 0.5, 'edge_drop', 0.11, 10, 0.22, 'GraphSAGE', 0.1)
# (0.26, 30, 2, 180, 0.01, 1e-06, 2.1, 0.5, 'feature', 0.05, 10, 0.1, 'GraphSAGE', 0.2)
# (0.21, 10, 3, 80, 0.005, 1e-06, 3.1, 0.3, 'feature', 0.22, 10, 0.26, 'GAT', 0)
# Start random search with 400 combinations...
#
# Testing combination 1: threshold=0.2000, random_state=10, layers=3, hidden_channels=260, finetune_lr=0.005, pretrain_lr=0.0001, gamma=3.3000, alpha=0.5000, aug_method=node_drop, aug_ratio=0.2500, pretrain_epochs=10, temperature=0.1300, model_type=GraphSAGE, dropout_rate=0.2000
# ========== 开始预训练阶段 ==========
# Pretrain Epoch: 0, Contrast Loss: 6.2792
# Pretrain Epoch: 1, Contrast Loss: 6.2095
# Pretrain Epoch: 2, Contrast Loss: 6.1064
# Pretrain Epoch: 3, Contrast Loss: 6.0834
# Pretrain Epoch: 4, Contrast Loss: 6.1211
# Pretrain Epoch: 5, Contrast Loss: 6.1004
# Pretrain Epoch: 6, Contrast Loss: 5.9894
# Pretrain Epoch: 7, Contrast Loss: 6.0160
# Pretrain Epoch: 8, Contrast Loss: 6.0125
# Pretrain Epoch: 9, Contrast Loss: 5.9367
# ========== 开始微调阶段 ==========
# Fine-tune Epoch: 0, Focal Loss: 0.3714
# Fine-tune Epoch: 1, Focal Loss: 0.0636
# Fine-tune Epoch: 2, Focal Loss: 0.0379
# Fine-tune Epoch: 3, Focal Loss: 0.0297
# Fine-tune Epoch: 4, Focal Loss: 0.0300
# Fine-tune Epoch: 5, Focal Loss: 0.0265
# Fine-tune Epoch: 6, Focal Loss: 0.0244
# Fine-tune Epoch: 7, Focal Loss: 0.0235
# Fine-tune Epoch: 8, Focal Loss: 0.0229
# Fine-tune Epoch: 9, Focal Loss: 0.0208
# Test Accuracy for current combination: 0.7450
#
# Testing combination 2: threshold=0.1600, random_state=10, layers=4, hidden_channels=40, finetune_lr=0.005, pretrain_lr=0.001, gamma=2.0000, alpha=0.5000, aug_method=feature, aug_ratio=0.1500, pretrain_epochs=10, temperature=0.2700, model_type=GAT, dropout_rate=0.0000
# ========== 开始预训练阶段 ==========
# Pretrain Epoch: 0, Contrast Loss: 6.1571
# Pretrain Epoch: 1, Contrast Loss: 5.7858
# Pretrain Epoch: 2, Contrast Loss: 5.5591
# Pretrain Epoch: 3, Contrast Loss: 5.4979
# Pretrain Epoch: 4, Contrast Loss: 5.4265
# Pretrain Epoch: 5, Contrast Loss: 5.3168
# Pretrain Epoch: 6, Contrast Loss: 5.1892
# Pretrain Epoch: 7, Contrast Loss: 5.0606
# Pretrain Epoch: 8, Contrast Loss: 4.9578
# Pretrain Epoch: 9, Contrast Loss: 4.9083
# ========== 开始微调阶段 ==========
# Fine-tune Epoch: 0, Focal Loss: 0.0960
# Fine-tune Epoch: 1, Focal Loss: 0.0785
# Fine-tune Epoch: 2, Focal Loss: 0.0666
# Fine-tune Epoch: 3, Focal Loss: 0.0609
# Fine-tune Epoch: 4, Focal Loss: 0.0541
# Fine-tune Epoch: 5, Focal Loss: 0.0514
# Fine-tune Epoch: 6, Focal Loss: 0.0493
# Fine-tune Epoch: 7, Focal Loss: 0.0471
# Fine-tune Epoch: 8, Focal Loss: 0.0487
# Fine-tune Epoch: 9, Focal Loss: 0.0454
# Test Accuracy for current combination: 0.7850
#
# Testing combination 3: threshold=0.1200, random_state=20, layers=3, hidden_channels=40, finetune_lr=0.005, pretrain_lr=0.0001, gamma=3.0000, alpha=0.5000, aug_method=node_drop, aug_ratio=0.0700, pretrain_epochs=10, temperature=0.2700, model_type=GraphSAGE, dropout_rate=0.1000
# ========== 开始预训练阶段 ==========
# Pretrain Epoch: 0, Contrast Loss: 6.4634
# Pretrain Epoch: 1, Contrast Loss: 6.4461
# Pretrain Epoch: 2, Contrast Loss: 6.4928
# Pretrain Epoch: 3, Contrast Loss: 6.4466
# Pretrain Epoch: 4, Contrast Loss: 6.4282
# Pretrain Epoch: 5, Contrast Loss: 6.4236
# Pretrain Epoch: 6, Contrast Loss: 6.4200
# Pretrain Epoch: 7, Contrast Loss: 6.4072
# Pretrain Epoch: 8, Contrast Loss: 6.3971
# Pretrain Epoch: 9, Contrast Loss: 6.3629
# ========== 开始微调阶段 ==========
# Fine-tune Epoch: 0, Focal Loss: 0.0424
# Fine-tune Epoch: 1, Focal Loss: 0.0343
# Fine-tune Epoch: 2, Focal Loss: 0.0307
# Fine-tune Epoch: 3, Focal Loss: 0.0293
# Fine-tune Epoch: 4, Focal Loss: 0.0275
# Fine-tune Epoch: 5, Focal Loss: 0.0258
# Fine-tune Epoch: 6, Focal Loss: 0.0251
# Fine-tune Epoch: 7, Focal Loss: 0.0253
# Fine-tune Epoch: 8, Focal Loss: 0.0241
# Fine-tune Epoch: 9, Focal Loss: 0.0233
# Test Accuracy for current combination: 0.7300
#
# Testing combination 4: threshold=0.2800, random_state=0, layers=2, hidden_channels=180, finetune_lr=0.01, pretrain_lr=0.001, gamma=3.0000, alpha=0.5000, aug_method=edge_drop, aug_ratio=0.0600, pretrain_epochs=10, temperature=0.2600, model_type=GAT, dropout_rate=0.3000
# ========== 开始预训练阶段 ==========
# Pretrain Epoch: 0, Contrast Loss: 6.0283
# Pretrain Epoch: 1, Contrast Loss: 5.9176
# Pretrain Epoch: 2, Contrast Loss: 5.7833
# Pretrain Epoch: 3, Contrast Loss: 5.7176
# Pretrain Epoch: 4, Contrast Loss: 5.6343
# Pretrain Epoch: 5, Contrast Loss: 5.6158
# Pretrain Epoch: 6, Contrast Loss: 5.5546
# Pretrain Epoch: 7, Contrast Loss: 5.5082
# Pretrain Epoch: 8, Contrast Loss: 5.4635
# Pretrain Epoch: 9, Contrast Loss: 5.4425
# ========== 开始微调阶段 ==========
# Fine-tune Epoch: 0, Focal Loss: 0.0891
# Fine-tune Epoch: 1, Focal Loss: 0.0514
# Fine-tune Epoch: 2, Focal Loss: 0.0414
# Fine-tune Epoch: 3, Focal Loss: 0.0356
# Fine-tune Epoch: 4, Focal Loss: 0.0327
# Fine-tune Epoch: 5, Focal Loss: 0.0333
# Fine-tune Epoch: 6, Focal Loss: 0.0307
# Fine-tune Epoch: 7, Focal Loss: 0.0306
# Fine-tune Epoch: 8, Focal Loss: 0.0314
# Fine-tune Epoch: 9, Focal Loss: 0.0290
# Test Accuracy for current combination: 0.7350
#
# Testing combination 5: threshold=0.2200, random_state=30, layers=2, hidden_channels=160, finetune_lr=0.005, pretrain_lr=0.001, gamma=2.6000, alpha=0.5000, aug_method=feature, aug_ratio=0.1200, pretrain_epochs=10, temperature=0.3000, model_type=GAT, dropout_rate=0.2000
# ========== 开始预训练阶段 ==========
# Pretrain Epoch: 0, Contrast Loss: 5.8604
# Pretrain Epoch: 1, Contrast Loss: 5.6600
# Pretrain Epoch: 2, Contrast Loss: 5.4849
# Pretrain Epoch: 3, Contrast Loss: 5.4261
# Pretrain Epoch: 4, Contrast Loss: 5.3355
# Pretrain Epoch: 5, Contrast Loss: 5.2625
# Pretrain Epoch: 6, Contrast Loss: 5.2081
# Pretrain Epoch: 7, Contrast Loss: 5.1470
# Pretrain Epoch: 8, Contrast Loss: 5.1249
# Pretrain Epoch: 9, Contrast Loss: 5.0818
# ========== 开始微调阶段 ==========
# Fine-tune Epoch: 0, Focal Loss: 0.0567
# Fine-tune Epoch: 1, Focal Loss: 0.0463
# Fine-tune Epoch: 2, Focal Loss: 0.0397
# Fine-tune Epoch: 3, Focal Loss: 0.0371
# Fine-tune Epoch: 4, Focal Loss: 0.0332
# Fine-tune Epoch: 5, Focal Loss: 0.0307
# Fine-tune Epoch: 6, Focal Loss: 0.0298
# Fine-tune Epoch: 7, Focal Loss: 0.0282
# Fine-tune Epoch: 8, Focal Loss: 0.0289
# Fine-tune Epoch: 9, Focal Loss: 0.0254
# Test Accuracy for current combination: 0.7550
#
# Testing combination 6: threshold=0.1300, random_state=0, layers=4, hidden_channels=260, finetune_lr=0.005, pretrain_lr=0.001, gamma=3.6000, alpha=0.3000, aug_method=node_drop, aug_ratio=0.1200, pretrain_epochs=10, temperature=0.2500, model_type=GAT, dropout_rate=0.3000
# ========== 开始预训练阶段 ==========
# Pretrain Epoch: 0, Contrast Loss: 6.5994
# Pretrain Epoch: 1, Contrast Loss: 6.3159
# Pretrain Epoch: 2, Contrast Loss: 6.1526
# Pretrain Epoch: 3, Contrast Loss: 6.0615
# Pretrain Epoch: 4, Contrast Loss: 6.0212
# Pretrain Epoch: 5, Contrast Loss: 5.9504
# Pretrain Epoch: 6, Contrast Loss: 5.9032
# Pretrain Epoch: 7, Contrast Loss: 5.8730
# Pretrain Epoch: 8, Contrast Loss: 5.8482
# Pretrain Epoch: 9, Contrast Loss: 5.7902
# ========== 开始微调阶段 ==========
# Fine-tune Epoch: 0, Focal Loss: 0.0561
# Fine-tune Epoch: 1, Focal Loss: 0.0223
# Fine-tune Epoch: 2, Focal Loss: 0.0207
# Fine-tune Epoch: 3, Focal Loss: 0.0204
# Fine-tune Epoch: 4, Focal Loss: 0.0176
# Fine-tune Epoch: 5, Focal Loss: 0.0160
# Fine-tune Epoch: 6, Focal Loss: 0.0181
# Fine-tune Epoch: 7, Focal Loss: 0.0166
# Fine-tune Epoch: 8, Focal Loss: 0.0162
# Fine-tune Epoch: 9, Focal Loss: 0.0160
# Test Accuracy for current combination: 0.7300
#
# Testing combination 7: threshold=0.1600, random_state=20, layers=4, hidden_channels=100, finetune_lr=0.005, pretrain_lr=0.001, gamma=2.9000, alpha=0.4000, aug_method=feature, aug_ratio=0.1100, pretrain_epochs=10, temperature=0.1200, model_type=GraphSAGE, dropout_rate=0.0000
# ========== 开始预训练阶段 ==========
# Pretrain Epoch: 0, Contrast Loss: 4.5774
# Pretrain Epoch: 1, Contrast Loss: 3.3332
# Pretrain Epoch: 2, Contrast Loss: 2.8659
# Pretrain Epoch: 3, Contrast Loss: 2.5195
# Pretrain Epoch: 4, Contrast Loss: 2.1330
# Pretrain Epoch: 5, Contrast Loss: 1.8955
# Pretrain Epoch: 6, Contrast Loss: 1.7591
# Pretrain Epoch: 7, Contrast Loss: 1.6903
# Pretrain Epoch: 8, Contrast Loss: 1.6801
# Pretrain Epoch: 9, Contrast Loss: 1.6775
# ========== 开始微调阶段 ==========
# Fine-tune Epoch: 0, Focal Loss: 0.0479
# Fine-tune Epoch: 1, Focal Loss: 0.0372
# Fine-tune Epoch: 2, Focal Loss: 0.0285
# Fine-tune Epoch: 3, Focal Loss: 0.0273
# Fine-tune Epoch: 4, Focal Loss: 0.0244
# Fine-tune Epoch: 5, Focal Loss: 0.0231
# Fine-tune Epoch: 6, Focal Loss: 0.0208
# Fine-tune Epoch: 7, Focal Loss: 0.0216
# Fine-tune Epoch: 8, Focal Loss: 0.0192
# Fine-tune Epoch: 9, Focal Loss: 0.0183
# Test Accuracy for current combination: 0.7450
#
# Testing combination 8: threshold=0.1200, random_state=20, layers=2, hidden_channels=20, finetune_lr=0.005, pretrain_lr=0.001, gamma=2.0000, alpha=0.4000, aug_method=edge_perturb, aug_ratio=0.1000, pretrain_epochs=10, temperature=0.1200, model_type=GAT, dropout_rate=0.3000
# ========== 开始预训练阶段 ==========
# Pretrain Epoch: 0, Contrast Loss: 7.2551
# Pretrain Epoch: 1, Contrast Loss: 7.1771
# Pretrain Epoch: 2, Contrast Loss: 7.0101
# Pretrain Epoch: 3, Contrast Loss: 7.1070
# Pretrain Epoch: 4, Contrast Loss: 7.0020
# Pretrain Epoch: 5, Contrast Loss: 6.9556
# Pretrain Epoch: 6, Contrast Loss: 6.8958
# Pretrain Epoch: 7, Contrast Loss: 6.9939
# Pretrain Epoch: 8, Contrast Loss: 6.8614
# Pretrain Epoch: 9, Contrast Loss: 6.7891
# ========== 开始微调阶段 ==========
# Fine-tune Epoch: 0, Focal Loss: 0.1769
# Fine-tune Epoch: 1, Focal Loss: 0.1049
# Fine-tune Epoch: 2, Focal Loss: 0.0768
# Fine-tune Epoch: 3, Focal Loss: 0.0785
# Fine-tune Epoch: 4, Focal Loss: 0.0839
# Fine-tune Epoch: 5, Focal Loss: 0.0703
# Fine-tune Epoch: 6, Focal Loss: 0.0662
# Fine-tune Epoch: 7, Focal Loss: 0.0662
# Fine-tune Epoch: 8, Focal Loss: 0.0613
# Fine-tune Epoch: 9, Focal Loss: 0.0594
# Test Accuracy for current combination: 0.7150
#
# Testing combination 9: threshold=0.1200, random_state=10, layers=2, hidden_channels=280, finetune_lr=0.005, pretrain_lr=0.001, gamma=3.6000, alpha=0.3000, aug_method=edge_perturb, aug_ratio=0.1400, pretrain_epochs=10, temperature=0.2700, model_type=GAT, dropout_rate=0.0000
# ========== 开始预训练阶段 ==========
# Pretrain Epoch: 0, Contrast Loss: 5.5924
# Pretrain Epoch: 1, Contrast Loss: 4.8566
# Pretrain Epoch: 2, Contrast Loss: 4.2690
# Pretrain Epoch: 3, Contrast Loss: 3.8332
# Pretrain Epoch: 4, Contrast Loss: 3.6027
# Pretrain Epoch: 5, Contrast Loss: 3.6028
# Pretrain Epoch: 6, Contrast Loss: 3.5679
# Pretrain Epoch: 7, Contrast Loss: 3.5237
# Pretrain Epoch: 8, Contrast Loss: 3.4991
# Pretrain Epoch: 9, Contrast Loss: 3.4593
# ========== 开始微调阶段 ==========
# Fine-tune Epoch: 0, Focal Loss: 0.0372
# Fine-tune Epoch: 1, Focal Loss: 0.0179
# Fine-tune Epoch: 2, Focal Loss: 0.0164
# Fine-tune Epoch: 3, Focal Loss: 0.0151
# Fine-tune Epoch: 4, Focal Loss: 0.0142
# Fine-tune Epoch: 5, Focal Loss: 0.0134
# Fine-tune Epoch: 6, Focal Loss: 0.0124
# Fine-tune Epoch: 7, Focal Loss: 0.0119
# Fine-tune Epoch: 8, Focal Loss: 0.0109
# Fine-tune Epoch: 9, Focal Loss: 0.0100
# Test Accuracy for current combination: 0.7450
#
# Testing combination 10: threshold=0.2600, random_state=0, layers=3, hidden_channels=240, finetune_lr=0.01, pretrain_lr=0.001, gamma=3.0000, alpha=0.3000, aug_method=edge_drop, aug_ratio=0.0500, pretrain_epochs=10, temperature=0.1600, model_type=GAT, dropout_rate=0.1000
# ========== 开始预训练阶段 ==========
# Pretrain Epoch: 0, Contrast Loss: 5.3430
# Pretrain Epoch: 1, Contrast Loss: 4.6395
# Pretrain Epoch: 2, Contrast Loss: 4.2591
# Pretrain Epoch: 3, Contrast Loss: 4.0218
# Pretrain Epoch: 4, Contrast Loss: 3.7979
# Pretrain Epoch: 5, Contrast Loss: 3.6785
# Pretrain Epoch: 6, Contrast Loss: 3.5786
# Pretrain Epoch: 7, Contrast Loss: 3.5578
# Pretrain Epoch: 8, Contrast Loss: 3.4541
# Pretrain Epoch: 9, Contrast Loss: 3.3865
# ========== 开始微调阶段 ==========
# Fine-tune Epoch: 0, Focal Loss: 0.0993
# Fine-tune Epoch: 1, Focal Loss: 0.1113
# Fine-tune Epoch: 2, Focal Loss: 0.0314
# Fine-tune Epoch: 3, Focal Loss: 0.0276
# Fine-tune Epoch: 4, Focal Loss: 0.0281
# Fine-tune Epoch: 5, Focal Loss: 0.0250
# Fine-tune Epoch: 6, Focal Loss: 0.0241
# Fine-tune Epoch: 7, Focal Loss: 0.0221
# Fine-tune Epoch: 8, Focal Loss: 0.0219
# Fine-tune Epoch: 9, Focal Loss: 0.0202
# Test Accuracy for current combination: 0.7450
#
# Testing combination 11: threshold=0.1200, random_state=20, layers=3, hidden_channels=200, finetune_lr=0.005, pretrain_lr=0.001, gamma=2.7000, alpha=0.5000, aug_method=node_drop, aug_ratio=0.0800, pretrain_epochs=10, temperature=0.0600, model_type=GraphSAGE, dropout_rate=0.1000
# ========== 开始预训练阶段 ==========
# Pretrain Epoch: 0, Contrast Loss: 4.6719
# Pretrain Epoch: 1, Contrast Loss: 3.3964
# Pretrain Epoch: 2, Contrast Loss: 3.1942
# Pretrain Epoch: 3, Contrast Loss: 2.9223
# Pretrain Epoch: 4, Contrast Loss: 2.7482
# Pretrain Epoch: 5, Contrast Loss: 2.5607
# Pretrain Epoch: 6, Contrast Loss: 2.5110
# Pretrain Epoch: 7, Contrast Loss: 2.2171
# Pretrain Epoch: 8, Contrast Loss: 2.2740
# Pretrain Epoch: 9, Contrast Loss: 2.0154
# ========== 开始微调阶段 ==========
# Fine-tune Epoch: 0, Focal Loss: 0.1685
# Fine-tune Epoch: 1, Focal Loss: 0.0472
# Fine-tune Epoch: 2, Focal Loss: 0.0488
# Fine-tune Epoch: 3, Focal Loss: 0.0404
# Fine-tune Epoch: 4, Focal Loss: 0.0377
# Fine-tune Epoch: 5, Focal Loss: 0.0344
# Fine-tune Epoch: 6, Focal Loss: 0.0338
# Fine-tune Epoch: 7, Focal Loss: 0.0323
# Fine-tune Epoch: 8, Focal Loss: 0.0316
# Fine-tune Epoch: 9, Focal Loss: 0.0315
# Test Accuracy for current combination: 0.7500
#
# Testing combination 12: threshold=0.2100, random_state=10, layers=2, hidden_channels=60, finetune_lr=0.01, pretrain_lr=1e-06, gamma=2.0000, alpha=0.5000, aug_method=edge_drop, aug_ratio=0.1600, pretrain_epochs=10, temperature=0.0900, model_type=GAT, dropout_rate=0.0000
# ========== 开始预训练阶段 ==========
# Pretrain Epoch: 0, Contrast Loss: 3.4880
# Pretrain Epoch: 1, Contrast Loss: 3.4709
# Pretrain Epoch: 2, Contrast Loss: 3.5113
# Pretrain Epoch: 3, Contrast Loss: 3.4763
# Pretrain Epoch: 4, Contrast Loss: 3.5124
# Pretrain Epoch: 5, Contrast Loss: 3.4892
# Pretrain Epoch: 6, Contrast Loss: 3.4805
# Pretrain Epoch: 7, Contrast Loss: 3.5059
# Pretrain Epoch: 8, Contrast Loss: 3.4723
# Pretrain Epoch: 9, Contrast Loss: 3.4797
# ========== 开始微调阶段 ==========
# Fine-tune Epoch: 0, Focal Loss: 0.0834
# Fine-tune Epoch: 1, Focal Loss: 0.0614
# Fine-tune Epoch: 2, Focal Loss: 0.0510
# Fine-tune Epoch: 3, Focal Loss: 0.0486
# Fine-tune Epoch: 4, Focal Loss: 0.0436
# Fine-tune Epoch: 5, Focal Loss: 0.0415
# Fine-tune Epoch: 6, Focal Loss: 0.0377
# Fine-tune Epoch: 7, Focal Loss: 0.0355
# Fine-tune Epoch: 8, Focal Loss: 0.0328
# Fine-tune Epoch: 9, Focal Loss: 0.0318
# Test Accuracy for current combination: 0.7500
#
# Testing combination 13: threshold=0.1700, random_state=20, layers=2, hidden_channels=200, finetune_lr=0.01, pretrain_lr=0.001, gamma=2.5000, alpha=0.5000, aug_method=edge_drop, aug_ratio=0.1500, pretrain_epochs=10, temperature=0.2000, model_type=GAT, dropout_rate=0.3000
# ========== 开始预训练阶段 ==========
# Pretrain Epoch: 0, Contrast Loss: 5.7990
# Pretrain Epoch: 1, Contrast Loss: 5.5137
# Pretrain Epoch: 2, Contrast Loss: 5.3889
# Pretrain Epoch: 3, Contrast Loss: 5.2457
# Pretrain Epoch: 4, Contrast Loss: 5.2045
# Pretrain Epoch: 5, Contrast Loss: 5.0962
# Pretrain Epoch: 6, Contrast Loss: 4.9872
# Pretrain Epoch: 7, Contrast Loss: 4.9413
# Pretrain Epoch: 8, Contrast Loss: 4.8999
# Pretrain Epoch: 9, Contrast Loss: 4.8308
# ========== 开始微调阶段 ==========
# Fine-tune Epoch: 0, Focal Loss: 0.0551
# Fine-tune Epoch: 1, Focal Loss: 0.1087
# Fine-tune Epoch: 2, Focal Loss: 0.0817
# Fine-tune Epoch: 3, Focal Loss: 0.0375
# Fine-tune Epoch: 4, Focal Loss: 0.0375
# Fine-tune Epoch: 5, Focal Loss: 0.0378
# Fine-tune Epoch: 6, Focal Loss: 0.0348
# Fine-tune Epoch: 7, Focal Loss: 0.0340
# Fine-tune Epoch: 8, Focal Loss: 0.0328
# Fine-tune Epoch: 9, Focal Loss: 0.0296
# Test Accuracy for current combination: 0.7350
#
# Testing combination 14: threshold=0.2000, random_state=20, layers=2, hidden_channels=140, finetune_lr=0.005, pretrain_lr=0.001, gamma=2.0000, alpha=0.4000, aug_method=edge_perturb, aug_ratio=0.2500, pretrain_epochs=10, temperature=0.2200, model_type=GAT, dropout_rate=0.1000
# ========== 开始预训练阶段 ==========
# Pretrain Epoch: 0, Contrast Loss: 5.8874
# Pretrain Epoch: 1, Contrast Loss: 5.5153
# Pretrain Epoch: 2, Contrast Loss: 5.2362
# Pretrain Epoch: 3, Contrast Loss: 5.0123
# Pretrain Epoch: 4, Contrast Loss: 4.8575
# Pretrain Epoch: 5, Contrast Loss: 4.6564
# Pretrain Epoch: 6, Contrast Loss: 4.5491
# Pretrain Epoch: 7, Contrast Loss: 4.4166
# Pretrain Epoch: 8, Contrast Loss: 4.3475
# Pretrain Epoch: 9, Contrast Loss: 4.3128
# ========== 开始微调阶段 ==========
# Fine-tune Epoch: 0, Focal Loss: 0.0991
# Fine-tune Epoch: 1, Focal Loss: 0.0642
# Fine-tune Epoch: 2, Focal Loss: 0.0537
# Fine-tune Epoch: 3, Focal Loss: 0.0505
# Fine-tune Epoch: 4, Focal Loss: 0.0474
# Fine-tune Epoch: 5, Focal Loss: 0.0435
# Fine-tune Epoch: 6, Focal Loss: 0.0420
# Fine-tune Epoch: 7, Focal Loss: 0.0406
# Fine-tune Epoch: 8, Focal Loss: 0.0372
# Fine-tune Epoch: 9, Focal Loss: 0.0359
# Test Accuracy for current combination: 0.7550
#
# Testing combination 15: threshold=0.2600, random_state=20, layers=2, hidden_channels=20, finetune_lr=0.01, pretrain_lr=0.0001, gamma=4.0000, alpha=0.3000, aug_method=node_drop, aug_ratio=0.1000, pretrain_epochs=10, temperature=0.3000, model_type=GAT, dropout_rate=0.0000
# ========== 开始预训练阶段 ==========
# Pretrain Epoch: 0, Contrast Loss: 5.7984
# Pretrain Epoch: 1, Contrast Loss: 5.7647
# Pretrain Epoch: 2, Contrast Loss: 5.7994
# Pretrain Epoch: 3, Contrast Loss: 5.7444
# Pretrain Epoch: 4, Contrast Loss: 5.7535
# Pretrain Epoch: 5, Contrast Loss: 5.7471
# Pretrain Epoch: 6, Contrast Loss: 5.7771
# Pretrain Epoch: 7, Contrast Loss: 5.7344
# Pretrain Epoch: 8, Contrast Loss: 5.7535
# Pretrain Epoch: 9, Contrast Loss: 5.7055
# ========== 开始微调阶段 ==========
# Fine-tune Epoch: 0, Focal Loss: 0.0228
# Fine-tune Epoch: 1, Focal Loss: 0.0155
# Fine-tune Epoch: 2, Focal Loss: 0.0136
# Fine-tune Epoch: 3, Focal Loss: 0.0129
# Fine-tune Epoch: 4, Focal Loss: 0.0124
# Fine-tune Epoch: 5, Focal Loss: 0.0119
# Fine-tune Epoch: 6, Focal Loss: 0.0116
# Fine-tune Epoch: 7, Focal Loss: 0.0113
# Fine-tune Epoch: 8, Focal Loss: 0.0109
# Fine-tune Epoch: 9, Focal Loss: 0.0107
# Test Accuracy for current combination: 0.7000
#
# Testing combination 16: threshold=0.1700, random_state=0, layers=4, hidden_channels=220, finetune_lr=0.01, pretrain_lr=0.0001, gamma=3.3000, alpha=0.3000, aug_method=feature, aug_ratio=0.1400, pretrain_epochs=10, temperature=0.1000, model_type=GAT, dropout_rate=0.2000
# ========== 开始预训练阶段 ==========
# Pretrain Epoch: 0, Contrast Loss: 6.3852
# Pretrain Epoch: 1, Contrast Loss: 6.2882
# Pretrain Epoch: 2, Contrast Loss: 6.1723
# Pretrain Epoch: 3, Contrast Loss: 6.0655
# Pretrain Epoch: 4, Contrast Loss: 5.9284
# Pretrain Epoch: 5, Contrast Loss: 5.7770
# Pretrain Epoch: 6, Contrast Loss: 5.6866
# Pretrain Epoch: 7, Contrast Loss: 5.5191
# Pretrain Epoch: 8, Contrast Loss: 5.4917
# Pretrain Epoch: 9, Contrast Loss: 5.4378
# ========== 开始微调阶段 ==========
# Fine-tune Epoch: 0, Focal Loss: 0.1928
# Fine-tune Epoch: 1, Focal Loss: 0.1944
# Fine-tune Epoch: 2, Focal Loss: 0.0245
# Fine-tune Epoch: 3, Focal Loss: 0.0233
# Fine-tune Epoch: 4, Focal Loss: 0.0218
# Fine-tune Epoch: 5, Focal Loss: 0.0199
# Fine-tune Epoch: 6, Focal Loss: 0.0206
# Fine-tune Epoch: 7, Focal Loss: 0.0215
# Fine-tune Epoch: 8, Focal Loss: 0.0197
# Fine-tune Epoch: 9, Focal Loss: 0.0191
# Test Accuracy for current combination: 0.7300
#
# Testing combination 17: threshold=0.2900, random_state=30, layers=3, hidden_channels=100, finetune_lr=0.01, pretrain_lr=1e-06, gamma=3.6000, alpha=0.4000, aug_method=edge_perturb, aug_ratio=0.1000, pretrain_epochs=10, temperature=0.1200, model_type=GraphSAGE, dropout_rate=0.0000
# ========== 开始预训练阶段 ==========
# Pretrain Epoch: 0, Contrast Loss: 4.9709
# Pretrain Epoch: 1, Contrast Loss: 4.9313
# Pretrain Epoch: 2, Contrast Loss: 4.9424
# Pretrain Epoch: 3, Contrast Loss: 4.9425
# Pretrain Epoch: 4, Contrast Loss: 4.9496
# Pretrain Epoch: 5, Contrast Loss: 4.9515
# Pretrain Epoch: 6, Contrast Loss: 4.9274
# Pretrain Epoch: 7, Contrast Loss: 4.8565
# Pretrain Epoch: 8, Contrast Loss: 4.9713
# Pretrain Epoch: 9, Contrast Loss: 4.9430
# ========== 开始微调阶段 ==========
# Fine-tune Epoch: 0, Focal Loss: 0.0920
# Fine-tune Epoch: 1, Focal Loss: 0.0273
# Fine-tune Epoch: 2, Focal Loss: 0.0267
# Fine-tune Epoch: 3, Focal Loss: 0.0189
# Fine-tune Epoch: 4, Focal Loss: 0.0187
# Fine-tune Epoch: 5, Focal Loss: 0.0163
# Fine-tune Epoch: 6, Focal Loss: 0.0164
# Fine-tune Epoch: 7, Focal Loss: 0.0151
# Fine-tune Epoch: 8, Focal Loss: 0.0150
# Fine-tune Epoch: 9, Focal Loss: 0.0141
# Test Accuracy for current combination: 0.7250
#
# Testing combination 18: threshold=0.1300, random_state=30, layers=2, hidden_channels=240, finetune_lr=0.01, pretrain_lr=0.001, gamma=2.0000, alpha=0.3000, aug_method=edge_drop, aug_ratio=0.0600, pretrain_epochs=10, temperature=0.2900, model_type=GAT, dropout_rate=0.0000
# ========== 开始预训练阶段 ==========
# Pretrain Epoch: 0, Contrast Loss: 5.4383
# Pretrain Epoch: 1, Contrast Loss: 4.8329
# Pretrain Epoch: 2, Contrast Loss: 4.3701
# Pretrain Epoch: 3, Contrast Loss: 3.9643
# Pretrain Epoch: 4, Contrast Loss: 3.6685
# Pretrain Epoch: 5, Contrast Loss: 3.5582
# Pretrain Epoch: 6, Contrast Loss: 3.7171
# Pretrain Epoch: 7, Contrast Loss: 3.8546
# Pretrain Epoch: 8, Contrast Loss: 3.8997
# Pretrain Epoch: 9, Contrast Loss: 3.8866
# ========== 开始微调阶段 ==========
# Fine-tune Epoch: 0, Focal Loss: 0.0982
# Fine-tune Epoch: 1, Focal Loss: 0.0662
# Fine-tune Epoch: 2, Focal Loss: 0.0461
# Fine-tune Epoch: 3, Focal Loss: 0.0418
# Fine-tune Epoch: 4, Focal Loss: 0.0377
# Fine-tune Epoch: 5, Focal Loss: 0.0356
# Fine-tune Epoch: 6, Focal Loss: 0.0361
# Fine-tune Epoch: 7, Focal Loss: 0.0304
# Fine-tune Epoch: 8, Focal Loss: 0.0250
# Fine-tune Epoch: 9, Focal Loss: 0.0224
# Test Accuracy for current combination: 0.7350
#
# Testing combination 19: threshold=0.2600, random_state=10, layers=4, hidden_channels=280, finetune_lr=0.005, pretrain_lr=0.001, gamma=2.2000, alpha=0.3000, aug_method=feature, aug_ratio=0.2500, pretrain_epochs=10, temperature=0.0500, model_type=GAT, dropout_rate=0.1000
# ========== 开始预训练阶段 ==========
# Pretrain Epoch: 0, Contrast Loss: 5.3220
# Pretrain Epoch: 1, Contrast Loss: 4.0319
# Pretrain Epoch: 2, Contrast Loss: 3.4013
# Pretrain Epoch: 3, Contrast Loss: 3.1630
# Pretrain Epoch: 4, Contrast Loss: 2.8050
# Pretrain Epoch: 5, Contrast Loss: 2.6497
# Pretrain Epoch: 6, Contrast Loss: 2.5129
# Pretrain Epoch: 7, Contrast Loss: 2.3762
# Pretrain Epoch: 8, Contrast Loss: 2.2262
# Pretrain Epoch: 9, Contrast Loss: 2.2538
# ========== 开始微调阶段 ==========
# Fine-tune Epoch: 0, Focal Loss: 0.1520
# Fine-tune Epoch: 1, Focal Loss: 0.0655
# Fine-tune Epoch: 2, Focal Loss: 0.0596
# Fine-tune Epoch: 3, Focal Loss: 0.0510
# Fine-tune Epoch: 4, Focal Loss: 0.0427
# Fine-tune Epoch: 5, Focal Loss: 0.0410
# Fine-tune Epoch: 6, Focal Loss: 0.0406
# Fine-tune Epoch: 7, Focal Loss: 0.0378
# Fine-tune Epoch: 8, Focal Loss: 0.0367
# Fine-tune Epoch: 9, Focal Loss: 0.0344
# Test Accuracy for current combination: 0.7150
#
# Testing combination 20: threshold=0.2200, random_state=10, layers=4, hidden_channels=200, finetune_lr=0.005, pretrain_lr=1e-06, gamma=3.8000, alpha=0.5000, aug_method=edge_perturb, aug_ratio=0.0500, pretrain_epochs=10, temperature=0.0900, model_type=GraphSAGE, dropout_rate=0.0000
# ========== 开始预训练阶段 ==========
# Pretrain Epoch: 0, Contrast Loss: 5.2186
# Pretrain Epoch: 1, Contrast Loss: 5.1963
# Pretrain Epoch: 2, Contrast Loss: 5.1964
# Pretrain Epoch: 3, Contrast Loss: 5.1392
# Pretrain Epoch: 4, Contrast Loss: 5.1596
# Pretrain Epoch: 5, Contrast Loss: 5.1842
# Pretrain Epoch: 6, Contrast Loss: 5.1621
# Pretrain Epoch: 7, Contrast Loss: 5.1282
# Pretrain Epoch: 8, Contrast Loss: 5.1780
# Pretrain Epoch: 9, Contrast Loss: 5.1466
# ========== 开始微调阶段 ==========
# Fine-tune Epoch: 0, Focal Loss: 0.1585
# Fine-tune Epoch: 1, Focal Loss: 0.0451
# Fine-tune Epoch: 2, Focal Loss: 0.0248
# Fine-tune Epoch: 3, Focal Loss: 0.0199
# Fine-tune Epoch: 4, Focal Loss: 0.0158
# Fine-tune Epoch: 5, Focal Loss: 0.0156
# Fine-tune Epoch: 6, Focal Loss: 0.0150
# Fine-tune Epoch: 7, Focal Loss: 0.0143
# Fine-tune Epoch: 8, Focal Loss: 0.0140
# Fine-tune Epoch: 9, Focal Loss: 0.0134
# Test Accuracy for current combination: 0.7600
#
# Testing combination 21: threshold=0.1000, random_state=30, layers=3, hidden_channels=200, finetune_lr=0.01, pretrain_lr=0.001, gamma=2.6000, alpha=0.5000, aug_method=edge_perturb, aug_ratio=0.1800, pretrain_epochs=10, temperature=0.0800, model_type=GAT, dropout_rate=0.0000
# ========== 开始预训练阶段 ==========
# Pretrain Epoch: 0, Contrast Loss: 5.2485
# Pretrain Epoch: 1, Contrast Loss: 3.1440
# Pretrain Epoch: 2, Contrast Loss: 1.9524
# Pretrain Epoch: 3, Contrast Loss: 1.1619
# Pretrain Epoch: 4, Contrast Loss: 0.8963
# Pretrain Epoch: 5, Contrast Loss: 0.8034
# Pretrain Epoch: 6, Contrast Loss: 0.7085
# Pretrain Epoch: 7, Contrast Loss: 0.7178
# Pretrain Epoch: 8, Contrast Loss: 0.6524
# Pretrain Epoch: 9, Contrast Loss: 0.5982
# ========== 开始微调阶段 ==========
# Fine-tune Epoch: 0, Focal Loss: 0.0833
# Fine-tune Epoch: 1, Focal Loss: 0.2981
# Fine-tune Epoch: 2, Focal Loss: 0.0479
# Fine-tune Epoch: 3, Focal Loss: 0.0501
# Fine-tune Epoch: 4, Focal Loss: 0.0375
# Fine-tune Epoch: 5, Focal Loss: 0.0364
# Fine-tune Epoch: 6, Focal Loss: 0.0330
# Fine-tune Epoch: 7, Focal Loss: 0.0346
# Fine-tune Epoch: 8, Focal Loss: 0.0323
# Fine-tune Epoch: 9, Focal Loss: 0.0309
# Test Accuracy for current combination: 0.7550
#
# Testing combination 22: threshold=0.2000, random_state=0, layers=4, hidden_channels=180, finetune_lr=0.005, pretrain_lr=0.001, gamma=2.4000, alpha=0.5000, aug_method=node_drop, aug_ratio=0.0500, pretrain_epochs=10, temperature=0.2700, model_type=GAT, dropout_rate=0.0000
# ========== 开始预训练阶段 ==========
# Pretrain Epoch: 0, Contrast Loss: 5.7508
# Pretrain Epoch: 1, Contrast Loss: 5.0916
# Pretrain Epoch: 2, Contrast Loss: 4.7225
# Pretrain Epoch: 3, Contrast Loss: 4.4358
# Pretrain Epoch: 4, Contrast Loss: 4.2572
# Pretrain Epoch: 5, Contrast Loss: 4.3798
# Pretrain Epoch: 6, Contrast Loss: 4.1854
# Pretrain Epoch: 7, Contrast Loss: 4.1864
# Pretrain Epoch: 8, Contrast Loss: 4.1931
# Pretrain Epoch: 9, Contrast Loss: 4.1649
# ========== 开始微调阶段 ==========
# Fine-tune Epoch: 0, Focal Loss: 0.0680
# Fine-tune Epoch: 1, Focal Loss: 0.0580
# Fine-tune Epoch: 2, Focal Loss: 0.0458
# Fine-tune Epoch: 3, Focal Loss: 0.0441
# Fine-tune Epoch: 4, Focal Loss: 0.0365
# Fine-tune Epoch: 5, Focal Loss: 0.0381
# Fine-tune Epoch: 6, Focal Loss: 0.0345
# Fine-tune Epoch: 7, Focal Loss: 0.0330
# Fine-tune Epoch: 8, Focal Loss: 0.0322
# Fine-tune Epoch: 9, Focal Loss: 0.0308
# Test Accuracy for current combination: 0.7550
#
# Testing combination 23: threshold=0.1900, random_state=20, layers=3, hidden_channels=120, finetune_lr=0.01, pretrain_lr=0.0001, gamma=2.7000, alpha=0.4000, aug_method=node_drop, aug_ratio=0.0800, pretrain_epochs=10, temperature=0.0800, model_type=GraphSAGE, dropout_rate=0.0000
# ========== 开始预训练阶段 ==========
# Pretrain Epoch: 0, Contrast Loss: 4.3938
# Pretrain Epoch: 1, Contrast Loss: 3.9714
# Pretrain Epoch: 2, Contrast Loss: 3.7381
# Pretrain Epoch: 3, Contrast Loss: 3.6643
# Pretrain Epoch: 4, Contrast Loss: 3.3144
# Pretrain Epoch: 5, Contrast Loss: 3.3148
# Pretrain Epoch: 6, Contrast Loss: 2.9286
# Pretrain Epoch: 7, Contrast Loss: 2.7409
# Pretrain Epoch: 8, Contrast Loss: 2.5910
# Pretrain Epoch: 9, Contrast Loss: 2.4429
# ========== 开始微调阶段 ==========
# Fine-tune Epoch: 0, Focal Loss: 0.1824
# Fine-tune Epoch: 1, Focal Loss: 0.0442
# Fine-tune Epoch: 2, Focal Loss: 0.0586
# Fine-tune Epoch: 3, Focal Loss: 0.0555
# Fine-tune Epoch: 4, Focal Loss: 0.0491
# Fine-tune Epoch: 5, Focal Loss: 0.0372
# Fine-tune Epoch: 6, Focal Loss: 0.0346
# Fine-tune Epoch: 7, Focal Loss: 0.0321
# Fine-tune Epoch: 8, Focal Loss: 0.0316
# Fine-tune Epoch: 9, Focal Loss: 0.0290
# Test Accuracy for current combination: 0.7200
#
# Testing combination 24: threshold=0.2100, random_state=20, layers=3, hidden_channels=220, finetune_lr=0.005, pretrain_lr=0.001, gamma=3.3000, alpha=0.5000, aug_method=edge_drop, aug_ratio=0.1200, pretrain_epochs=10, temperature=0.1800, model_type=GAT, dropout_rate=0.3000
# ========== 开始预训练阶段 ==========
# Pretrain Epoch: 0, Contrast Loss: 6.3123
# Pretrain Epoch: 1, Contrast Loss: 5.9247
# Pretrain Epoch: 2, Contrast Loss: 5.7250
# Pretrain Epoch: 3, Contrast Loss: 5.6255
# Pretrain Epoch: 4, Contrast Loss: 5.4711
# Pretrain Epoch: 5, Contrast Loss: 5.3968
# Pretrain Epoch: 6, Contrast Loss: 5.3056
# Pretrain Epoch: 7, Contrast Loss: 5.2517
# Pretrain Epoch: 8, Contrast Loss: 5.1989
# Pretrain Epoch: 9, Contrast Loss: 5.1702
# ========== 开始微调阶段 ==========
# Fine-tune Epoch: 0, Focal Loss: 0.0437
# Fine-tune Epoch: 1, Focal Loss: 0.0348
# Fine-tune Epoch: 2, Focal Loss: 0.0306
# Fine-tune Epoch: 3, Focal Loss: 0.0244
# Fine-tune Epoch: 4, Focal Loss: 0.0237
# Fine-tune Epoch: 5, Focal Loss: 0.0217
# Fine-tune Epoch: 6, Focal Loss: 0.0233
# Fine-tune Epoch: 7, Focal Loss: 0.0199
# Fine-tune Epoch: 8, Focal Loss: 0.0213
# Fine-tune Epoch: 9, Focal Loss: 0.0198
# Test Accuracy for current combination: 0.7400
#
# Testing combination 25: threshold=0.1600, random_state=20, layers=2, hidden_channels=80, finetune_lr=0.01, pretrain_lr=0.001, gamma=4.0000, alpha=0.4000, aug_method=edge_perturb, aug_ratio=0.1500, pretrain_epochs=10, temperature=0.2900, model_type=GraphSAGE, dropout_rate=0.2000
# ========== 开始预训练阶段 ==========
# Pretrain Epoch: 0, Contrast Loss: 5.9286
# Pretrain Epoch: 1, Contrast Loss: 5.7804
# Pretrain Epoch: 2, Contrast Loss: 5.6204
# Pretrain Epoch: 3, Contrast Loss: 5.5347
# Pretrain Epoch: 4, Contrast Loss: 5.4900
# Pretrain Epoch: 5, Contrast Loss: 5.4290
# Pretrain Epoch: 6, Contrast Loss: 5.3797
# Pretrain Epoch: 7, Contrast Loss: 5.3305
# Pretrain Epoch: 8, Contrast Loss: 5.3174
# Pretrain Epoch: 9, Contrast Loss: 5.2642
# ========== 开始微调阶段 ==========
# Fine-tune Epoch: 0, Focal Loss: 0.0405
# Fine-tune Epoch: 1, Focal Loss: 0.0180
# Fine-tune Epoch: 2, Focal Loss: 0.0229
# Fine-tune Epoch: 3, Focal Loss: 0.0197
# Fine-tune Epoch: 4, Focal Loss: 0.0164
# Fine-tune Epoch: 5, Focal Loss: 0.0157
# Fine-tune Epoch: 6, Focal Loss: 0.0149
# Fine-tune Epoch: 7, Focal Loss: 0.0141
# Fine-tune Epoch: 8, Focal Loss: 0.0135
# Fine-tune Epoch: 9, Focal Loss: 0.0129
# Test Accuracy for current combination: 0.7400
#
# Testing combination 26: threshold=0.2500, random_state=0, layers=3, hidden_channels=140, finetune_lr=0.005, pretrain_lr=0.001, gamma=2.9000, alpha=0.5000, aug_method=edge_perturb, aug_ratio=0.0900, pretrain_epochs=10, temperature=0.2100, model_type=GAT, dropout_rate=0.2000
# ========== 开始预训练阶段 ==========
# Pretrain Epoch: 0, Contrast Loss: 6.3844
# Pretrain Epoch: 1, Contrast Loss: 6.1387
# Pretrain Epoch: 2, Contrast Loss: 5.9305
# Pretrain Epoch: 3, Contrast Loss: 5.8031
# Pretrain Epoch: 4, Contrast Loss: 5.7532
# Pretrain Epoch: 5, Contrast Loss: 5.6627
# Pretrain Epoch: 6, Contrast Loss: 5.5901
# Pretrain Epoch: 7, Contrast Loss: 5.5439
# Pretrain Epoch: 8, Contrast Loss: 5.4949
# Pretrain Epoch: 9, Contrast Loss: 5.4422
# ========== 开始微调阶段 ==========
# Fine-tune Epoch: 0, Focal Loss: 0.0602
# Fine-tune Epoch: 1, Focal Loss: 0.0378
# Fine-tune Epoch: 2, Focal Loss: 0.0349
# Fine-tune Epoch: 3, Focal Loss: 0.0329
# Fine-tune Epoch: 4, Focal Loss: 0.0301
# Fine-tune Epoch: 5, Focal Loss: 0.0284
# Fine-tune Epoch: 6, Focal Loss: 0.0305
# Fine-tune Epoch: 7, Focal Loss: 0.0253
# Fine-tune Epoch: 8, Focal Loss: 0.0266
# Fine-tune Epoch: 9, Focal Loss: 0.0244
# Test Accuracy for current combination: 0.7350
#
# Testing combination 27: threshold=0.2200, random_state=0, layers=3, hidden_channels=100, finetune_lr=0.01, pretrain_lr=0.001, gamma=3.9000, alpha=0.3000, aug_method=feature, aug_ratio=0.1700, pretrain_epochs=10, temperature=0.2900, model_type=GraphSAGE, dropout_rate=0.3000
# ========== 开始预训练阶段 ==========
# Pretrain Epoch: 0, Contrast Loss: 6.4405
# Pretrain Epoch: 1, Contrast Loss: 6.3282
# Pretrain Epoch: 2, Contrast Loss: 6.2200
# Pretrain Epoch: 3, Contrast Loss: 6.1443
# Pretrain Epoch: 4, Contrast Loss: 6.0703
# Pretrain Epoch: 5, Contrast Loss: 6.0266
# Pretrain Epoch: 6, Contrast Loss: 5.9564
# Pretrain Epoch: 7, Contrast Loss: 5.9191
# Pretrain Epoch: 8, Contrast Loss: 5.8669
# Pretrain Epoch: 9, Contrast Loss: 5.8197
# ========== 开始微调阶段 ==========
# Fine-tune Epoch: 0, Focal Loss: 0.0328
# Fine-tune Epoch: 1, Focal Loss: 0.0171
# Fine-tune Epoch: 2, Focal Loss: 0.0180
# Fine-tune Epoch: 3, Focal Loss: 0.0140
# Fine-tune Epoch: 4, Focal Loss: 0.0147
# Fine-tune Epoch: 5, Focal Loss: 0.0134
# Fine-tune Epoch: 6, Focal Loss: 0.0129
# Fine-tune Epoch: 7, Focal Loss: 0.0120
# Fine-tune Epoch: 8, Focal Loss: 0.0118
# Fine-tune Epoch: 9, Focal Loss: 0.0124
# Test Accuracy for current combination: 0.7300
#
# Testing combination 28: threshold=0.2500, random_state=0, layers=4, hidden_channels=240, finetune_lr=0.01, pretrain_lr=1e-06, gamma=2.0000, alpha=0.4000, aug_method=feature, aug_ratio=0.0800, pretrain_epochs=10, temperature=0.1800, model_type=GAT, dropout_rate=0.1000
# ========== 开始预训练阶段 ==========
# Pretrain Epoch: 0, Contrast Loss: 6.1871
# Pretrain Epoch: 1, Contrast Loss: 6.1498
# Pretrain Epoch: 2, Contrast Loss: 6.1560
# Pretrain Epoch: 3, Contrast Loss: 6.1734
# Pretrain Epoch: 4, Contrast Loss: 6.1657
# Pretrain Epoch: 5, Contrast Loss: 6.1701
# Pretrain Epoch: 6, Contrast Loss: 6.1814
# Pretrain Epoch: 7, Contrast Loss: 6.1552
# Pretrain Epoch: 8, Contrast Loss: 6.1791
# Pretrain Epoch: 9, Contrast Loss: 6.1685
# ========== 开始微调阶段 ==========
# Fine-tune Epoch: 0, Focal Loss: 0.4386
# Fine-tune Epoch: 1, Focal Loss: 0.1110
# Fine-tune Epoch: 2, Focal Loss: 0.1020
# Fine-tune Epoch: 3, Focal Loss: 0.0821
# Fine-tune Epoch: 4, Focal Loss: 0.0704
# Fine-tune Epoch: 5, Focal Loss: 0.0657
# Fine-tune Epoch: 6, Focal Loss: 0.0603
# Fine-tune Epoch: 7, Focal Loss: 0.0536
# Fine-tune Epoch: 8, Focal Loss: 0.0538
# Fine-tune Epoch: 9, Focal Loss: 0.0500
# Test Accuracy for current combination: 0.7000
#
# Testing combination 29: threshold=0.2000, random_state=10, layers=3, hidden_channels=40, finetune_lr=0.01, pretrain_lr=1e-06, gamma=4.0000, alpha=0.3000, aug_method=edge_perturb, aug_ratio=0.1800, pretrain_epochs=10, temperature=0.2400, model_type=GAT, dropout_rate=0.3000
# ========== 开始预训练阶段 ==========
# Pretrain Epoch: 0, Contrast Loss: 6.8176
# Pretrain Epoch: 1, Contrast Loss: 6.7964
# Pretrain Epoch: 2, Contrast Loss: 6.7976
# Pretrain Epoch: 3, Contrast Loss: 6.7531
# Pretrain Epoch: 4, Contrast Loss: 6.7284
# Pretrain Epoch: 5, Contrast Loss: 6.7889
# Pretrain Epoch: 6, Contrast Loss: 6.7779
# Pretrain Epoch: 7, Contrast Loss: 6.7860
# Pretrain Epoch: 8, Contrast Loss: 6.7955
# Pretrain Epoch: 9, Contrast Loss: 6.8122
# ========== 开始微调阶段 ==========
# Fine-tune Epoch: 0, Focal Loss: 0.0474
# Fine-tune Epoch: 1, Focal Loss: 0.0229
# Fine-tune Epoch: 2, Focal Loss: 0.0198
# Fine-tune Epoch: 3, Focal Loss: 0.0150
# Fine-tune Epoch: 4, Focal Loss: 0.0129
# Fine-tune Epoch: 5, Focal Loss: 0.0146
# Fine-tune Epoch: 6, Focal Loss: 0.0123
# Fine-tune Epoch: 7, Focal Loss: 0.0133
# Fine-tune Epoch: 8, Focal Loss: 0.0129
# Fine-tune Epoch: 9, Focal Loss: 0.0136
# Test Accuracy for current combination: 0.7000
#
# Testing combination 30: threshold=0.2400, random_state=20, layers=4, hidden_channels=100, finetune_lr=0.01, pretrain_lr=1e-06, gamma=2.9000, alpha=0.4000, aug_method=edge_perturb, aug_ratio=0.2000, pretrain_epochs=10, temperature=0.1000, model_type=GAT, dropout_rate=0.0000
# ========== 开始预训练阶段 ==========
# Pretrain Epoch: 0, Contrast Loss: 6.2963
# Pretrain Epoch: 1, Contrast Loss: 6.2974
# Pretrain Epoch: 2, Contrast Loss: 6.3131
# Pretrain Epoch: 3, Contrast Loss: 6.3116
# Pretrain Epoch: 4, Contrast Loss: 6.3174
# Pretrain Epoch: 5, Contrast Loss: 6.3152
# Pretrain Epoch: 6, Contrast Loss: 6.3087
# Pretrain Epoch: 7, Contrast Loss: 6.3169
# Pretrain Epoch: 8, Contrast Loss: 6.3049
# Pretrain Epoch: 9, Contrast Loss: 6.3011
# ========== 开始微调阶段 ==========
# Fine-tune Epoch: 0, Focal Loss: 0.0600
# Fine-tune Epoch: 1, Focal Loss: 0.0387
# Fine-tune Epoch: 2, Focal Loss: 0.0292
# Fine-tune Epoch: 3, Focal Loss: 0.0287
# Fine-tune Epoch: 4, Focal Loss: 0.0258
# Fine-tune Epoch: 5, Focal Loss: 0.0259
# Fine-tune Epoch: 6, Focal Loss: 0.0247
# Fine-tune Epoch: 7, Focal Loss: 0.0236
# Fine-tune Epoch: 8, Focal Loss: 0.0228
# Fine-tune Epoch: 9, Focal Loss: 0.0216
# Test Accuracy for current combination: 0.7250
#
# Testing combination 31: threshold=0.1200, random_state=10, layers=4, hidden_channels=100, finetune_lr=0.01, pretrain_lr=0.0001, gamma=3.4000, alpha=0.5000, aug_method=edge_perturb, aug_ratio=0.0700, pretrain_epochs=10, temperature=0.1300, model_type=GAT, dropout_rate=0.3000
# ========== 开始预训练阶段 ==========
# Pretrain Epoch: 0, Contrast Loss: 7.0676
# Pretrain Epoch: 1, Contrast Loss: 7.0668
# Pretrain Epoch: 2, Contrast Loss: 7.0225
# Pretrain Epoch: 3, Contrast Loss: 7.0214
# Pretrain Epoch: 4, Contrast Loss: 6.9910
# Pretrain Epoch: 5, Contrast Loss: 7.0218
# Pretrain Epoch: 6, Contrast Loss: 6.9010
# Pretrain Epoch: 7, Contrast Loss: 6.9383
# Pretrain Epoch: 8, Contrast Loss: 6.9458
# Pretrain Epoch: 9, Contrast Loss: 6.9428
# ========== 开始微调阶段 ==========
# Fine-tune Epoch: 0, Focal Loss: 0.0445
# Fine-tune Epoch: 1, Focal Loss: 0.0314
# Fine-tune Epoch: 2, Focal Loss: 0.0305
# Fine-tune Epoch: 3, Focal Loss: 0.0284
# Fine-tune Epoch: 4, Focal Loss: 0.0257
# Fine-tune Epoch: 5, Focal Loss: 0.0239
# Fine-tune Epoch: 6, Focal Loss: 0.0229
# Fine-tune Epoch: 7, Focal Loss: 0.0234
# Fine-tune Epoch: 8, Focal Loss: 0.0221
# Fine-tune Epoch: 9, Focal Loss: 0.0212
# Test Accuracy for current combination: 0.7600
#
# Testing combination 32: threshold=0.1900, random_state=30, layers=2, hidden_channels=200, finetune_lr=0.005, pretrain_lr=0.001, gamma=2.9000, alpha=0.5000, aug_method=node_drop, aug_ratio=0.1700, pretrain_epochs=10, temperature=0.0800, model_type=GAT, dropout_rate=0.2000
# ========== 开始预训练阶段 ==========
# Pretrain Epoch: 0, Contrast Loss: 5.3472
# Pretrain Epoch: 1, Contrast Loss: 4.9580
# Pretrain Epoch: 2, Contrast Loss: 4.8183
# Pretrain Epoch: 3, Contrast Loss: 4.6778
# Pretrain Epoch: 4, Contrast Loss: 4.5227
# Pretrain Epoch: 5, Contrast Loss: 4.3241
# Pretrain Epoch: 6, Contrast Loss: 4.1613
# Pretrain Epoch: 7, Contrast Loss: 4.1610
# Pretrain Epoch: 8, Contrast Loss: 3.9468
# Pretrain Epoch: 9, Contrast Loss: 3.9960
# ========== 开始微调阶段 ==========
# Fine-tune Epoch: 0, Focal Loss: 0.0614
# Fine-tune Epoch: 1, Focal Loss: 0.0355
# Fine-tune Epoch: 2, Focal Loss: 0.0426
# Fine-tune Epoch: 3, Focal Loss: 0.0307
# Fine-tune Epoch: 4, Focal Loss: 0.0316
# Fine-tune Epoch: 5, Focal Loss: 0.0294
# Fine-tune Epoch: 6, Focal Loss: 0.0271
# Fine-tune Epoch: 7, Focal Loss: 0.0255
# Fine-tune Epoch: 8, Focal Loss: 0.0241
# Fine-tune Epoch: 9, Focal Loss: 0.0228
# Test Accuracy for current combination: 0.7450
#
# Testing combination 33: threshold=0.2200, random_state=10, layers=4, hidden_channels=180, finetune_lr=0.01, pretrain_lr=0.0001, gamma=3.8000, alpha=0.4000, aug_method=node_drop, aug_ratio=0.1600, pretrain_epochs=10, temperature=0.0800, model_type=GAT, dropout_rate=0.3000
# ========== 开始预训练阶段 ==========
# Pretrain Epoch: 0, Contrast Loss: 7.1664
# Pretrain Epoch: 1, Contrast Loss: 7.0217
# Pretrain Epoch: 2, Contrast Loss: 6.9458
# Pretrain Epoch: 3, Contrast Loss: 6.8617
# Pretrain Epoch: 4, Contrast Loss: 6.9415
# Pretrain Epoch: 5, Contrast Loss: 6.9438
# Pretrain Epoch: 6, Contrast Loss: 6.8884
# Pretrain Epoch: 7, Contrast Loss: 6.7982
# Pretrain Epoch: 8, Contrast Loss: 6.7436
# Pretrain Epoch: 9, Contrast Loss: 6.7508
# ========== 开始微调阶段 ==========
# Fine-tune Epoch: 0, Focal Loss: 0.0311
# Fine-tune Epoch: 1, Focal Loss: 0.4289
# Fine-tune Epoch: 2, Focal Loss: 0.0221
# Fine-tune Epoch: 3, Focal Loss: 0.0212
# Fine-tune Epoch: 4, Focal Loss: 0.0199
# Fine-tune Epoch: 5, Focal Loss: 0.0191
# Fine-tune Epoch: 6, Focal Loss: 0.0196
# Fine-tune Epoch: 7, Focal Loss: 0.0171
# Fine-tune Epoch: 8, Focal Loss: 0.0183
# Fine-tune Epoch: 9, Focal Loss: 0.0174
# Test Accuracy for current combination: 0.7000
#
# Testing combination 34: threshold=0.1600, random_state=30, layers=3, hidden_channels=80, finetune_lr=0.005, pretrain_lr=0.0001, gamma=2.4000, alpha=0.4000, aug_method=node_drop, aug_ratio=0.1300, pretrain_epochs=10, temperature=0.0600, model_type=GAT, dropout_rate=0.2000
# ========== 开始预训练阶段 ==========
# Pretrain Epoch: 0, Contrast Loss: 7.0234
# Pretrain Epoch: 1, Contrast Loss: 7.0739
# Pretrain Epoch: 2, Contrast Loss: 6.8338
# Pretrain Epoch: 3, Contrast Loss: 6.9219
# Pretrain Epoch: 4, Contrast Loss: 6.6195
# Pretrain Epoch: 5, Contrast Loss: 6.8440
# Pretrain Epoch: 6, Contrast Loss: 6.8591
# Pretrain Epoch: 7, Contrast Loss: 6.6433
# Pretrain Epoch: 8, Contrast Loss: 6.5562
# Pretrain Epoch: 9, Contrast Loss: 6.6683
# ========== 开始微调阶段 ==========
# Fine-tune Epoch: 0, Focal Loss: 0.0776
# Fine-tune Epoch: 1, Focal Loss: 0.0531
# Fine-tune Epoch: 2, Focal Loss: 0.0448
# Fine-tune Epoch: 3, Focal Loss: 0.0403
# Fine-tune Epoch: 4, Focal Loss: 0.0403
# Fine-tune Epoch: 5, Focal Loss: 0.0375
# Fine-tune Epoch: 6, Focal Loss: 0.0375
# Fine-tune Epoch: 7, Focal Loss: 0.0370
# Fine-tune Epoch: 8, Focal Loss: 0.0358
# Fine-tune Epoch: 9, Focal Loss: 0.0341
# Test Accuracy for current combination: 0.7550
#
# Testing combination 35: threshold=0.2200, random_state=30, layers=3, hidden_channels=280, finetune_lr=0.005, pretrain_lr=0.0001, gamma=3.5000, alpha=0.5000, aug_method=edge_perturb, aug_ratio=0.2400, pretrain_epochs=10, temperature=0.1900, model_type=GraphSAGE, dropout_rate=0.1000
# ========== 开始预训练阶段 ==========
# Pretrain Epoch: 0, Contrast Loss: 5.8250
# Pretrain Epoch: 1, Contrast Loss: 5.6106
# Pretrain Epoch: 2, Contrast Loss: 5.4711
# Pretrain Epoch: 3, Contrast Loss: 5.3209
# Pretrain Epoch: 4, Contrast Loss: 5.1995
# Pretrain Epoch: 5, Contrast Loss: 5.1375
# Pretrain Epoch: 6, Contrast Loss: 5.0223
# Pretrain Epoch: 7, Contrast Loss: 4.9412
# Pretrain Epoch: 8, Contrast Loss: 4.9085
# Pretrain Epoch: 9, Contrast Loss: 4.8405
# ========== 开始微调阶段 ==========
# Fine-tune Epoch: 0, Focal Loss: 0.3838
# Fine-tune Epoch: 1, Focal Loss: 0.0285
# Fine-tune Epoch: 2, Focal Loss: 0.0274
# Fine-tune Epoch: 3, Focal Loss: 0.0250
# Fine-tune Epoch: 4, Focal Loss: 0.0196
# Fine-tune Epoch: 5, Focal Loss: 0.0200
# Fine-tune Epoch: 6, Focal Loss: 0.0200
# Fine-tune Epoch: 7, Focal Loss: 0.0193
# Fine-tune Epoch: 8, Focal Loss: 0.0178
# Fine-tune Epoch: 9, Focal Loss: 0.0172
# Test Accuracy for current combination: 0.7500
#
# Testing combination 36: threshold=0.1500, random_state=30, layers=4, hidden_channels=60, finetune_lr=0.005, pretrain_lr=0.001, gamma=3.8000, alpha=0.3000, aug_method=edge_drop, aug_ratio=0.2000, pretrain_epochs=10, temperature=0.2300, model_type=GAT, dropout_rate=0.0000
# ========== 开始预训练阶段 ==========
# Pretrain Epoch: 0, Contrast Loss: 6.0061
# Pretrain Epoch: 1, Contrast Loss: 5.4834
# Pretrain Epoch: 2, Contrast Loss: 5.2680
# Pretrain Epoch: 3, Contrast Loss: 5.0048
# Pretrain Epoch: 4, Contrast Loss: 4.7926
# Pretrain Epoch: 5, Contrast Loss: 4.6756
# Pretrain Epoch: 6, Contrast Loss: 4.5503
# Pretrain Epoch: 7, Contrast Loss: 4.3997
# Pretrain Epoch: 8, Contrast Loss: 4.2958
# Pretrain Epoch: 9, Contrast Loss: 4.2099
# ========== 开始微调阶段 ==========
# Fine-tune Epoch: 0, Focal Loss: 0.0268
# Fine-tune Epoch: 1, Focal Loss: 0.0139
# Fine-tune Epoch: 2, Focal Loss: 0.0141
# Fine-tune Epoch: 3, Focal Loss: 0.0122
# Fine-tune Epoch: 4, Focal Loss: 0.0117
# Fine-tune Epoch: 5, Focal Loss: 0.0114
# Fine-tune Epoch: 6, Focal Loss: 0.0107
# Fine-tune Epoch: 7, Focal Loss: 0.0102
# Fine-tune Epoch: 8, Focal Loss: 0.0100
# Fine-tune Epoch: 9, Focal Loss: 0.0095
# Test Accuracy for current combination: 0.7550
#
# Testing combination 37: threshold=0.2900, random_state=30, layers=2, hidden_channels=200, finetune_lr=0.005, pretrain_lr=1e-06, gamma=2.5000, alpha=0.4000, aug_method=edge_drop, aug_ratio=0.2000, pretrain_epochs=10, temperature=0.2100, model_type=GraphSAGE, dropout_rate=0.3000
# ========== 开始预训练阶段 ==========
# Pretrain Epoch: 0, Contrast Loss: 5.7910
# Pretrain Epoch: 1, Contrast Loss: 5.7914
# Pretrain Epoch: 2, Contrast Loss: 5.7984
# Pretrain Epoch: 3, Contrast Loss: 5.8008
# Pretrain Epoch: 4, Contrast Loss: 5.7825
# Pretrain Epoch: 5, Contrast Loss: 5.7949
# Pretrain Epoch: 6, Contrast Loss: 5.7612
# Pretrain Epoch: 7, Contrast Loss: 5.7822
# Pretrain Epoch: 8, Contrast Loss: 5.7552
# Pretrain Epoch: 9, Contrast Loss: 5.7905
# ========== 开始微调阶段 ==========
# Fine-tune Epoch: 0, Focal Loss: 0.1672
# Fine-tune Epoch: 1, Focal Loss: 0.1669
# Fine-tune Epoch: 2, Focal Loss: 0.0464
# Fine-tune Epoch: 3, Focal Loss: 0.0568
# Fine-tune Epoch: 4, Focal Loss: 0.0546
# Fine-tune Epoch: 5, Focal Loss: 0.0503
# Fine-tune Epoch: 6, Focal Loss: 0.0450
# Fine-tune Epoch: 7, Focal Loss: 0.0392
# Fine-tune Epoch: 8, Focal Loss: 0.0364
# Fine-tune Epoch: 9, Focal Loss: 0.0346
# Test Accuracy for current combination: 0.7300
#
# Testing combination 38: threshold=0.2800, random_state=10, layers=2, hidden_channels=100, finetune_lr=0.005, pretrain_lr=0.0001, gamma=2.8000, alpha=0.4000, aug_method=node_drop, aug_ratio=0.1800, pretrain_epochs=10, temperature=0.0800, model_type=GAT, dropout_rate=0.2000
# ========== 开始预训练阶段 ==========
# Pretrain Epoch: 0, Contrast Loss: 5.8030
# Pretrain Epoch: 1, Contrast Loss: 5.7551
# Pretrain Epoch: 2, Contrast Loss: 5.6252
# Pretrain Epoch: 3, Contrast Loss: 5.9013
# Pretrain Epoch: 4, Contrast Loss: 5.7824
# Pretrain Epoch: 5, Contrast Loss: 5.8384
# Pretrain Epoch: 6, Contrast Loss: 5.7351
# Pretrain Epoch: 7, Contrast Loss: 5.7218
# Pretrain Epoch: 8, Contrast Loss: 5.6844
# Pretrain Epoch: 9, Contrast Loss: 5.5498
# ========== 开始微调阶段 ==========
# Fine-tune Epoch: 0, Focal Loss: 0.0787
# Fine-tune Epoch: 1, Focal Loss: 0.0570
# Fine-tune Epoch: 2, Focal Loss: 0.0408
# Fine-tune Epoch: 3, Focal Loss: 0.0362
# Fine-tune Epoch: 4, Focal Loss: 0.0360
# Fine-tune Epoch: 5, Focal Loss: 0.0325
# Fine-tune Epoch: 6, Focal Loss: 0.0320
# Fine-tune Epoch: 7, Focal Loss: 0.0330
# Fine-tune Epoch: 8, Focal Loss: 0.0303
# Fine-tune Epoch: 9, Focal Loss: 0.0297
# Test Accuracy for current combination: 0.7500
#
# Testing combination 39: threshold=0.1700, random_state=0, layers=3, hidden_channels=100, finetune_lr=0.005, pretrain_lr=1e-06, gamma=3.5000, alpha=0.4000, aug_method=node_drop, aug_ratio=0.1400, pretrain_epochs=10, temperature=0.2900, model_type=GraphSAGE, dropout_rate=0.3000
# ========== 开始预训练阶段 ==========
# Pretrain Epoch: 0, Contrast Loss: 6.5113
# Pretrain Epoch: 1, Contrast Loss: 6.5021
# Pretrain Epoch: 2, Contrast Loss: 6.5395
# Pretrain Epoch: 3, Contrast Loss: 6.5295
# Pretrain Epoch: 4, Contrast Loss: 6.5158
# Pretrain Epoch: 5, Contrast Loss: 6.5363
# Pretrain Epoch: 6, Contrast Loss: 6.5429
# Pretrain Epoch: 7, Contrast Loss: 6.5115
# Pretrain Epoch: 8, Contrast Loss: 6.5382
# Pretrain Epoch: 9, Contrast Loss: 6.5085
# ========== 开始微调阶段 ==========
# Fine-tune Epoch: 0, Focal Loss: 0.0525
# Fine-tune Epoch: 1, Focal Loss: 0.0275
# Fine-tune Epoch: 2, Focal Loss: 0.0281
# Fine-tune Epoch: 3, Focal Loss: 0.0238
# Fine-tune Epoch: 4, Focal Loss: 0.0223
# Fine-tune Epoch: 5, Focal Loss: 0.0213
# Fine-tune Epoch: 6, Focal Loss: 0.0198
# Fine-tune Epoch: 7, Focal Loss: 0.0194
# Fine-tune Epoch: 8, Focal Loss: 0.0181
# Fine-tune Epoch: 9, Focal Loss: 0.0179
# Test Accuracy for current combination: 0.7450
#
# Testing combination 40: threshold=0.1600, random_state=20, layers=4, hidden_channels=40, finetune_lr=0.005, pretrain_lr=0.0001, gamma=3.2000, alpha=0.3000, aug_method=feature, aug_ratio=0.1400, pretrain_epochs=10, temperature=0.2300, model_type=GraphSAGE, dropout_rate=0.3000
# ========== 开始预训练阶段 ==========
# Pretrain Epoch: 0, Contrast Loss: 6.8457
# Pretrain Epoch: 1, Contrast Loss: 6.9533
# Pretrain Epoch: 2, Contrast Loss: 6.9172
# Pretrain Epoch: 3, Contrast Loss: 6.8564
# Pretrain Epoch: 4, Contrast Loss: 6.8666
# Pretrain Epoch: 5, Contrast Loss: 6.9488
# Pretrain Epoch: 6, Contrast Loss: 6.8468
# Pretrain Epoch: 7, Contrast Loss: 6.8507
# Pretrain Epoch: 8, Contrast Loss: 6.8832
# Pretrain Epoch: 9, Contrast Loss: 6.9098
# ========== 开始微调阶段 ==========
# Fine-tune Epoch: 0, Focal Loss: 0.0329
# Fine-tune Epoch: 1, Focal Loss: 0.0272
# Fine-tune Epoch: 2, Focal Loss: 0.0251
# Fine-tune Epoch: 3, Focal Loss: 0.0244
# Fine-tune Epoch: 4, Focal Loss: 0.0245
# Fine-tune Epoch: 5, Focal Loss: 0.0224
# Fine-tune Epoch: 6, Focal Loss: 0.0223
# Fine-tune Epoch: 7, Focal Loss: 0.0227
# Fine-tune Epoch: 8, Focal Loss: 0.0216
# Fine-tune Epoch: 9, Focal Loss: 0.0207
# Test Accuracy for current combination: 0.7150
#
# Testing combination 41: threshold=0.2800, random_state=20, layers=2, hidden_channels=220, finetune_lr=0.005, pretrain_lr=0.0001, gamma=2.5000, alpha=0.4000, aug_method=feature, aug_ratio=0.0600, pretrain_epochs=10, temperature=0.0500, model_type=GAT, dropout_rate=0.1000
# ========== 开始预训练阶段 ==========
# Pretrain Epoch: 0, Contrast Loss: 2.5685
# ...
# Fine-tune Epoch: 9, Focal Loss: 0.0164
# Test Accuracy for current combination: 0.7500
#
# Testing combination 388: threshold=0.1100, random_state=30, layers=3, hidden_channels=100, finetune_lr=0.005, pretrain_lr=0.0001, gamma=2.4000, alpha=0.3000, aug_method=edge_perturb, aug_ratio=0.0600, pretrain_epochs=10, temperature=0.1900, model_type=GAT, dropout_rate=0.3000
# ========== 开始预训练阶段 ==========
# Pretrain Epoch: 0, Contrast Loss: 6.4381
# Pretrain Epoch: 1, Contrast Loss: 6.4445
# Pretrain Epoch: 2, Contrast Loss: 6.3974
# Pretrain Epoch: 3, Contrast Loss: 6.4264
# Pretrain Epoch: 4, Contrast Loss: 6.3522
# Pretrain Epoch: 5, Contrast Loss: 6.3629
# Pretrain Epoch: 6, Contrast Loss: 6.3277
# Pretrain Epoch: 7, Contrast Loss: 6.2486
# Pretrain Epoch: 8, Contrast Loss: 6.2405
# Pretrain Epoch: 9, Contrast Loss: 6.2251
# ========== 开始微调阶段 ==========
# Fine-tune Epoch: 0, Focal Loss: 0.0702
# Fine-tune Epoch: 1, Focal Loss: 0.0435
# Fine-tune Epoch: 2, Focal Loss: 0.0386
# Fine-tune Epoch: 3, Focal Loss: 0.0358
# Fine-tune Epoch: 4, Focal Loss: 0.0355
# Fine-tune Epoch: 5, Focal Loss: 0.0336
# Fine-tune Epoch: 6, Focal Loss: 0.0340
# Fine-tune Epoch: 7, Focal Loss: 0.0329
# Fine-tune Epoch: 8, Focal Loss: 0.0323
# Fine-tune Epoch: 9, Focal Loss: 0.0318
# Test Accuracy for current combination: 0.7400
#
# Testing combination 389: threshold=0.1700, random_state=10, layers=2, hidden_channels=160, finetune_lr=0.01, pretrain_lr=1e-06, gamma=3.8000, alpha=0.4000, aug_method=feature, aug_ratio=0.1200, pretrain_epochs=10, temperature=0.2600, model_type=GAT, dropout_rate=0.3000
# ========== 开始预训练阶段 ==========
# Pretrain Epoch: 0, Contrast Loss: 6.0509
# Pretrain Epoch: 1, Contrast Loss: 6.0457
# Pretrain Epoch: 2, Contrast Loss: 6.0302
# Pretrain Epoch: 3, Contrast Loss: 6.0708
# Pretrain Epoch: 4, Contrast Loss: 6.0711
# Pretrain Epoch: 5, Contrast Loss: 6.0606
# Pretrain Epoch: 6, Contrast Loss: 6.0458
# Pretrain Epoch: 7, Contrast Loss: 6.0656
# Pretrain Epoch: 8, Contrast Loss: 6.0585
# Pretrain Epoch: 9, Contrast Loss: 6.0595
# ========== 开始微调阶段 ==========
# Fine-tune Epoch: 0, Focal Loss: 0.1188
# Fine-tune Epoch: 1, Focal Loss: 0.0458
# Fine-tune Epoch: 2, Focal Loss: 0.0373
# Fine-tune Epoch: 3, Focal Loss: 0.0253
# Fine-tune Epoch: 4, Focal Loss: 0.0221
# Fine-tune Epoch: 5, Focal Loss: 0.0200
# Fine-tune Epoch: 6, Focal Loss: 0.0188
# Fine-tune Epoch: 7, Focal Loss: 0.0171
# Fine-tune Epoch: 8, Focal Loss: 0.0186
# Fine-tune Epoch: 9, Focal Loss: 0.0166
# Test Accuracy for current combination: 0.7200
#
# Testing combination 390: threshold=0.2700, random_state=10, layers=4, hidden_channels=120, finetune_lr=0.01, pretrain_lr=1e-06, gamma=3.2000, alpha=0.3000, aug_method=feature, aug_ratio=0.1800, pretrain_epochs=10, temperature=0.2800, model_type=GraphSAGE, dropout_rate=0.1000
# ========== 开始预训练阶段 ==========
# Pretrain Epoch: 0, Contrast Loss: 6.0752
# Pretrain Epoch: 1, Contrast Loss: 6.1013
# Pretrain Epoch: 2, Contrast Loss: 6.0818
# Pretrain Epoch: 3, Contrast Loss: 6.0591
# Pretrain Epoch: 4, Contrast Loss: 6.0754
# Pretrain Epoch: 5, Contrast Loss: 6.0861
# Pretrain Epoch: 6, Contrast Loss: 6.0587
# Pretrain Epoch: 7, Contrast Loss: 6.0635
# Pretrain Epoch: 8, Contrast Loss: 6.0631
# Pretrain Epoch: 9, Contrast Loss: 6.0908
# ========== 开始微调阶段 ==========
# Fine-tune Epoch: 0, Focal Loss: 0.1043
# Fine-tune Epoch: 1, Focal Loss: 0.0268
# Fine-tune Epoch: 2, Focal Loss: 0.0325
# Fine-tune Epoch: 3, Focal Loss: 0.0260
# Fine-tune Epoch: 4, Focal Loss: 0.0248
# Fine-tune Epoch: 5, Focal Loss: 0.0213
# Fine-tune Epoch: 6, Focal Loss: 0.0197
# Fine-tune Epoch: 7, Focal Loss: 0.0195
# Fine-tune Epoch: 8, Focal Loss: 0.0186
# Fine-tune Epoch: 9, Focal Loss: 0.0183
# Test Accuracy for current combination: 0.7550
#
# Testing combination 391: threshold=0.1000, random_state=0, layers=3, hidden_channels=200, finetune_lr=0.01, pretrain_lr=1e-06, gamma=3.5000, alpha=0.4000, aug_method=edge_drop, aug_ratio=0.0900, pretrain_epochs=10, temperature=0.2800, model_type=GAT, dropout_rate=0.3000
# ========== 开始预训练阶段 ==========
# Pretrain Epoch: 0, Contrast Loss: 6.3994
# Pretrain Epoch: 1, Contrast Loss: 6.3884
# Pretrain Epoch: 2, Contrast Loss: 6.3790
# Pretrain Epoch: 3, Contrast Loss: 6.3781
# Pretrain Epoch: 4, Contrast Loss: 6.3977
# Pretrain Epoch: 5, Contrast Loss: 6.3698
# Pretrain Epoch: 6, Contrast Loss: 6.3828
# Pretrain Epoch: 7, Contrast Loss: 6.3978
# Pretrain Epoch: 8, Contrast Loss: 6.3964
# Pretrain Epoch: 9, Contrast Loss: 6.4124
# ========== 开始微调阶段 ==========
# Fine-tune Epoch: 0, Focal Loss: 0.0482
# Fine-tune Epoch: 1, Focal Loss: 0.6215
# Fine-tune Epoch: 2, Focal Loss: 0.0246
# Fine-tune Epoch: 3, Focal Loss: 0.0257
# Fine-tune Epoch: 4, Focal Loss: 0.0226
# Fine-tune Epoch: 5, Focal Loss: 0.0204
# Fine-tune Epoch: 6, Focal Loss: 0.0212
# Fine-tune Epoch: 7, Focal Loss: 0.0192
# Fine-tune Epoch: 8, Focal Loss: 0.0189
# Fine-tune Epoch: 9, Focal Loss: 0.0188
# Test Accuracy for current combination: 0.7350
#
# Testing combination 392: threshold=0.1100, random_state=0, layers=4, hidden_channels=240, finetune_lr=0.005, pretrain_lr=0.001, gamma=2.9000, alpha=0.5000, aug_method=node_drop, aug_ratio=0.1400, pretrain_epochs=10, temperature=0.1700, model_type=GAT, dropout_rate=0.1000
# ========== 开始预训练阶段 ==========
# Pretrain Epoch: 0, Contrast Loss: 6.2972
# Pretrain Epoch: 1, Contrast Loss: 5.6941
# Pretrain Epoch: 2, Contrast Loss: 5.4135
# Pretrain Epoch: 3, Contrast Loss: 5.3782
# Pretrain Epoch: 4, Contrast Loss: 5.1744
# Pretrain Epoch: 5, Contrast Loss: 5.0126
# Pretrain Epoch: 6, Contrast Loss: 4.8788
# Pretrain Epoch: 7, Contrast Loss: 4.8903
# Pretrain Epoch: 8, Contrast Loss: 4.8479
# Pretrain Epoch: 9, Contrast Loss: 4.8904
# ========== 开始微调阶段 ==========
# Fine-tune Epoch: 0, Focal Loss: 0.0437
# Fine-tune Epoch: 1, Focal Loss: 0.0560
# Fine-tune Epoch: 2, Focal Loss: 0.0404
# Fine-tune Epoch: 3, Focal Loss: 0.0302
# Fine-tune Epoch: 4, Focal Loss: 0.0317
# Fine-tune Epoch: 5, Focal Loss: 0.0283
# Fine-tune Epoch: 6, Focal Loss: 0.0292
# Fine-tune Epoch: 7, Focal Loss: 0.0271
# Fine-tune Epoch: 8, Focal Loss: 0.0258
# Fine-tune Epoch: 9, Focal Loss: 0.0260
# Test Accuracy for current combination: 0.7350
#
# Testing combination 393: threshold=0.1700, random_state=20, layers=2, hidden_channels=260, finetune_lr=0.01, pretrain_lr=1e-06, gamma=3.7000, alpha=0.4000, aug_method=edge_drop, aug_ratio=0.1000, pretrain_epochs=10, temperature=0.2900, model_type=GAT, dropout_rate=0.0000
# ========== 开始预训练阶段 ==========
# Pretrain Epoch: 0, Contrast Loss: 5.4125
# Pretrain Epoch: 1, Contrast Loss: 5.4121
# Pretrain Epoch: 2, Contrast Loss: 5.4099
# Pretrain Epoch: 3, Contrast Loss: 5.4105
# Pretrain Epoch: 4, Contrast Loss: 5.4080
# Pretrain Epoch: 5, Contrast Loss: 5.4086
# Pretrain Epoch: 6, Contrast Loss: 5.4082
# Pretrain Epoch: 7, Contrast Loss: 5.4082
# Pretrain Epoch: 8, Contrast Loss: 5.4068
# Pretrain Epoch: 9, Contrast Loss: 5.4042
# ========== 开始微调阶段 ==========
# Fine-tune Epoch: 0, Focal Loss: 0.2611
# Fine-tune Epoch: 1, Focal Loss: 0.1119
# Fine-tune Epoch: 2, Focal Loss: 0.0718
# Fine-tune Epoch: 3, Focal Loss: 0.0182
# Fine-tune Epoch: 4, Focal Loss: 0.0190
# Fine-tune Epoch: 5, Focal Loss: 0.0181
# Fine-tune Epoch: 6, Focal Loss: 0.0169
# Fine-tune Epoch: 7, Focal Loss: 0.0165
# Fine-tune Epoch: 8, Focal Loss: 0.0161
# Fine-tune Epoch: 9, Focal Loss: 0.0152
# Test Accuracy for current combination: 0.7400
#
# Testing combination 394: threshold=0.2700, random_state=20, layers=4, hidden_channels=160, finetune_lr=0.005, pretrain_lr=0.0001, gamma=3.6000, alpha=0.3000, aug_method=feature, aug_ratio=0.0500, pretrain_epochs=10, temperature=0.2200, model_type=GAT, dropout_rate=0.3000
# ========== 开始预训练阶段 ==========
# Pretrain Epoch: 0, Contrast Loss: 6.6019
# Pretrain Epoch: 1, Contrast Loss: 6.5819
# Pretrain Epoch: 2, Contrast Loss: 6.6006
# Pretrain Epoch: 3, Contrast Loss: 6.5754
# Pretrain Epoch: 4, Contrast Loss: 6.5566
# Pretrain Epoch: 5, Contrast Loss: 6.5441
# Pretrain Epoch: 6, Contrast Loss: 6.5075
# Pretrain Epoch: 7, Contrast Loss: 6.5174
# Pretrain Epoch: 8, Contrast Loss: 6.5035
# Pretrain Epoch: 9, Contrast Loss: 6.4391
# ========== 开始微调阶段 ==========
# Fine-tune Epoch: 0, Focal Loss: 0.0576
# Fine-tune Epoch: 1, Focal Loss: 0.0352
# Fine-tune Epoch: 2, Focal Loss: 0.0300
# Fine-tune Epoch: 3, Focal Loss: 0.0255
# Fine-tune Epoch: 4, Focal Loss: 0.0213
# Fine-tune Epoch: 5, Focal Loss: 0.0206
# Fine-tune Epoch: 6, Focal Loss: 0.0201
# Fine-tune Epoch: 7, Focal Loss: 0.0182
# Fine-tune Epoch: 8, Focal Loss: 0.0171
# Fine-tune Epoch: 9, Focal Loss: 0.0165
# Test Accuracy for current combination: 0.7000
#
# Testing combination 395: threshold=0.2900, random_state=10, layers=4, hidden_channels=140, finetune_lr=0.01, pretrain_lr=0.001, gamma=3.4000, alpha=0.4000, aug_method=edge_drop, aug_ratio=0.1300, pretrain_epochs=10, temperature=0.1800, model_type=GAT, dropout_rate=0.3000
# ========== 开始预训练阶段 ==========
# Pretrain Epoch: 0, Contrast Loss: 6.5635
# Pretrain Epoch: 1, Contrast Loss: 6.4582
# Pretrain Epoch: 2, Contrast Loss: 6.3654
# Pretrain Epoch: 3, Contrast Loss: 6.2784
# Pretrain Epoch: 4, Contrast Loss: 6.1635
# Pretrain Epoch: 5, Contrast Loss: 6.1613
# Pretrain Epoch: 6, Contrast Loss: 6.0845
# Pretrain Epoch: 7, Contrast Loss: 6.0318
# Pretrain Epoch: 8, Contrast Loss: 6.0133
# Pretrain Epoch: 9, Contrast Loss: 5.9405
# ========== 开始微调阶段 ==========
# Fine-tune Epoch: 0, Focal Loss: 0.0581
# Fine-tune Epoch: 1, Focal Loss: 0.0413
# Fine-tune Epoch: 2, Focal Loss: 0.0380
# Fine-tune Epoch: 3, Focal Loss: 0.0282
# Fine-tune Epoch: 4, Focal Loss: 0.0243
# Fine-tune Epoch: 5, Focal Loss: 0.0239
# Fine-tune Epoch: 6, Focal Loss: 0.0217
# Fine-tune Epoch: 7, Focal Loss: 0.0207
# Fine-tune Epoch: 8, Focal Loss: 0.0201
# Fine-tune Epoch: 9, Focal Loss: 0.0199
# Test Accuracy for current combination: 0.7200
#
# Testing combination 396: threshold=0.2700, random_state=30, layers=2, hidden_channels=20, finetune_lr=0.005, pretrain_lr=0.0001, gamma=2.9000, alpha=0.3000, aug_method=edge_drop, aug_ratio=0.0900, pretrain_epochs=10, temperature=0.1100, model_type=GraphSAGE, dropout_rate=0.2000
# ========== 开始预训练阶段 ==========
# Pretrain Epoch: 0, Contrast Loss: 5.8083
# Pretrain Epoch: 1, Contrast Loss: 5.9891
# Pretrain Epoch: 2, Contrast Loss: 6.0515
# Pretrain Epoch: 3, Contrast Loss: 5.8838
# Pretrain Epoch: 4, Contrast Loss: 5.7745
# Pretrain Epoch: 5, Contrast Loss: 5.8841
# Pretrain Epoch: 6, Contrast Loss: 5.8195
# Pretrain Epoch: 7, Contrast Loss: 5.9597
# Pretrain Epoch: 8, Contrast Loss: 5.9396
# Pretrain Epoch: 9, Contrast Loss: 5.9063
# ========== 开始微调阶段 ==========
# Fine-tune Epoch: 0, Focal Loss: 0.0651
# Fine-tune Epoch: 1, Focal Loss: 0.0405
# Fine-tune Epoch: 2, Focal Loss: 0.0362
# Fine-tune Epoch: 3, Focal Loss: 0.0354
# Fine-tune Epoch: 4, Focal Loss: 0.0325
# Fine-tune Epoch: 5, Focal Loss: 0.0288
# Fine-tune Epoch: 6, Focal Loss: 0.0275
# Fine-tune Epoch: 7, Focal Loss: 0.0277
# Fine-tune Epoch: 8, Focal Loss: 0.0267
# Fine-tune Epoch: 9, Focal Loss: 0.0252
# Test Accuracy for current combination: 0.7050
#
# Testing combination 397: threshold=0.2700, random_state=30, layers=4, hidden_channels=200, finetune_lr=0.005, pretrain_lr=0.0001, gamma=3.1000, alpha=0.3000, aug_method=node_drop, aug_ratio=0.2300, pretrain_epochs=10, temperature=0.1500, model_type=GAT, dropout_rate=0.1000
# ========== 开始预训练阶段 ==========
# Pretrain Epoch: 0, Contrast Loss: 6.3646
# Pretrain Epoch: 1, Contrast Loss: 6.2821
# Pretrain Epoch: 2, Contrast Loss: 6.2486
# Pretrain Epoch: 3, Contrast Loss: 6.1703
# Pretrain Epoch: 4, Contrast Loss: 6.2217
# Pretrain Epoch: 5, Contrast Loss: 6.0433
# Pretrain Epoch: 6, Contrast Loss: 5.9896
# Pretrain Epoch: 7, Contrast Loss: 6.0986
# Pretrain Epoch: 8, Contrast Loss: 5.9817
# Pretrain Epoch: 9, Contrast Loss: 5.9703
# ========== 开始微调阶段 ==========
# Fine-tune Epoch: 0, Focal Loss: 0.1209
# Fine-tune Epoch: 1, Focal Loss: 0.0500
# Fine-tune Epoch: 2, Focal Loss: 0.0368
# Fine-tune Epoch: 3, Focal Loss: 0.0288
# Fine-tune Epoch: 4, Focal Loss: 0.0267
# Fine-tune Epoch: 5, Focal Loss: 0.0226
# Fine-tune Epoch: 6, Focal Loss: 0.0223
# Fine-tune Epoch: 7, Focal Loss: 0.0201
# Fine-tune Epoch: 8, Focal Loss: 0.0216
# Fine-tune Epoch: 9, Focal Loss: 0.0201
# Test Accuracy for current combination: 0.7450
#
# Testing combination 398: threshold=0.2500, random_state=30, layers=4, hidden_channels=140, finetune_lr=0.005, pretrain_lr=1e-06, gamma=3.8000, alpha=0.3000, aug_method=edge_drop, aug_ratio=0.0500, pretrain_epochs=10, temperature=0.1200, model_type=GAT, dropout_rate=0.1000
# ========== 开始预训练阶段 ==========
# Pretrain Epoch: 0, Contrast Loss: 5.9188
# Pretrain Epoch: 1, Contrast Loss: 5.9083
# Pretrain Epoch: 2, Contrast Loss: 5.9620
# Pretrain Epoch: 3, Contrast Loss: 5.9861
# Pretrain Epoch: 4, Contrast Loss: 5.9523
# Pretrain Epoch: 5, Contrast Loss: 5.9250
# Pretrain Epoch: 6, Contrast Loss: 5.9614
# Pretrain Epoch: 7, Contrast Loss: 5.9352
# Pretrain Epoch: 8, Contrast Loss: 5.8806
# Pretrain Epoch: 9, Contrast Loss: 5.9055
# ========== 开始微调阶段 ==========
# Fine-tune Epoch: 0, Focal Loss: 0.0336
# Fine-tune Epoch: 1, Focal Loss: 0.0222
# Fine-tune Epoch: 2, Focal Loss: 0.0171
# Fine-tune Epoch: 3, Focal Loss: 0.0165
# Fine-tune Epoch: 4, Focal Loss: 0.0150
# Fine-tune Epoch: 5, Focal Loss: 0.0142
# Fine-tune Epoch: 6, Focal Loss: 0.0146
# Fine-tune Epoch: 7, Focal Loss: 0.0132
# Fine-tune Epoch: 8, Focal Loss: 0.0136
# Fine-tune Epoch: 9, Focal Loss: 0.0127
# Test Accuracy for current combination: 0.7050
#
# Testing combination 399: threshold=0.1400, random_state=30, layers=4, hidden_channels=200, finetune_lr=0.01, pretrain_lr=0.001, gamma=3.8000, alpha=0.5000, aug_method=edge_perturb, aug_ratio=0.1400, pretrain_epochs=10, temperature=0.2300, model_type=GAT, dropout_rate=0.3000
# ========== 开始预训练阶段 ==========
# Pretrain Epoch: 0, Contrast Loss: 6.6443
# Pretrain Epoch: 1, Contrast Loss: 6.5190
# Pretrain Epoch: 2, Contrast Loss: 6.2934
# Pretrain Epoch: 3, Contrast Loss: 6.1105
# Pretrain Epoch: 4, Contrast Loss: 6.0523
# Pretrain Epoch: 5, Contrast Loss: 5.9807
# Pretrain Epoch: 6, Contrast Loss: 5.9466
# Pretrain Epoch: 7, Contrast Loss: 5.9156
# Pretrain Epoch: 8, Contrast Loss: 5.8605
# Pretrain Epoch: 9, Contrast Loss: 5.8189
# ========== 开始微调阶段 ==========
# Fine-tune Epoch: 0, Focal Loss: 0.0291
# Fine-tune Epoch: 1, Focal Loss: 0.3575
# Fine-tune Epoch: 2, Focal Loss: 0.0251
# Fine-tune Epoch: 3, Focal Loss: 0.0230
# Fine-tune Epoch: 4, Focal Loss: 0.0207
# Fine-tune Epoch: 5, Focal Loss: 0.0188
# Fine-tune Epoch: 6, Focal Loss: 0.0166
# Fine-tune Epoch: 7, Focal Loss: 0.0203
# Fine-tune Epoch: 8, Focal Loss: 0.0189
# Fine-tune Epoch: 9, Focal Loss: 0.0183
# Test Accuracy for current combination: 0.7550
#
# Testing combination 400: threshold=0.2700, random_state=20, layers=3, hidden_channels=100, finetune_lr=0.005, pretrain_lr=1e-06, gamma=3.4000, alpha=0.5000, aug_method=feature, aug_ratio=0.1200, pretrain_epochs=10, temperature=0.2200, model_type=GAT, dropout_rate=0.1000
# ========== 开始预训练阶段 ==========
# Pretrain Epoch: 0, Contrast Loss: 6.0247
# Pretrain Epoch: 1, Contrast Loss: 6.0022
# Pretrain Epoch: 2, Contrast Loss: 5.9967
# Pretrain Epoch: 3, Contrast Loss: 6.0058
# Pretrain Epoch: 4, Contrast Loss: 6.0108
# Pretrain Epoch: 5, Contrast Loss: 6.0495
# Pretrain Epoch: 6, Contrast Loss: 5.9963
# Pretrain Epoch: 7, Contrast Loss: 5.9902
# Pretrain Epoch: 8, Contrast Loss: 6.0193
# Pretrain Epoch: 9, Contrast Loss: 6.0228
# ========== 开始微调阶段 ==========
# Fine-tune Epoch: 0, Focal Loss: 0.0600
# Fine-tune Epoch: 1, Focal Loss: 0.0328
# Fine-tune Epoch: 2, Focal Loss: 0.0272
# Fine-tune Epoch: 3, Focal Loss: 0.0237
# Fine-tune Epoch: 4, Focal Loss: 0.0242
# Fine-tune Epoch: 5, Focal Loss: 0.0219
# Fine-tune Epoch: 6, Focal Loss: 0.0226
# Fine-tune Epoch: 7, Focal Loss: 0.0209
# Fine-tune Epoch: 8, Focal Loss: 0.0212
# Fine-tune Epoch: 9, Focal Loss: 0.0201
# Test Accuracy for current combination: 0.7250
#
# Best Hyperparameters: (0.16, 10, 4, 40, 0.005, 0.001, 2.0, 0.5, 'feature', 0.15, 10, 0.27, 'GAT', 0)
#
# Best Model Classification Report on Test Set:
#               precision    recall  f1-score   support
#
#      Class 0     0.8089    0.9071    0.8552       140
#      Class 1     0.6977    0.5000    0.5825        60
#
#     accuracy                         0.7850       200
#    macro avg     0.7533    0.7036    0.7189       200
# weighted avg     0.7755    0.7850    0.7734       200
#
# Best Model Test Set Metrics:
# Precision: 0.7533, Recall: 0.7036, F1: 0.7189, Accuracy: 0.7850

# %%
# 使用最佳模型在测试集上进行评估，并输出分类报告和错误样本的索引集合
with torch.no_grad():
    # 预测测试集
    test_out = model(data)
    # 取出测试集对应的预测结果（注意：data.test_mask 为 bool 型 mask）
    preds = test_out[data.test_mask].argmax(dim=1)
    true_labels = data.y[data.test_mask]

    # 输出测试集上的分类报告
    print("Test Set Classification Report:")
    print(classification_report(true_labels.cpu(), preds.cpu(), target_names=["Class 0", "Class 1"], digits=4))

    # 获取测试集在整个数据集中的原始索引（假设 data.test_mask 是一个布尔向量）
    test_indices = torch.where(data.test_mask)[0].cpu().numpy()
    
    # 将预测和真实标签转换为 numpy 数组
    preds_np = preds.cpu().numpy()
    true_np = true_labels.cpu().numpy()

    # 计算四类样本的索引集合：
    # True Positives (TP): 真标签为 1 且预测为 1 （1 被分为 1）
    tp_idx = test_indices[(true_np == 1) & (preds_np == 1)]
    # False Negatives (FN): 真标签为 1 但预测为 0 （1 被分为 0）
    fn_idx = test_indices[(true_np == 1) & (preds_np == 0)]
    # True Negatives (TN): 真标签为 0 且预测为 0 （0 被分为 0）
    tn_idx = test_indices[(true_np == 0) & (preds_np == 0)]
    # False Positives (FP): 真标签为 0 但预测为 1 （0 被分为 1）
    fp_idx = test_indices[(true_np == 0) & (preds_np == 1)]

    print("\nError Samples Index Sets:")
    print("True Positives (1 被分为 1):", tp_idx)
    print("False Negatives (1 被分为 0):", fn_idx)
    print("True Negatives (0 被分为 0):", tn_idx)
    print("False Positives (0 被分为 1):", fp_idx)

# %% [markdown]
# ### 比较有无对比损失
