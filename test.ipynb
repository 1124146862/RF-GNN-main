# %%
# util function
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
import pandas as pd
from sklearn.ensemble import RandomForestClassifier
from scipy.sparse import csr_matrix
import torch


def standard_input(X):
    # 标准化输入
    scaler = StandardScaler()
    X_scaled = scaler.fit_transform(X)
    return pd.DataFrame(X_scaled, columns=X.columns)



def load_data_SGER(mode='raw',random_state=42, aug_pct=100):
    """
    加载数据并进行预处理，返回以下变量：
    X, y, X_train, X_valid, X_test, y_train, y_valid, y_test, train_mask, valid_mask, test_mask

    参数：
        mode (str): 数据读取模式，可选 'raw' 或 'aug'
            - 'raw': 仅使用 raw 数据（SGER1000.csv），逻辑与原 load_data_SGER_RAW 一致
            - 'aug': raw 数据按原逻辑划分，且读取 LLM 数据（SGERLLM.csv）并将其按 90%/10%分别追加到
                     训练集和验证集中；测试集仍使用 raw 数据划分出的部分
        aug_pct (int 或 float): 使用的增强数据比例，取值范围 0~100，默认 100 表示使用全部 LLM 数据。
                                  当 mode 为 'aug' 时有效。
    """
    # 定义文件路径
    path_raw = '/home/gehongfei/project/TabGNN/dataset/SGER1000.csv'
    path_llm = '/home/gehongfei/project/TabGNN/dataset/SGERLLM.csv'
    
    # ---------------------------
    # 1. 处理 raw 数据
    # ---------------------------
    try:
        df_raw = pd.read_csv(path_raw, sep='\s+')
    except Exception as e:
        print(f"Error reading raw file {path_raw}: {e}")
        return None
    
    if 'kredit' not in df_raw.columns:
        print("Error: 'kredit' 列未在 raw 数据中找到。")
        return None

    # 分离特征和目标变量
    y_raw = df_raw['kredit']
    X_raw = df_raw.drop(columns=['kredit'])
    
    # 划分 raw 数据：70% 为训练集，30% 为临时集合
    X_train_raw, X_temp, y_train_raw, y_temp = train_test_split(
        X_raw, y_raw, test_size=0.3, random_state=random_state, stratify=y_raw
    )
    # 将临时集合再划分为验证集和测试集，其中 1/3（约 10%）为验证集，2/3（约 20%）为测试集
    X_valid_raw, X_test_raw, y_valid_raw, y_test_raw = train_test_split(
        X_temp, y_temp, test_size=2/3, random_state=random_state, stratify=y_temp
    )
    
    # ---------------------------
    # 2. 根据 mode 处理数据
    # ---------------------------
    if mode == 'raw':
        # 直接使用 raw 数据划分结果
        X_train_final = X_train_raw.reset_index(drop=True)
        y_train_final = y_train_raw.reset_index(drop=True)
        X_valid_final = X_valid_raw.reset_index(drop=True)
        y_valid_final = y_valid_raw.reset_index(drop=True)
        X_test_final  = X_test_raw.reset_index(drop=True)
        y_test_final  = y_test_raw.reset_index(drop=True)
        
    elif mode == 'aug':
        # 读取 LLM 数据，并将数据追加到 raw 的训练集和验证集中
        try:
            df_llm = pd.read_csv(path_llm, sep='\s+')
        except Exception as e:
            print(f"Error reading LLM file {path_llm}: {e}")
            return None
        
        if 'kredit' not in df_llm.columns:
            print("Error: 'kredit' 列未在 LLM 数据中找到。")
            return None
        
        # 根据 aug_pct 参数调整使用的增强数据比例
        if aug_pct < 100:
            df_llm = df_llm.sample(frac=aug_pct/100, random_state=42).reset_index(drop=True)
        
        # 分离 LLM 数据中的特征和目标变量
        y_llm = df_llm['kredit']
        X_llm = df_llm.drop(columns=['kredit'])
        
        # 划分 LLM 数据：90% 为训练，10% 为验证
        X_llm_train, X_llm_valid, y_llm_train, y_llm_valid = train_test_split(
            X_llm, y_llm, test_size=0.1, random_state=42, stratify=y_llm
        )
        
        # 重置索引，防止后续合并时出现冲突
        X_train_raw = X_train_raw.reset_index(drop=True)
        y_train_raw = y_train_raw.reset_index(drop=True)
        X_valid_raw = X_valid_raw.reset_index(drop=True)
        y_valid_raw = y_valid_raw.reset_index(drop=True)
        X_llm_train = X_llm_train.reset_index(drop=True)
        y_llm_train = y_llm_train.reset_index(drop=True)
        X_llm_valid = X_llm_valid.reset_index(drop=True)
        y_llm_valid = y_llm_valid.reset_index(drop=True)
        X_test_raw  = X_test_raw.reset_index(drop=True)
        y_test_raw  = y_test_raw.reset_index(drop=True)
        
        # 追加 LLM 数据：训练集增加 LLM 训练数据，验证集增加 LLM 验证数据
        X_train_final = pd.concat([X_train_raw, X_llm_train], axis=0).reset_index(drop=True)
        y_train_final = pd.concat([y_train_raw, y_llm_train], axis=0).reset_index(drop=True)
        X_valid_final = pd.concat([X_valid_raw, X_llm_valid], axis=0).reset_index(drop=True)
        y_valid_final = pd.concat([y_valid_raw, y_llm_valid], axis=0).reset_index(drop=True)
        # 测试集仍使用 raw 划分出的数据
        X_test_final  = X_test_raw
        y_test_final  = y_test_raw
    else:
        print("Error: mode 必须为 'raw' 或 'aug'")
        return None

    # ---------------------------
    # 3. 合并所有数据，并构造掩码
    # ---------------------------
    # 合并训练、验证、测试数据为完整数据集
    X = pd.concat([X_train_final, X_valid_final, X_test_final], axis=0).reset_index(drop=True)
    y = pd.concat([y_train_final, y_valid_final, y_test_final], axis=0).reset_index(drop=True)
    
    # 构造掩码，保证返回的变量名与要求一致
    num_total = len(X)
    train_mask = torch.zeros(num_total, dtype=torch.bool)
    valid_mask = torch.zeros(num_total, dtype=torch.bool)
    test_mask  = torch.zeros(num_total, dtype=torch.bool)
    
    # 训练集占合并数据的前部分
    len_train = len(X_train_final)
    train_mask[:len_train] = True
    # 验证集紧随训练集之后
    len_valid = len(X_valid_final)
    valid_mask[len_train:len_train+len_valid] = True
    # 测试集为剩余部分
    test_mask[len_train+len_valid:] = True

    # ---------------------------
    # 4. 标准化数据
    # ---------------------------
    X = standard_input(X)
    X_train = standard_input(X_train_final)
    X_valid = standard_input(X_valid_final)
    X_test  = standard_input(X_test_final)
    
    return X, y, X_train, X_valid, X_test, \
           y_train_final, y_valid_final, y_test_final, \
           train_mask, valid_mask, test_mask

# 使用示例：



# 训练Random Forest并计算相似性
# Function to compute adjacency matrices for train, validation, and test data
def compute_adjacency_matrix(X_train, X_valid, X_test, y_train, y_valid, n_estimators=100, max_depth=None, threshold=0.15, random_state=42):
    # 合并训练、验证和测试数据
    X_combined = pd.concat([X_train, X_valid, X_test], axis=0)
    num_samples = X_combined.shape[0]
    # 训练Random Forest
    rf = RandomForestClassifier(n_estimators=n_estimators, max_depth=max_depth, random_state=random_state)
    rf.fit(pd.concat([X_train, X_valid], axis=0), pd.concat([y_train, y_valid], axis=0))
    # 获取每棵树的叶子索引
    leaf_indices = rf.apply(X_combined)
    # 计算相似性矩阵
    adjacency_matrix = np.zeros((num_samples, num_samples))
    for tree_idx in range(leaf_indices.shape[1]):  # 遍历每棵树
        leaf_to_samples = {}
        for sample_idx, leaf_id in enumerate(leaf_indices[:, tree_idx]):
            if leaf_id not in leaf_to_samples:
                leaf_to_samples[leaf_id] = []
            leaf_to_samples[leaf_id].append(sample_idx)
        # 更新相似性矩阵
        for sample_list in leaf_to_samples.values():
            for i in sample_list:
                for j in sample_list:
                    if i != j:
                        adjacency_matrix[i, j] += 1
    # 归一化相似性
    adjacency_matrix /= adjacency_matrix.max()
    # 应用阈值，转换为二值矩阵
    adjacency_matrix = (adjacency_matrix > threshold).astype(int)
    # 转换为稀疏矩阵
    adjacency_matrix_sparse = csr_matrix(adjacency_matrix)
    return adjacency_matrix_sparse

# 从稀疏邻接矩阵提取边索引
def adjacency_to_edge_index(adj_matrix):
    coo_matrix = adj_matrix.tocoo()  # 转换为COO格式
    edge_index = torch.tensor(np.vstack((coo_matrix.row, coo_matrix.col)), dtype=torch.long)
    return edge_index

# %%
import itertools
import random
import torch
import numpy as np
from sklearn.metrics import f1_score, classification_report, accuracy_score, precision_score, recall_score
from torch_geometric.data import Data
from torch_geometric.nn import SAGEConv

device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")

# 定义 Focal Loss，用于替代 CrossEntropyLoss
class FocalLoss(torch.nn.Module):
    def __init__(self, gamma=2, alpha=None, reduction="mean"):
        """
        :param gamma: focusing parameter, gamma > 0 调整容易分类样本的权重
        :param alpha: 类别权重，通常可以设置为一个列表或者 tensor
        :param reduction: 损失的计算方式，"mean" 或 "sum"
        """
        super(FocalLoss, self).__init__()
        self.gamma = gamma
        self.alpha = alpha  # alpha 通常用于对不同类别加权
        self.reduction = reduction
        self.ce = torch.nn.CrossEntropyLoss(reduction="none")

    def forward(self, inputs, targets):
        # 计算基本的交叉熵损失
        ce_loss = self.ce(inputs, targets)
        # 计算概率值（注意：torch.exp(-ce_loss) 就是模型给出的对应类别的概率）
        pt = torch.exp(-ce_loss)
        # 根据 alpha 调整不同类别的权重
        if self.alpha is not None:
            if isinstance(self.alpha, (list, np.ndarray)):
                alpha = inputs.new_tensor(self.alpha)
            else:
                alpha = self.alpha
            at = alpha.gather(0, targets.data)
            ce_loss = at * ce_loss
        # Focal Loss 的公式
        focal_loss = ((1 - pt) ** self.gamma) * ce_loss

        if self.reduction == "mean":
            return focal_loss.mean()
        elif self.reduction == "sum":
            return focal_loss.sum()
        else:
            return focal_loss

# GraphSAGE 模型定义（可包含多个图卷积层）
class GraphSAGE(torch.nn.Module):
    def __init__(self, in_channels, hidden_channels, out_channels, num_layers=2):
        super(GraphSAGE, self).__init__()
        self.convs = torch.nn.ModuleList()
        self.convs.append(SAGEConv(in_channels, hidden_channels))
        
        # 添加更多层
        for _ in range(num_layers - 1):
            self.convs.append(SAGEConv(hidden_channels, hidden_channels))
        self.fc = torch.nn.Linear(hidden_channels, out_channels)

    def forward(self, data):
        x, edge_index = data.x, data.edge_index
        for conv in self.convs:
            x = conv(x, edge_index).relu()
        x = self.fc(x)
        return x

# 主 grid search 函数（这里使用 FocalLoss 替代 CrossEntropyLoss）
def grid_search(X, y, X_train, X_valid, X_test, y_train, y_valid, train_mask, valid_mask, test_mask, n_iter):
    best_acc = 0.0
    best_overall_model_state = None
    best_overall_params = None
    
    thresholds = np.arange(0.1, 0.4, 0.02).tolist()
    random_states = list(range(0, 300, 10))
    num_layers_list = [1, 2, 3, 4, 5]
    hidden_channels_list = list(range(20, 300, 10))
    lrs = [0.01, 0.05, 0.001, 0.005]
    gammas = np.arange(0.1, 4, 0.2).tolist()
    alphas = np.arange(0.1, 0.9, 0.1).tolist()
    
    print("Start grid search...")

    # 将所有超参数组合在一起
    param_combinations = list(itertools.product(thresholds, random_states, num_layers_list, 
                                                hidden_channels_list, lrs, gammas, alphas))
    # 打印所有组合（可选）
    print("Total parameter combinations:", len(param_combinations))
    random.shuffle(param_combinations)
    
    for i, (threshold, random_state, num_layers, hidden_channels, lr, gamma, alpha_value) in enumerate(param_combinations[:n_iter]):
        print(f"\nTesting combination {i+1}: threshold={threshold}, random_state={random_state}, "
              f"layers={num_layers}, hidden_channels={hidden_channels}, lr={lr}, gamma={gamma}, alpha={alpha_value}")

        adj_matrix = compute_adjacency_matrix(X_train, X_valid, X_test, y_train, y_valid, 
                                                threshold=threshold, random_state=random_state)
        edge_index = adjacency_to_edge_index(adj_matrix)

        X_tensor = torch.tensor(X.values, dtype=torch.float)
        y_tensor = torch.tensor(y.values, dtype=torch.long)
        data = Data(x=X_tensor, y=y_tensor, edge_index=edge_index, 
                    train_mask=train_mask, val_mask=valid_mask, test_mask=test_mask)

        model = GraphSAGE(in_channels=X.shape[1], hidden_channels=hidden_channels, 
                          out_channels=len(np.unique(y)), num_layers=num_layers).to(device)
        data = data.to(device)
        optimizer = torch.optim.Adam(model.parameters(), lr=lr, weight_decay=5e-4)

        # 利用 grid search 中的 alpha 参数构造类别权重
        # 假设二分类任务中，将类别 1 设为少数类，其权重取 alpha_value，类别 0 的权重为 1 - alpha_value
        alpha_list = [1 - alpha_value, alpha_value]
        alpha_tensor = torch.tensor(alpha_list, dtype=torch.float).to(device)
        print("Alpha weights:", alpha_tensor)
        criterion = FocalLoss(gamma=gamma, alpha=alpha_tensor, reduction="mean")

        best_f1_epoch = 0.0
        best_model_epoch = None

        for epoch in range(100):
            model.train()
            optimizer.zero_grad()
            out = model(data)
            loss = criterion(out[data.train_mask], data.y[data.train_mask])
            loss.backward()
            optimizer.step()

            model.eval()
            with torch.no_grad():
                val_out = model(data)
                val_preds = val_out[data.val_mask].argmax(dim=1)
                val_true = data.y[data.val_mask]
                val_f1 = f1_score(val_true.cpu(), val_preds.cpu(), average="macro")

            if val_f1 > best_f1_epoch:
                best_f1_epoch = val_f1
                best_model_epoch = model.state_dict()

        model.load_state_dict(best_model_epoch)
        model.eval()
        with torch.no_grad():
            test_out = model(data)
            preds = test_out[data.test_mask].argmax(dim=1)
            true_labels = data.y[data.test_mask]
            test_acc = accuracy_score(true_labels.cpu(), preds.cpu())
        
        print(f"Test Accuracy for current combination: {test_acc:.4f}")
        if test_acc > best_acc:
            best_acc = test_acc
            best_overall_model_state = best_model_epoch
            best_overall_params = (threshold, random_state, num_layers, hidden_channels, lr, gamma, alpha_value)
    
    return best_overall_params, best_overall_model_state


X, y, X_train, X_valid, X_test, y_train, y_valid, y_test, train_mask, valid_mask, test_mask = load_data_SGER(random_state=42, mode='raw')

# 此处 n_iter 可以根据需要调整，示例中仅搜索 3 个组合
best_params, best_model_state = grid_search(X, y, X_train, X_valid, X_test, 
                                            y_train, y_valid, train_mask, valid_mask, test_mask, n_iter=1000)
print("\nBest Hyperparameters:", best_params)

# 解包最佳超参数
threshold, random_state, num_layers, hidden_channels, lr, gamma, alpha_value = best_params
adj_matrix = compute_adjacency_matrix(X_train, X_valid, X_test, y_train, y_valid, 
                                      threshold=threshold, random_state=random_state)
edge_index = adjacency_to_edge_index(adj_matrix).to(device)

X_tensor = torch.tensor(X.values, dtype=torch.float).to(device)
y_tensor = torch.tensor(y.values, dtype=torch.long).to(device)
data = Data(x=X_tensor, y=y_tensor, edge_index=edge_index, 
            train_mask=train_mask.to(device), val_mask=valid_mask.to(device), test_mask=test_mask.to(device))

model = GraphSAGE(in_channels=X.shape[1], hidden_channels=hidden_channels, 
                  out_channels=len(np.unique(y)), num_layers=num_layers).to(device)
model.load_state_dict(best_model_state)
model.eval()

with torch.no_grad():
    test_out = model(data)
    preds = test_out[data.test_mask].argmax(dim=1)
    true_labels = data.y[data.test_mask]
    
    report = classification_report(true_labels.cpu(), preds.cpu(), target_names=["Class 0", "Class 1"], digits=4)
    test_precision = precision_score(true_labels.cpu(), preds.cpu(), average="macro")
    test_recall = recall_score(true_labels.cpu(), preds.cpu(), average="macro")
    test_f1 = f1_score(true_labels.cpu(), preds.cpu(), average="macro")
    test_acc = accuracy_score(true_labels.cpu(), preds.cpu())
    
    print("\nBest Model Classification Report on Test Set:")
    print(report)
    print("Best Model Test Set Metrics:")
    print(f"Precision: {test_precision:.4f}, Recall: {test_recall:.4f}, "
          f"F1: {test_f1:.4f}, Accuracy: {test_acc:.4f}")
# Out:
# Start grid search...
# Total parameter combinations: 43008000
#
# Testing combination 1: threshold=0.32000000000000006, random_state=160, layers=5, hidden_channels=170, lr=0.001, gamma=3.7000000000000006, alpha=0.2
# Alpha weights: tensor([0.8000, 0.2000], device='cuda:0')
# Test Accuracy for current combination: 0.7300
#
# Testing combination 2: threshold=0.32000000000000006, random_state=80, layers=3, hidden_channels=30, lr=0.001, gamma=3.500000000000001, alpha=0.1
# Alpha weights: tensor([0.9000, 0.1000], device='cuda:0')
# Test Accuracy for current combination: 0.7200
#
# Testing combination 3: threshold=0.22000000000000003, random_state=230, layers=3, hidden_channels=230, lr=0.005, gamma=0.1, alpha=0.1
# Alpha weights: tensor([0.9000, 0.1000], device='cuda:0')
# Test Accuracy for current combination: 0.7000
#
# Testing combination 4: threshold=0.30000000000000004, random_state=200, layers=5, hidden_channels=280, lr=0.05, gamma=3.7000000000000006, alpha=0.2
# Alpha weights: tensor([0.8000, 0.2000], device='cuda:0')
# Test Accuracy for current combination: 0.7050
#
# Testing combination 5: threshold=0.38, random_state=170, layers=1, hidden_channels=70, lr=0.01, gamma=3.7000000000000006, alpha=0.8
# Alpha weights: tensor([0.2000, 0.8000], device='cuda:0')
# Test Accuracy for current combination: 0.7250
#
# Testing combination 6: threshold=0.26, random_state=60, layers=1, hidden_channels=130, lr=0.05, gamma=0.9000000000000001, alpha=0.4
# Alpha weights: tensor([0.6000, 0.4000], device='cuda:0')
# Test Accuracy for current combination: 0.7000
#
# Testing combination 7: threshold=0.28, random_state=130, layers=2, hidden_channels=270, lr=0.05, gamma=1.5000000000000004, alpha=0.1
# Alpha weights: tensor([0.9000, 0.1000], device='cuda:0')
# Test Accuracy for current combination: 0.7550
#
# Testing combination 8: threshold=0.18000000000000002, random_state=30, layers=4, hidden_channels=250, lr=0.005, gamma=0.30000000000000004, alpha=0.6
# Alpha weights: tensor([0.4000, 0.6000], device='cuda:0')
# Test Accuracy for current combination: 0.7000
#
# Testing combination 9: threshold=0.1, random_state=240, layers=2, hidden_channels=210, lr=0.05, gamma=0.30000000000000004, alpha=0.30000000000000004
# Alpha weights: tensor([0.7000, 0.3000], device='cuda:0')
# Test Accuracy for current combination: 0.7000
#
# Testing combination 10: threshold=0.26, random_state=190, layers=1, hidden_channels=60, lr=0.005, gamma=3.3000000000000007, alpha=0.1
# Alpha weights: tensor([0.9000, 0.1000], device='cuda:0')
# Test Accuracy for current combination: 0.7300
#
# Testing combination 11: threshold=0.24000000000000002, random_state=20, layers=1, hidden_channels=150, lr=0.001, gamma=3.1000000000000005, alpha=0.5
# Alpha weights: tensor([0.5000, 0.5000], device='cuda:0')
# Test Accuracy for current combination: 0.7550
#
# Testing combination 12: threshold=0.18000000000000002, random_state=190, layers=5, hidden_channels=280, lr=0.005, gamma=1.9000000000000004, alpha=0.4
# Alpha weights: tensor([0.6000, 0.4000], device='cuda:0')
# Test Accuracy for current combination: 0.7650
#
# Testing combination 13: threshold=0.3600000000000001, random_state=30, layers=3, hidden_channels=240, lr=0.05, gamma=2.5000000000000004, alpha=0.4
# Alpha weights: tensor([0.6000, 0.4000], device='cuda:0')
# Test Accuracy for current combination: 0.7450
#
# Testing combination 14: threshold=0.3600000000000001, random_state=250, layers=5, hidden_channels=140, lr=0.05, gamma=2.1000000000000005, alpha=0.2
# Alpha weights: tensor([0.8000, 0.2000], device='cuda:0')
# Test Accuracy for current combination: 0.7150
#
# Testing combination 15: threshold=0.26, random_state=80, layers=4, hidden_channels=160, lr=0.01, gamma=2.3000000000000007, alpha=0.5
# Alpha weights: tensor([0.5000, 0.5000], device='cuda:0')
# Test Accuracy for current combination: 0.7200
#
# Testing combination 16: threshold=0.3600000000000001, random_state=120, layers=5, hidden_channels=30, lr=0.001, gamma=1.3000000000000003, alpha=0.30000000000000004
# Alpha weights: tensor([0.7000, 0.3000], device='cuda:0')
# Test Accuracy for current combination: 0.7100
#
# Testing combination 17: threshold=0.32000000000000006, random_state=230, layers=4, hidden_channels=120, lr=0.001, gamma=0.7000000000000001, alpha=0.8
# Alpha weights: tensor([0.2000, 0.8000], device='cuda:0')
# Test Accuracy for current combination: 0.7000
#
# Testing combination 18: threshold=0.22000000000000003, random_state=170, layers=2, hidden_channels=110, lr=0.05, gamma=3.3000000000000007, alpha=0.30000000000000004
# Alpha weights: tensor([0.7000, 0.3000], device='cuda:0')
# Test Accuracy for current combination: 0.7550
#
# Testing combination 19: threshold=0.18000000000000002, random_state=190, layers=1, hidden_channels=120, lr=0.005, gamma=2.5000000000000004, alpha=0.6
# Alpha weights: tensor([0.4000, 0.6000], device='cuda:0')
# Test Accuracy for current combination: 0.7400
#
# Testing combination 20: threshold=0.26, random_state=70, layers=5, hidden_channels=130, lr=0.005, gamma=2.900000000000001, alpha=0.30000000000000004
# Alpha weights: tensor([0.7000, 0.3000], device='cuda:0')
# Test Accuracy for current combination: 0.7250
#
# Testing combination 21: threshold=0.3600000000000001, random_state=60, layers=1, hidden_channels=210, lr=0.01, gamma=0.1, alpha=0.1
# Alpha weights: tensor([0.9000, 0.1000], device='cuda:0')
# Test Accuracy for current combination: 0.7000
#
# Testing combination 22: threshold=0.4, random_state=200, layers=4, hidden_channels=170, lr=0.01, gamma=3.7000000000000006, alpha=0.30000000000000004
# Alpha weights: tensor([0.7000, 0.3000], device='cuda:0')
# Test Accuracy for current combination: 0.7250
#
# Testing combination 23: threshold=0.1, random_state=20, layers=5, hidden_channels=170, lr=0.005, gamma=1.1000000000000003, alpha=0.2
# Alpha weights: tensor([0.8000, 0.2000], device='cuda:0')
# Test Accuracy for current combination: 0.7700
#
# Testing combination 24: threshold=0.16000000000000003, random_state=70, layers=2, hidden_channels=60, lr=0.001, gamma=1.1000000000000003, alpha=0.2
# Alpha weights: tensor([0.8000, 0.2000], device='cuda:0')
# Test Accuracy for current combination: 0.7350
#
# Testing combination 25: threshold=0.14, random_state=220, layers=5, hidden_channels=290, lr=0.05, gamma=0.7000000000000001, alpha=0.7000000000000001
# Alpha weights: tensor([0.3000, 0.7000], device='cuda:0')
# Test Accuracy for current combination: 0.7000
#
# Testing combination 26: threshold=0.1, random_state=190, layers=1, hidden_channels=250, lr=0.005, gamma=2.7000000000000006, alpha=0.1
# Alpha weights: tensor([0.9000, 0.1000], device='cuda:0')
# Test Accuracy for current combination: 0.7550
#
# Testing combination 27: threshold=0.2, random_state=30, layers=1, hidden_channels=260, lr=0.01, gamma=3.1000000000000005, alpha=0.4
# Alpha weights: tensor([0.6000, 0.4000], device='cuda:0')
# Test Accuracy for current combination: 0.7550
#
# Testing combination 28: threshold=0.4, random_state=190, layers=1, hidden_channels=220, lr=0.05, gamma=0.30000000000000004, alpha=0.1
# Alpha weights: tensor([0.9000, 0.1000], device='cuda:0')
# Test Accuracy for current combination: 0.7000
#
# Testing combination 29: threshold=0.22000000000000003, random_state=120, layers=3, hidden_channels=180, lr=0.01, gamma=3.1000000000000005, alpha=0.2
# Alpha weights: tensor([0.8000, 0.2000], device='cuda:0')
# Test Accuracy for current combination: 0.7400
#
# Testing combination 30: threshold=0.3400000000000001, random_state=290, layers=2, hidden_channels=270, lr=0.01, gamma=0.30000000000000004, alpha=0.2
# Alpha weights: tensor([0.8000, 0.2000], device='cuda:0')
# Test Accuracy for current combination: 0.7000
#
# Testing combination 31: threshold=0.2, random_state=190, layers=4, hidden_channels=50, lr=0.01, gamma=0.30000000000000004, alpha=0.2
# Alpha weights: tensor([0.8000, 0.2000], device='cuda:0')
# Test Accuracy for current combination: 0.7000
#
# Testing combination 32: threshold=0.4, random_state=0, layers=2, hidden_channels=220, lr=0.05, gamma=2.7000000000000006, alpha=0.1
# Alpha weights: tensor([0.9000, 0.1000], device='cuda:0')
# Test Accuracy for current combination: 0.7400
#
# Testing combination 33: threshold=0.26, random_state=270, layers=2, hidden_channels=210, lr=0.005, gamma=3.1000000000000005, alpha=0.1
# Alpha weights: tensor([0.9000, 0.1000], device='cuda:0')
# Test Accuracy for current combination: 0.7550
#
# Testing combination 34: threshold=0.3600000000000001, random_state=150, layers=1, hidden_channels=120, lr=0.01, gamma=0.30000000000000004, alpha=0.1
# Alpha weights: tensor([0.9000, 0.1000], device='cuda:0')
# Test Accuracy for current combination: 0.7000
#
# Testing combination 35: threshold=0.3600000000000001, random_state=90, layers=5, hidden_channels=200, lr=0.001, gamma=1.5000000000000004, alpha=0.8
# Alpha weights: tensor([0.2000, 0.8000], device='cuda:0')
# Test Accuracy for current combination: 0.7200
#
# Testing combination 36: threshold=0.22000000000000003, random_state=170, layers=4, hidden_channels=260, lr=0.005, gamma=3.7000000000000006, alpha=0.8
# Alpha weights: tensor([0.2000, 0.8000], device='cuda:0')
# Test Accuracy for current combination: 0.7550
#
# Testing combination 37: threshold=0.28, random_state=120, layers=4, hidden_channels=250, lr=0.001, gamma=2.7000000000000006, alpha=0.5
# Alpha weights: tensor([0.5000, 0.5000], device='cuda:0')
# Test Accuracy for current combination: 0.7000
#
# Testing combination 38: threshold=0.26, random_state=130, layers=2, hidden_channels=70, lr=0.005, gamma=2.900000000000001, alpha=0.30000000000000004
# Alpha weights: tensor([0.7000, 0.3000], device='cuda:0')
# Test Accuracy for current combination: 0.7000
#
# Testing combination 39: threshold=0.30000000000000004, random_state=90, layers=4, hidden_channels=280, lr=0.01, gamma=0.1, alpha=0.30000000000000004
# Alpha weights: tensor([0.7000, 0.3000], device='cuda:0')
# Test Accuracy for current combination: 0.7000
#
# Testing combination 40: threshold=0.32000000000000006, random_state=0, layers=1, hidden_channels=170, lr=0.01, gamma=0.30000000000000004, alpha=0.6
# Alpha weights: tensor([0.4000, 0.6000], device='cuda:0')
# Test Accuracy for current combination: 0.7000
#
# Testing combination 41: threshold=0.18000000000000002, random_state=150, layers=4, hidden_channels=190, lr=0.05, gamma=1.3000000000000003, alpha=0.8
# Alpha weights: tensor([0.2000, 0.8000], device='cuda:0')
# Test Accuracy for current combination: 0.3000
#
# Testing combination 42: threshold=0.32000000000000006, random_state=150, layers=1, hidden_channels=240, lr=0.005, gamma=0.9000000000000001, alpha=0.30000000000000004
# Alpha weights: tensor([0.7000, 0.3000], device='cuda:0')
# Test Accuracy for current combination: 0.7250
#
# Testing combination 43: threshold=0.18000000000000002, random_state=140, layers=3, hidden_channels=50, lr=0.01, gamma=3.3000000000000007, alpha=0.1
# Alpha weights: tensor([0.9000, 0.1000], device='cuda:0')
# Test Accuracy for current combination: 0.7350
#
# Testing combination 44: threshold=0.4, random_state=290, layers=3, hidden_channels=40, lr=0.05, gamma=2.7000000000000006, alpha=0.7000000000000001
# Alpha weights: tensor([0.3000, 0.7000], device='cuda:0')
# Test Accuracy for current combination: 0.7100
#
# Testing combination 45: threshold=0.2, random_state=290, layers=4, hidden_channels=170, lr=0.005, gamma=3.500000000000001, alpha=0.4
# Alpha weights: tensor([0.6000, 0.4000], device='cuda:0')
# Test Accuracy for current combination: 0.7150
#
# Testing combination 46: threshold=0.32000000000000006, random_state=180, layers=2, hidden_channels=50, lr=0.001, gamma=2.7000000000000006, alpha=0.8
# Alpha weights: tensor([0.2000, 0.8000], device='cuda:0')
# Test Accuracy for current combination: 0.7250
#
# Testing combination 47: threshold=0.28, random_state=290, layers=3, hidden_channels=150, lr=0.005, gamma=1.9000000000000004, alpha=0.1
# Alpha weights: tensor([0.9000, 0.1000], device='cuda:0')
# Test Accuracy for current combination: 0.7550
#
# Testing combination 48: threshold=0.12000000000000001, random_state=10, layers=2, hidden_channels=50, lr=0.001, gamma=2.7000000000000006, alpha=0.8
# Alpha weights: tensor([0.2000, 0.8000], device='cuda:0')
# Test Accuracy for current combination: 0.7200
#
# Testing combination 49: threshold=0.28, random_state=100, layers=4, hidden_channels=50, lr=0.005, gamma=3.7000000000000006, alpha=0.1
# Alpha weights: tensor([0.9000, 0.1000], device='cuda:0')
# Test Accuracy for current combination: 0.7200
#
# Testing combination 50: threshold=0.16000000000000003, random_state=90, layers=5, hidden_channels=280, lr=0.001, gamma=0.5000000000000001, alpha=0.8
# Alpha weights: tensor([0.2000, 0.8000], device='cuda:0')
# Test Accuracy for current combination: 0.7000
#
# Testing combination 51: threshold=0.30000000000000004, random_state=230, layers=3, hidden_channels=120, lr=0.01, gamma=2.3000000000000007, alpha=0.7000000000000001
# Alpha weights: tensor([0.3000, 0.7000], device='cuda:0')
# Test Accuracy for current combination: 0.7200
#
# Testing combination 52: threshold=0.18000000000000002, random_state=140, layers=5, hidden_channels=170, lr=0.05, gamma=2.1000000000000005, alpha=0.4
# Alpha weights: tensor([0.6000, 0.4000], device='cuda:0')
# Test Accuracy for current combination: 0.7000
#
# Testing combination 53: threshold=0.3400000000000001, random_state=40, layers=4, hidden_channels=50, lr=0.005, gamma=3.1000000000000005, alpha=0.30000000000000004
# Alpha weights: tensor([0.7000, 0.3000], device='cuda:0')
# Test Accuracy for current combination: 0.7000
#
# Testing combination 54: threshold=0.18000000000000002, random_state=30, layers=1, hidden_channels=230, lr=0.05, gamma=2.900000000000001, alpha=0.7000000000000001
# Alpha weights: tensor([0.3000, 0.7000], device='cuda:0')
# Test Accuracy for current combination: 0.7600
#
# Testing combination 55: threshold=0.4, random_state=20, layers=1, hidden_channels=180, lr=0.001, gamma=2.7000000000000006, alpha=0.5
# Alpha weights: tensor([0.5000, 0.5000], device='cuda:0')
# Test Accuracy for current combination: 0.7400
#
# Testing combination 56: threshold=0.32000000000000006, random_state=270, layers=5, hidden_channels=40, lr=0.05, gamma=3.3000000000000007, alpha=0.8
# Alpha weights: tensor([0.2000, 0.8000], device='cuda:0')
# Test Accuracy for current combination: 0.7050
#
# Testing combination 57: threshold=0.22000000000000003, random_state=70, layers=2, hidden_channels=250, lr=0.01, gamma=0.5000000000000001, alpha=0.5
# Alpha weights: tensor([0.5000, 0.5000], device='cuda:0')
# Test Accuracy for current combination: 0.7000
#
# Testing combination 58: threshold=0.3400000000000001, random_state=150, layers=5, hidden_channels=110, lr=0.05, gamma=3.7000000000000006, alpha=0.6
# Alpha weights: tensor([0.4000, 0.6000], device='cuda:0')
# Test Accuracy for current combination: 0.6850
#
# Testing combination 59: threshold=0.16000000000000003, random_state=130, layers=4, hidden_channels=20, lr=0.005, gamma=1.3000000000000003, alpha=0.8
# Alpha weights: tensor([0.2000, 0.8000], device='cuda:0')
# Test Accuracy for current combination: 0.7050
#
# Testing combination 60: threshold=0.3600000000000001, random_state=120, layers=4, hidden_channels=280, lr=0.05, gamma=2.900000000000001, alpha=0.8
# Alpha weights: tensor([0.2000, 0.8000], device='cuda:0')
# Test Accuracy for current combination: 0.6050
#
# Testing combination 61: threshold=0.12000000000000001, random_state=100, layers=1, hidden_channels=40, lr=0.01, gamma=3.900000000000001, alpha=0.4
# Alpha weights: tensor([0.6000, 0.4000], device='cuda:0')
# Test Accuracy for current combination: 0.7550
#
# Testing combination 62: threshold=0.30000000000000004, random_state=50, layers=5, hidden_channels=40, lr=0.001, gamma=1.7000000000000004, alpha=0.6
# Alpha weights: tensor([0.4000, 0.6000], device='cuda:0')
# Test Accuracy for current combination: 0.7300
#
# Testing combination 63: threshold=0.24000000000000002, random_state=200, layers=5, hidden_channels=280, lr=0.001, gamma=2.1000000000000005, alpha=0.1
# Alpha weights: tensor([0.9000, 0.1000], device='cuda:0')
# Test Accuracy for current combination: 0.7550
#
# Testing combination 64: threshold=0.4, random_state=20, layers=1, hidden_channels=200, lr=0.001, gamma=3.1000000000000005, alpha=0.30000000000000004
# Alpha weights: tensor([0.7000, 0.3000], device='cuda:0')
# Test Accuracy for current combination: 0.7350
#
# Testing combination 65: threshold=0.24000000000000002, random_state=30, layers=2, hidden_channels=170, lr=0.01, gamma=2.1000000000000005, alpha=0.2
# Alpha weights: tensor([0.8000, 0.2000], device='cuda:0')
# Test Accuracy for current combination: 0.7550
#
# Testing combination 66: threshold=0.2, random_state=220, layers=4, hidden_channels=90, lr=0.001, gamma=1.5000000000000004, alpha=0.2
# Alpha weights: tensor([0.8000, 0.2000], device='cuda:0')
# Test Accuracy for current combination: 0.7400
#
# Testing combination 67: threshold=0.16000000000000003, random_state=70, layers=3, hidden_channels=100, lr=0.05, gamma=0.30000000000000004, alpha=0.8
# Alpha weights: tensor([0.2000, 0.8000], device='cuda:0')
# Test Accuracy for current combination: 0.7000
#
# Testing combination 68: threshold=0.30000000000000004, random_state=250, layers=4, hidden_channels=30, lr=0.001, gamma=0.7000000000000001, alpha=0.4
# Alpha weights: tensor([0.6000, 0.4000], device='cuda:0')
# Test Accuracy for current combination: 0.7650
#
# Testing combination 69: threshold=0.3600000000000001, random_state=150, layers=3, hidden_channels=110, lr=0.05, gamma=3.7000000000000006, alpha=0.4
# Alpha weights: tensor([0.6000, 0.4000], device='cuda:0')
# Test Accuracy for current combination: 0.7200
#
# Testing combination 70: threshold=0.4, random_state=160, layers=3, hidden_channels=260, lr=0.005, gamma=2.3000000000000007, alpha=0.2
# Alpha weights: tensor([0.8000, 0.2000], device='cuda:0')
# Test Accuracy for current combination: 0.7450
#
# Testing combination 71: threshold=0.32000000000000006, random_state=60, layers=1, hidden_channels=190, lr=0.001, gamma=1.7000000000000004, alpha=0.7000000000000001
# Alpha weights: tensor([0.3000, 0.7000], device='cuda:0')
# Test Accuracy for current combination: 0.7500
#
# Testing combination 72: threshold=0.3400000000000001, random_state=100, layers=2, hidden_channels=160, lr=0.05, gamma=3.7000000000000006, alpha=0.30000000000000004
# Alpha weights: tensor([0.7000, 0.3000], device='cuda:0')
# Test Accuracy for current combination: 0.7300
#
# Testing combination 73: threshold=0.18000000000000002, random_state=260, layers=4, hidden_channels=190, lr=0.005, gamma=2.7000000000000006, alpha=0.6
# Alpha weights: tensor([0.4000, 0.6000], device='cuda:0')
# Test Accuracy for current combination: 0.7650
#
# Testing combination 74: threshold=0.3400000000000001, random_state=110, layers=1, hidden_channels=240, lr=0.001, gamma=0.30000000000000004, alpha=0.4
# Alpha weights: tensor([0.6000, 0.4000], device='cuda:0')
# Test Accuracy for current combination: 0.7200
#
# Testing combination 75: threshold=0.30000000000000004, random_state=80, layers=2, hidden_channels=20, lr=0.001, gamma=1.5000000000000004, alpha=0.1
# Alpha weights: tensor([0.9000, 0.1000], device='cuda:0')
# Test Accuracy for current combination: 0.7100
#
# Testing combination 76: threshold=0.38, random_state=210, layers=1, hidden_channels=180, lr=0.05, gamma=0.1, alpha=0.7000000000000001
# Alpha weights: tensor([0.3000, 0.7000], device='cuda:0')
# Test Accuracy for current combination: 0.7000
#
# Testing combination 77: threshold=0.2, random_state=30, layers=1, hidden_channels=50, lr=0.005, gamma=2.7000000000000006, alpha=0.7000000000000001
# Alpha weights: tensor([0.3000, 0.7000], device='cuda:0')
# Test Accuracy for current combination: 0.7500
#
# Testing combination 78: threshold=0.32000000000000006, random_state=280, layers=1, hidden_channels=70, lr=0.001, gamma=2.1000000000000005, alpha=0.5
# Alpha weights: tensor([0.5000, 0.5000], device='cuda:0')
# Test Accuracy for current combination: 0.7400
#
# Testing combination 79: threshold=0.18000000000000002, random_state=280, layers=5, hidden_channels=240, lr=0.001, gamma=0.7000000000000001, alpha=0.6
# Alpha weights: tensor([0.4000, 0.6000], device='cuda:0')
# Test Accuracy for current combination: 0.7000
#
# Testing combination 80: threshold=0.30000000000000004, random_state=20, layers=4, hidden_channels=260, lr=0.001, gamma=2.7000000000000006, alpha=0.4
# Alpha weights: tensor([0.6000, 0.4000], device='cuda:0')
# Test Accuracy for current combination: 0.7200
#
# Testing combination 81: threshold=0.30000000000000004, random_state=150, layers=5, hidden_channels=280, lr=0.001, gamma=3.3000000000000007, alpha=0.4
# Alpha weights: tensor([0.6000, 0.4000], device='cuda:0')
# Test Accuracy for current combination: 0.7250
#
# Testing combination 82: threshold=0.26, random_state=120, layers=2, hidden_channels=280, lr=0.005, gamma=2.3000000000000007, alpha=0.1
# Alpha weights: tensor([0.9000, 0.1000], device='cuda:0')
# Test Accuracy for current combination: 0.7500
#
# Testing combination 83: threshold=0.16000000000000003, random_state=80, layers=4, hidden_channels=250, lr=0.05, gamma=2.1000000000000005, alpha=0.8
# Alpha weights: tensor([0.2000, 0.8000], device='cuda:0')
# Test Accuracy for current combination: 0.6800
#
# Testing combination 84: threshold=0.24000000000000002, random_state=120, layers=3, hidden_channels=120, lr=0.001, gamma=0.5000000000000001, alpha=0.8
# Alpha weights: tensor([0.2000, 0.8000], device='cuda:0')
# Test Accuracy for current combination: 0.7000
#
# Testing combination 85: threshold=0.1, random_state=130, layers=5, hidden_channels=150, lr=0.01, gamma=0.30000000000000004, alpha=0.6
# Alpha weights: tensor([0.4000, 0.6000], device='cuda:0')
# Test Accuracy for current combination: 0.7000
#
# Testing combination 86: threshold=0.14, random_state=250, layers=1, hidden_channels=170, lr=0.05, gamma=2.7000000000000006, alpha=0.4
# Alpha weights: tensor([0.6000, 0.4000], device='cuda:0')
# Test Accuracy for current combination: 0.7350
#
# Testing combination 87: threshold=0.24000000000000002, random_state=130, layers=5, hidden_channels=140, lr=0.005, gamma=3.3000000000000007, alpha=0.8
# Alpha weights: tensor([0.2000, 0.8000], device='cuda:0')
# Test Accuracy for current combination: 0.7400
#
# Testing combination 88: threshold=0.28, random_state=220, layers=4, hidden_channels=140, lr=0.01, gamma=3.7000000000000006, alpha=0.2
# Alpha weights: tensor([0.8000, 0.2000], device='cuda:0')
# Test Accuracy for current combination: 0.7400
#
# Testing combination 89: threshold=0.38, random_state=70, layers=1, hidden_channels=160, lr=0.005, gamma=2.3000000000000007, alpha=0.1
# Alpha weights: tensor([0.9000, 0.1000], device='cuda:0')
# Test Accuracy for current combination: 0.7100
#
# Testing combination 90: threshold=0.26, random_state=130, layers=5, hidden_channels=140, lr=0.005, gamma=0.7000000000000001, alpha=0.1
# Alpha weights: tensor([0.9000, 0.1000], device='cuda:0')
# Test Accuracy for current combination: 0.7000
#
# Testing combination 91: threshold=0.3400000000000001, random_state=70, layers=3, hidden_channels=190, lr=0.005, gamma=2.5000000000000004, alpha=0.30000000000000004
# Alpha weights: tensor([0.7000, 0.3000], device='cuda:0')
# Test Accuracy for current combination: 0.7200
#
# Testing combination 92: threshold=0.38, random_state=30, layers=3, hidden_channels=240, lr=0.001, gamma=0.7000000000000001, alpha=0.6
# Alpha weights: tensor([0.4000, 0.6000], device='cuda:0')
# Test Accuracy for current combination: 0.7000
#
# Testing combination 93: threshold=0.12000000000000001, random_state=290, layers=4, hidden_channels=60, lr=0.01, gamma=3.3000000000000007, alpha=0.6
# Alpha weights: tensor([0.4000, 0.6000], device='cuda:0')
# Test Accuracy for current combination: 0.7250
#
# Testing combination 94: threshold=0.26, random_state=180, layers=5, hidden_channels=220, lr=0.005, gamma=2.5000000000000004, alpha=0.30000000000000004
# Alpha weights: tensor([0.7000, 0.3000], device='cuda:0')
# Test Accuracy for current combination: 0.7400
#
# Testing combination 95: threshold=0.12000000000000001, random_state=80, layers=5, hidden_channels=50, lr=0.05, gamma=1.7000000000000004, alpha=0.4
# Alpha weights: tensor([0.6000, 0.4000], device='cuda:0')
# Test Accuracy for current combination: 0.7500
#
# Testing combination 96: threshold=0.2, random_state=50, layers=1, hidden_channels=290, lr=0.005, gamma=2.900000000000001, alpha=0.30000000000000004
# Alpha weights: tensor([0.7000, 0.3000], device='cuda:0')
# Test Accuracy for current combination: 0.7500
#
# Testing combination 97: threshold=0.4, random_state=210, layers=5, hidden_channels=190, lr=0.005, gamma=3.3000000000000007, alpha=0.1
# Alpha weights: tensor([0.9000, 0.1000], device='cuda:0')
# Test Accuracy for current combination: 0.7450
#
# Testing combination 98: threshold=0.26, random_state=130, layers=5, hidden_channels=100, lr=0.001, gamma=3.500000000000001, alpha=0.7000000000000001
# Alpha weights: tensor([0.3000, 0.7000], device='cuda:0')
# Test Accuracy for current combination: 0.7300
#
# Testing combination 99: threshold=0.28, random_state=200, layers=5, hidden_channels=230, lr=0.001, gamma=0.5000000000000001, alpha=0.2
# Alpha weights: tensor([0.8000, 0.2000], device='cuda:0')
# Test Accuracy for current combination: 0.7000
#
# Testing combination 100: threshold=0.12000000000000001, random_state=80, layers=3, hidden_channels=150, lr=0.01, gamma=2.3000000000000007, alpha=0.7000000000000001
# Alpha weights: tensor([0.3000, 0.7000], device='cuda:0')
# Test Accuracy for current combination: 0.7650
#
# Testing combination 101: threshold=0.2, random_state=120, layers=4, hidden_channels=120, lr=0.01, gamma=2.7000000000000006, alpha=0.30000000000000004
# Alpha weights: tensor([0.7000, 0.3000], device='cuda:0')
# Test Accuracy for current combination: 0.7400
#
# Testing combination 102: threshold=0.26, random_state=40, layers=5, hidden_channels=120, lr=0.005, gamma=2.5000000000000004, alpha=0.6
# Alpha weights: tensor([0.4000, 0.6000], device='cuda:0')
# Test Accuracy for current combination: 0.7350
#
# Testing combination 103: threshold=0.4, random_state=190, layers=2, hidden_channels=290, lr=0.01, gamma=3.500000000000001, alpha=0.6
# Alpha weights: tensor([0.4000, 0.6000], device='cuda:0')
# Test Accuracy for current combination: 0.7500
#
# Testing combination 104: threshold=0.1, random_state=210, layers=5, hidden_channels=30, lr=0.05, gamma=3.1000000000000005, alpha=0.30000000000000004
# Alpha weights: tensor([0.7000, 0.3000], device='cuda:0')
# Test Accuracy for current combination: 0.7450
#
# Testing combination 105: threshold=0.4, random_state=220, layers=5, hidden_channels=150, lr=0.05, gamma=3.500000000000001, alpha=0.30000000000000004
# Alpha weights: tensor([0.7000, 0.3000], device='cuda:0')
# Test Accuracy for current combination: 0.7000
#
# Testing combination 106: threshold=0.18000000000000002, random_state=140, layers=1, hidden_channels=70, lr=0.01, gamma=3.500000000000001, alpha=0.4
# Alpha weights: tensor([0.6000, 0.4000], device='cuda:0')
# Test Accuracy for current combination: 0.7650
#
# Testing combination 107: threshold=0.32000000000000006, random_state=140, layers=4, hidden_channels=30, lr=0.005, gamma=3.900000000000001, alpha=0.8
# Alpha weights: tensor([0.2000, 0.8000], device='cuda:0')
# Test Accuracy for current combination: 0.7200
#
# Testing combination 108: threshold=0.12000000000000001, random_state=250, layers=1, hidden_channels=130, lr=0.005, gamma=1.7000000000000004, alpha=0.6
# Alpha weights: tensor([0.4000, 0.6000], device='cuda:0')
# Test Accuracy for current combination: 0.7200
#
# Testing combination 109: threshold=0.22000000000000003, random_state=170, layers=4, hidden_channels=160, lr=0.01, gamma=1.3000000000000003, alpha=0.2
# Alpha weights: tensor([0.8000, 0.2000], device='cuda:0')
# Test Accuracy for current combination: 0.7600
#
# Testing combination 110: threshold=0.30000000000000004, random_state=230, layers=2, hidden_channels=70, lr=0.005, gamma=2.3000000000000007, alpha=0.4
# Alpha weights: tensor([0.6000, 0.4000], device='cuda:0')
# Test Accuracy for current combination: 0.7450
#
# Testing combination 111: threshold=0.30000000000000004, random_state=240, layers=3, hidden_channels=240, lr=0.001, gamma=0.9000000000000001, alpha=0.6
# Alpha weights: tensor([0.4000, 0.6000], device='cuda:0')
# Test Accuracy for current combination: 0.7000
#
# Testing combination 112: threshold=0.24000000000000002, random_state=190, layers=4, hidden_channels=280, lr=0.05, gamma=3.900000000000001, alpha=0.8
# Alpha weights: tensor([0.2000, 0.8000], device='cuda:0')
# Test Accuracy for current combination: 0.3000
#
# Testing combination 113: threshold=0.30000000000000004, random_state=280, layers=5, hidden_channels=200, lr=0.005, gamma=2.5000000000000004, alpha=0.7000000000000001
# Alpha weights: tensor([0.3000, 0.7000], device='cuda:0')
# Test Accuracy for current combination: 0.7350
#
# Testing combination 114: threshold=0.1, random_state=180, layers=2, hidden_channels=120, lr=0.001, gamma=0.9000000000000001, alpha=0.6
# Alpha weights: tensor([0.4000, 0.6000], device='cuda:0')
# Test Accuracy for current combination: 0.7500
#
# Testing combination 115: threshold=0.16000000000000003, random_state=90, layers=3, hidden_channels=60, lr=0.005, gamma=1.3000000000000003, alpha=0.8
# Alpha weights: tensor([0.2000, 0.8000], device='cuda:0')
# Test Accuracy for current combination: 0.7550
#
# Testing combination 116: threshold=0.12000000000000001, random_state=150, layers=5, hidden_channels=230, lr=0.01, gamma=0.5000000000000001, alpha=0.7000000000000001
# Alpha weights: tensor([0.3000, 0.7000], device='cuda:0')
# Test Accuracy for current combination: 0.7000
#
# Testing combination 117: threshold=0.26, random_state=270, layers=4, hidden_channels=90, lr=0.001, gamma=3.7000000000000006, alpha=0.4
# Alpha weights: tensor([0.6000, 0.4000], device='cuda:0')
# Test Accuracy for current combination: 0.7450
#
# Testing combination 118: threshold=0.12000000000000001, random_state=120, layers=2, hidden_channels=20, lr=0.01, gamma=1.1000000000000003, alpha=0.7000000000000001
# Alpha weights: tensor([0.3000, 0.7000], device='cuda:0')
# Test Accuracy for current combination: 0.7450
#
# Testing combination 119: threshold=0.38, random_state=80, layers=5, hidden_channels=250, lr=0.05, gamma=3.3000000000000007, alpha=0.6
# Alpha weights: tensor([0.4000, 0.6000], device='cuda:0')
# Test Accuracy for current combination: 0.7000
#
# Testing combination 120: threshold=0.3400000000000001, random_state=100, layers=5, hidden_channels=40, lr=0.05, gamma=2.7000000000000006, alpha=0.5
# Alpha weights: tensor([0.5000, 0.5000], device='cuda:0')
# Test Accuracy for current combination: 0.7100
#
# Testing combination 121: threshold=0.26, random_state=230, layers=1, hidden_channels=60, lr=0.01, gamma=2.7000000000000006, alpha=0.1
# Alpha weights: tensor([0.9000, 0.1000], device='cuda:0')
# Test Accuracy for current combination: 0.7200
#
# Testing combination 122: threshold=0.4, random_state=40, layers=2, hidden_channels=170, lr=0.005, gamma=3.500000000000001, alpha=0.30000000000000004
# Alpha weights: tensor([0.7000, 0.3000], device='cuda:0')
# Test Accuracy for current combination: 0.7700
#
# Testing combination 123: threshold=0.22000000000000003, random_state=80, layers=4, hidden_channels=110, lr=0.05, gamma=1.9000000000000004, alpha=0.30000000000000004
# Alpha weights: tensor([0.7000, 0.3000], device='cuda:0')
# Test Accuracy for current combination: 0.7700
#
# Testing combination 124: threshold=0.16000000000000003, random_state=30, layers=1, hidden_channels=180, lr=0.005, gamma=1.7000000000000004, alpha=0.6
# Alpha weights: tensor([0.4000, 0.6000], device='cuda:0')
# Test Accuracy for current combination: 0.7200
#
# Testing combination 125: threshold=0.1, random_state=220, layers=4, hidden_channels=170, lr=0.01, gamma=0.1, alpha=0.4
# Alpha weights: tensor([0.6000, 0.4000], device='cuda:0')
# Test Accuracy for current combination: 0.7000
#
# Testing combination 126: threshold=0.18000000000000002, random_state=110, layers=4, hidden_channels=110, lr=0.005, gamma=3.900000000000001, alpha=0.4
# Alpha weights: tensor([0.6000, 0.4000], device='cuda:0')
# Test Accuracy for current combination: 0.7650
#
# Testing combination 127: threshold=0.30000000000000004, random_state=60, layers=1, hidden_channels=40, lr=0.05, gamma=3.500000000000001, alpha=0.6
# Alpha weights: tensor([0.4000, 0.6000], device='cuda:0')
# Test Accuracy for current combination: 0.7400
#
# Testing combination 128: threshold=0.14, random_state=100, layers=4, hidden_channels=180, lr=0.01, gamma=2.3000000000000007, alpha=0.2
# Alpha weights: tensor([0.8000, 0.2000], device='cuda:0')
# Test Accuracy for current combination: 0.7700
#
# Testing combination 129: threshold=0.18000000000000002, random_state=30, layers=2, hidden_channels=20, lr=0.001, gamma=1.9000000000000004, alpha=0.7000000000000001
# Alpha weights: tensor([0.3000, 0.7000], device='cuda:0')
# Test Accuracy for current combination: 0.7450
#
# Testing combination 130: threshold=0.30000000000000004, random_state=10, layers=2, hidden_channels=110, lr=0.001, gamma=0.5000000000000001, alpha=0.5
# Alpha weights: tensor([0.5000, 0.5000], device='cuda:0')
# Test Accuracy for current combination: 0.7000
#
# Testing combination 131: threshold=0.28, random_state=190, layers=1, hidden_channels=200, lr=0.001, gamma=1.1000000000000003, alpha=0.6
# Alpha weights: tensor([0.4000, 0.6000], device='cuda:0')
# Test Accuracy for current combination: 0.7350
#
# Testing combination 132: threshold=0.26, random_state=140, layers=3, hidden_channels=290, lr=0.01, gamma=3.7000000000000006, alpha=0.5
# Alpha weights: tensor([0.5000, 0.5000], device='cuda:0')
# Test Accuracy for current combination: 0.7300
#
# Testing combination 133: threshold=0.12000000000000001, random_state=90, layers=1, hidden_channels=110, lr=0.05, gamma=1.3000000000000003, alpha=0.30000000000000004
# Alpha weights: tensor([0.7000, 0.3000], device='cuda:0')
# Test Accuracy for current combination: 0.7400
#
# Testing combination 134: threshold=0.22000000000000003, random_state=230, layers=3, hidden_channels=20, lr=0.005, gamma=3.1000000000000005, alpha=0.5
# Alpha weights: tensor([0.5000, 0.5000], device='cuda:0')
# Test Accuracy for current combination: 0.7500
#
# Testing combination 135: threshold=0.28, random_state=140, layers=1, hidden_channels=290, lr=0.001, gamma=1.3000000000000003, alpha=0.4
# Alpha weights: tensor([0.6000, 0.4000], device='cuda:0')
# Test Accuracy for current combination: 0.7200
#
# Testing combination 136: threshold=0.30000000000000004, random_state=130, layers=4, hidden_channels=200, lr=0.01, gamma=0.1, alpha=0.6
# Alpha weights: tensor([0.4000, 0.6000], device='cuda:0')
# Test Accuracy for current combination: 0.7000
#
# Testing combination 137: threshold=0.16000000000000003, random_state=270, layers=3, hidden_channels=180, lr=0.01, gamma=1.5000000000000004, alpha=0.30000000000000004
# Alpha weights: tensor([0.7000, 0.3000], device='cuda:0')
# Test Accuracy for current combination: 0.7400
#
# Testing combination 138: threshold=0.26, random_state=40, layers=1, hidden_channels=290, lr=0.005, gamma=2.1000000000000005, alpha=0.2
# Alpha weights: tensor([0.8000, 0.2000], device='cuda:0')
# Test Accuracy for current combination: 0.7550
#
# Testing combination 139: threshold=0.3400000000000001, random_state=200, layers=5, hidden_channels=220, lr=0.005, gamma=1.5000000000000004, alpha=0.30000000000000004
# Alpha weights: tensor([0.7000, 0.3000], device='cuda:0')
# Test Accuracy for current combination: 0.7400
#
# Testing combination 140: threshold=0.30000000000000004, random_state=210, layers=5, hidden_channels=110, lr=0.001, gamma=1.9000000000000004, alpha=0.30000000000000004
# Alpha weights: tensor([0.7000, 0.3000], device='cuda:0')
# Test Accuracy for current combination: 0.7150
#
# Testing combination 141: threshold=0.22000000000000003, random_state=10, layers=2, hidden_channels=150, lr=0.05, gamma=3.500000000000001, alpha=0.2
# Alpha weights: tensor([0.8000, 0.2000], device='cuda:0')
# Test Accuracy for current combination: 0.7600
#
# Testing combination 142: threshold=0.26, random_state=130, layers=4, hidden_channels=140, lr=0.05, gamma=3.1000000000000005, alpha=0.5
# Alpha weights: tensor([0.5000, 0.5000], device='cuda:0')
# Test Accuracy for current combination: 0.7000
#
# Testing combination 143: threshold=0.30000000000000004, random_state=190, layers=2, hidden_channels=170, lr=0.001, gamma=1.9000000000000004, alpha=0.5
# Alpha weights: tensor([0.5000, 0.5000], device='cuda:0')
# Test Accuracy for current combination: 0.7300
#
# Testing combination 144: threshold=0.30000000000000004, random_state=10, layers=4, hidden_channels=40, lr=0.001, gamma=3.3000000000000007, alpha=0.5
# Alpha weights: tensor([0.5000, 0.5000], device='cuda:0')
# Test Accuracy for current combination: 0.7250
#
# Testing combination 145: threshold=0.18000000000000002, random_state=220, layers=4, hidden_channels=230, lr=0.005, gamma=0.5000000000000001, alpha=0.2
# Alpha weights: tensor([0.8000, 0.2000], device='cuda:0')
# Test Accuracy for current combination: 0.7000
#
# Testing combination 146: threshold=0.24000000000000002, random_state=140, layers=4, hidden_channels=240, lr=0.001, gamma=0.1, alpha=0.7000000000000001
# Alpha weights: tensor([0.3000, 0.7000], device='cuda:0')
# Test Accuracy for current combination: 0.7000
#
# Testing combination 147: threshold=0.3400000000000001, random_state=60, layers=3, hidden_channels=200, lr=0.001, gamma=1.1000000000000003, alpha=0.4
# Alpha weights: tensor([0.6000, 0.4000], device='cuda:0')
# Test Accuracy for current combination: 0.7400
#
# Testing combination 148: threshold=0.3600000000000001, random_state=160, layers=2, hidden_channels=50, lr=0.05, gamma=1.7000000000000004, alpha=0.7000000000000001
# Alpha weights: tensor([0.3000, 0.7000], device='cuda:0')
# Test Accuracy for current combination: 0.7200
#
# Testing combination 149: threshold=0.16000000000000003, random_state=200, layers=2, hidden_channels=290, lr=0.001, gamma=0.5000000000000001, alpha=0.1
# Alpha weights: tensor([0.9000, 0.1000], device='cuda:0')
# Test Accuracy for current combination: 0.7400
#
# Testing combination 150: threshold=0.3600000000000001, random_state=160, layers=5, hidden_channels=60, lr=0.005, gamma=3.900000000000001, alpha=0.7000000000000001
# Alpha weights: tensor([0.3000, 0.7000], device='cuda:0')
# Test Accuracy for current combination: 0.7300
#
# Testing combination 151: threshold=0.18000000000000002, random_state=140, layers=5, hidden_channels=60, lr=0.05, gamma=1.1000000000000003, alpha=0.1
# Alpha weights: tensor([0.9000, 0.1000], device='cuda:0')
# Test Accuracy for current combination: 0.7350
#
# Testing combination 152: threshold=0.26, random_state=70, layers=5, hidden_channels=220, lr=0.001, gamma=3.7000000000000006, alpha=0.2
# Alpha weights: tensor([0.8000, 0.2000], device='cuda:0')
# Test Accuracy for current combination: 0.7450
#
# Testing combination 153: threshold=0.2, random_state=140, layers=4, hidden_channels=130, lr=0.01, gamma=3.1000000000000005, alpha=0.1
# Alpha weights: tensor([0.9000, 0.1000], device='cuda:0')
# Test Accuracy for current combination: 0.7600
#
# Testing combination 154: threshold=0.18000000000000002, random_state=60, layers=4, hidden_channels=210, lr=0.001, gamma=1.5000000000000004, alpha=0.1
# Alpha weights: tensor([0.9000, 0.1000], device='cuda:0')
# Test Accuracy for current combination: 0.7550
#
# Testing combination 155: threshold=0.26, random_state=50, layers=3, hidden_channels=130, lr=0.005, gamma=2.900000000000001, alpha=0.6
# Alpha weights: tensor([0.4000, 0.6000], device='cuda:0')
# Test Accuracy for current combination: 0.7300
#
# Testing combination 156: threshold=0.14, random_state=20, layers=2, hidden_channels=280, lr=0.05, gamma=1.5000000000000004, alpha=0.2
# Alpha weights: tensor([0.8000, 0.2000], device='cuda:0')
# Test Accuracy for current combination: 0.7900
#
# Testing combination 157: threshold=0.32000000000000006, random_state=110, layers=5, hidden_channels=160, lr=0.005, gamma=0.1, alpha=0.30000000000000004
# Alpha weights: tensor([0.7000, 0.3000], device='cuda:0')
# Test Accuracy for current combination: 0.7000
#
# Testing combination 158: threshold=0.22000000000000003, random_state=210, layers=2, hidden_channels=20, lr=0.001, gamma=2.5000000000000004, alpha=0.5
# Alpha weights: tensor([0.5000, 0.5000], device='cuda:0')
# Test Accuracy for current combination: 0.7550
#
# Testing combination 159: threshold=0.38, random_state=120, layers=4, hidden_channels=190, lr=0.01, gamma=1.1000000000000003, alpha=0.7000000000000001
# Alpha weights: tensor([0.3000, 0.7000], device='cuda:0')
# Test Accuracy for current combination: 0.7400
#
# Testing combination 160: threshold=0.2, random_state=30, layers=4, hidden_channels=100, lr=0.005, gamma=3.500000000000001, alpha=0.4
# Alpha weights: tensor([0.6000, 0.4000], device='cuda:0')
# Test Accuracy for current combination: 0.7600
#
# Testing combination 161: threshold=0.2, random_state=180, layers=3, hidden_channels=250, lr=0.001, gamma=1.7000000000000004, alpha=0.1
# Alpha weights: tensor([0.9000, 0.1000], device='cuda:0')
# Test Accuracy for current combination: 0.7450
#
# Testing combination 162: threshold=0.18000000000000002, random_state=130, layers=5, hidden_channels=140, lr=0.001, gamma=1.1000000000000003, alpha=0.1
# Alpha weights: tensor([0.9000, 0.1000], device='cuda:0')
# Test Accuracy for current combination: 0.7650
#
# Testing combination 163: threshold=0.4, random_state=100, layers=1, hidden_channels=140, lr=0.005, gamma=1.3000000000000003, alpha=0.7000000000000001
# Alpha weights: tensor([0.3000, 0.7000], device='cuda:0')
# Test Accuracy for current combination: 0.6950
#
# Testing combination 164: threshold=0.2, random_state=220, layers=2, hidden_channels=50, lr=0.05, gamma=2.3000000000000007, alpha=0.2
# Alpha weights: tensor([0.8000, 0.2000], device='cuda:0')
# Test Accuracy for current combination: 0.7650
#
# Testing combination 165: threshold=0.14, random_state=140, layers=2, hidden_channels=160, lr=0.005, gamma=2.1000000000000005, alpha=0.30000000000000004
# Alpha weights: tensor([0.7000, 0.3000], device='cuda:0')
# Test Accuracy for current combination: 0.7300
#
# Testing combination 166: threshold=0.32000000000000006, random_state=250, layers=2, hidden_channels=160, lr=0.001, gamma=0.7000000000000001, alpha=0.2
# Alpha weights: tensor([0.8000, 0.2000], device='cuda:0')
# Test Accuracy for current combination: 0.7600
#
# Testing combination 167: threshold=0.30000000000000004, random_state=130, layers=3, hidden_channels=160, lr=0.001, gamma=1.5000000000000004, alpha=0.1
# Alpha weights: tensor([0.9000, 0.1000], device='cuda:0')
# Test Accuracy for current combination: 0.7300
#
# Testing combination 168: threshold=0.3400000000000001, random_state=230, layers=3, hidden_channels=190, lr=0.005, gamma=2.7000000000000006, alpha=0.1
# Alpha weights: tensor([0.9000, 0.1000], device='cuda:0')
# Test Accuracy for current combination: 0.6950
#
# Testing combination 169: threshold=0.14, random_state=150, layers=4, hidden_channels=70, lr=0.005, gamma=3.900000000000001, alpha=0.6
# Alpha weights: tensor([0.4000, 0.6000], device='cuda:0')
# Test Accuracy for current combination: 0.7800
#
# Testing combination 170: threshold=0.28, random_state=50, layers=3, hidden_channels=160, lr=0.005, gamma=2.3000000000000007, alpha=0.1
# Alpha weights: tensor([0.9000, 0.1000], device='cuda:0')
# Test Accuracy for current combination: 0.7300
#
# Testing combination 171: threshold=0.4, random_state=190, layers=2, hidden_channels=260, lr=0.01, gamma=2.3000000000000007, alpha=0.7000000000000001
# Alpha weights: tensor([0.3000, 0.7000], device='cuda:0')
# Test Accuracy for current combination: 0.6700
#
# Testing combination 172: threshold=0.3600000000000001, random_state=70, layers=3, hidden_channels=210, lr=0.005, gamma=2.900000000000001, alpha=0.5
# Alpha weights: tensor([0.5000, 0.5000], device='cuda:0')
# Test Accuracy for current combination: 0.7400
#
# Testing combination 173: threshold=0.24000000000000002, random_state=100, layers=5, hidden_channels=210, lr=0.05, gamma=1.5000000000000004, alpha=0.4
# Alpha weights: tensor([0.6000, 0.4000], device='cuda:0')
# Test Accuracy for current combination: 0.7000
#
# Testing combination 174: threshold=0.38, random_state=190, layers=1, hidden_channels=150, lr=0.001, gamma=1.1000000000000003, alpha=0.5
# Alpha weights: tensor([0.5000, 0.5000], device='cuda:0')
# Test Accuracy for current combination: 0.7450
#
# Testing combination 175: threshold=0.32000000000000006, random_state=140, layers=3, hidden_channels=250, lr=0.01, gamma=1.3000000000000003, alpha=0.8
# Alpha weights: tensor([0.2000, 0.8000], device='cuda:0')
# Test Accuracy for current combination: 0.7550
#
# Testing combination 176: threshold=0.18000000000000002, random_state=100, layers=2, hidden_channels=100, lr=0.001, gamma=1.3000000000000003, alpha=0.30000000000000004
# Alpha weights: tensor([0.7000, 0.3000], device='cuda:0')
# Test Accuracy for current combination: 0.7450
#
# Testing combination 177: threshold=0.28, random_state=60, layers=3, hidden_channels=270, lr=0.001, gamma=0.5000000000000001, alpha=0.4
# Alpha weights: tensor([0.6000, 0.4000], device='cuda:0')
# Test Accuracy for current combination: 0.7000
#
# Testing combination 178: threshold=0.1, random_state=200, layers=2, hidden_channels=50, lr=0.005, gamma=3.500000000000001, alpha=0.5
# Alpha weights: tensor([0.5000, 0.5000], device='cuda:0')
# Test Accuracy for current combination: 0.7550
#
# Testing combination 179: threshold=0.3400000000000001, random_state=150, layers=2, hidden_channels=30, lr=0.01, gamma=2.1000000000000005, alpha=0.30000000000000004
# Alpha weights: tensor([0.7000, 0.3000], device='cuda:0')
# Test Accuracy for current combination: 0.7150
#
# Testing combination 180: threshold=0.3400000000000001, random_state=130, layers=4, hidden_channels=240, lr=0.01, gamma=2.5000000000000004, alpha=0.5
# Alpha weights: tensor([0.5000, 0.5000], device='cuda:0')
# Test Accuracy for current combination: 0.7050
#
# Testing combination 181: threshold=0.32000000000000006, random_state=250, layers=3, hidden_channels=110, lr=0.05, gamma=3.7000000000000006, alpha=0.8
# Alpha weights: tensor([0.2000, 0.8000], device='cuda:0')
# Test Accuracy for current combination: 0.7450
#
# Testing combination 182: threshold=0.3400000000000001, random_state=260, layers=4, hidden_channels=160, lr=0.001, gamma=0.5000000000000001, alpha=0.30000000000000004
# Alpha weights: tensor([0.7000, 0.3000], device='cuda:0')
# Test Accuracy for current combination: 0.7000
#
# Testing combination 183: threshold=0.22000000000000003, random_state=170, layers=2, hidden_channels=50, lr=0.005, gamma=1.3000000000000003, alpha=0.4
# Alpha weights: tensor([0.6000, 0.4000], device='cuda:0')
# Test Accuracy for current combination: 0.7300
#
# Testing combination 184: threshold=0.14, random_state=230, layers=1, hidden_channels=180, lr=0.05, gamma=0.9000000000000001, alpha=0.2
# Alpha weights: tensor([0.8000, 0.2000], device='cuda:0')
# Test Accuracy for current combination: 0.7000
#
# Testing combination 185: threshold=0.32000000000000006, random_state=130, layers=5, hidden_channels=200, lr=0.01, gamma=1.7000000000000004, alpha=0.5
# Alpha weights: tensor([0.5000, 0.5000], device='cuda:0')
# Test Accuracy for current combination: 0.7250
#
# Testing combination 186: threshold=0.2, random_state=90, layers=1, hidden_channels=80, lr=0.001, gamma=2.3000000000000007, alpha=0.6
# Alpha weights: tensor([0.4000, 0.6000], device='cuda:0')
# Test Accuracy for current combination: 0.7400
#
# Testing combination 187: threshold=0.16000000000000003, random_state=60, layers=3, hidden_channels=80, lr=0.05, gamma=2.3000000000000007, alpha=0.4
# Alpha weights: tensor([0.6000, 0.4000], device='cuda:0')
# Test Accuracy for current combination: 0.7500
#
# Testing combination 188: threshold=0.30000000000000004, random_state=130, layers=3, hidden_channels=170, lr=0.001, gamma=0.1, alpha=0.2
# Alpha weights: tensor([0.8000, 0.2000], device='cuda:0')
# Test Accuracy for current combination: 0.7000
#
# Testing combination 189: threshold=0.28, random_state=170, layers=4, hidden_channels=260, lr=0.05, gamma=3.7000000000000006, alpha=0.8
# Alpha weights: tensor([0.2000, 0.8000], device='cuda:0')
# Test Accuracy for current combination: 0.3000
#
# Testing combination 190: threshold=0.16000000000000003, random_state=50, layers=4, hidden_channels=210, lr=0.005, gamma=0.1, alpha=0.7000000000000001
# Alpha weights: tensor([0.3000, 0.7000], device='cuda:0')
# Test Accuracy for current combination: 0.7000
#
# Testing combination 191: threshold=0.12000000000000001, random_state=150, layers=3, hidden_channels=20, lr=0.001, gamma=0.7000000000000001, alpha=0.30000000000000004
# Alpha weights: tensor([0.7000, 0.3000], device='cuda:0')
# Test Accuracy for current combination: 0.7450
#
# Testing combination 192: threshold=0.24000000000000002, random_state=270, layers=1, hidden_channels=30, lr=0.005, gamma=3.3000000000000007, alpha=0.6
# Alpha weights: tensor([0.4000, 0.6000], device='cuda:0')
# Test Accuracy for current combination: 0.7500
#
# Testing combination 193: threshold=0.12000000000000001, random_state=200, layers=1, hidden_channels=40, lr=0.005, gamma=0.9000000000000001, alpha=0.6
# Alpha weights: tensor([0.4000, 0.6000], device='cuda:0')
# Test Accuracy for current combination: 0.7550
#
# Testing combination 194: threshold=0.22000000000000003, random_state=70, layers=5, hidden_channels=140, lr=0.05, gamma=3.7000000000000006, alpha=0.5
# Alpha weights: tensor([0.5000, 0.5000], device='cuda:0')
# Test Accuracy for current combination: 0.7000
#
# Testing combination 195: threshold=0.28, random_state=50, layers=3, hidden_channels=30, lr=0.005, gamma=3.7000000000000006, alpha=0.8
# Alpha weights: tensor([0.2000, 0.8000], device='cuda:0')
# Test Accuracy for current combination: 0.7250
#
# Testing combination 196: threshold=0.12000000000000001, random_state=80, layers=1, hidden_channels=140, lr=0.05, gamma=0.30000000000000004, alpha=0.1
# Alpha weights: tensor([0.9000, 0.1000], device='cuda:0')
# Test Accuracy for current combination: 0.7000
#
# Testing combination 197: threshold=0.2, random_state=260, layers=5, hidden_channels=120, lr=0.001, gamma=1.7000000000000004, alpha=0.7000000000000001
# Alpha weights: tensor([0.3000, 0.7000], device='cuda:0')
# Test Accuracy for current combination: 0.7500
#
# Testing combination 198: threshold=0.1, random_state=190, layers=1, hidden_channels=40, lr=0.001, gamma=2.5000000000000004, alpha=0.1
# Alpha weights: tensor([0.9000, 0.1000], device='cuda:0')
# Test Accuracy for current combination: 0.7050
#
# Testing combination 199: threshold=0.14, random_state=150, layers=3, hidden_channels=240, lr=0.01, gamma=1.3000000000000003, alpha=0.2
# Alpha weights: tensor([0.8000, 0.2000], device='cuda:0')
# Test Accuracy for current combination: 0.7700
#
# Testing combination 200: threshold=0.2, random_state=190, layers=1, hidden_channels=20, lr=0.001, gamma=2.5000000000000004, alpha=0.4
# Alpha weights: tensor([0.6000, 0.4000], device='cuda:0')
# Test Accuracy for current combination: 0.7250
#
# Best Hyperparameters: (0.14, 20, 2, 280, 0.05, 1.5000000000000004, 0.2)
#
# Best Model Classification Report on Test Set:
#               precision    recall  f1-score   support
#
#      Class 0     0.8063    0.9214    0.8600       140
#      Class 1     0.7250    0.4833    0.5800        60
#
#     accuracy                         0.7900       200
#    macro avg     0.7656    0.7024    0.7200       200
# weighted avg     0.7819    0.7900    0.7760       200
#
# Best Model Test Set Metrics:
# Precision: 0.7656, Recall: 0.7024, F1: 0.7200, Accuracy: 0.7900
